# %% [markdown]
# # Optimize The Background Subtraction
#
# In our problem, the true background density ($N_f$) is not directly estimted, we use the background density in a ring around the cluster, $\hat{N}_f$. However, as we saw in the discussion of the normalization factor, it is not always that the local background provides an unbiased estimator.
#
# For this reason, we propose a fit of the true background density, our only free parameter is a multiplicative bias, $f = N_f/\hat{N}_f$, which is minimized for a given cluster.
#
# We know the total number of galaxies in the field and we want to estimate the $N_c$ and $N_f$,
# $$
# N_{cf} = N_c+N_f
# $$
#
# Our estimator of the number of cluster galaxies $\hat{N}_c$ is the sum of the membership probabilties. Then, we can define our probilize as the minizmiaof cluster galaxies. The loss function is given by:
#
# $$
# L (f | model,N_f, N_{cf}) = \left| \left( N_{cf} - N_f\right) - Prior(N_c,N_f)\sum{\frac{P(R,z,c|\; \textit{member})}{P(R,z,c)}} \right|
# $$
#
# We can then assume we don't know the true background density $N_f$ and re-write the loss function in terms of $f$. Since $N_{cf}$ and $\hat{N}_f$ are given the only free variable which remains is the multiplicative bias.
#
# $$
# L (f | model,\hat{N}_f, N_{cf}) = \left| \left(N_{cf} - f \hat{N}_f\right) -Prior(N_{cf}-f\hat{N}_f,f\hat{N}_f)\sum{\frac{P(R,z,c|\; \textit{member})}{P(R,z,c)}}  \right|
# $$
#
# The loss functions as is writen depends on the prior but it does not depend on the membership probabilites per se. So, this framework allow us to perofrm the fit in a post analysis.

# %%
# Loss function
def prior(a,b):
    return a/(a+b)

# def loss(f, params, p=2.):
#     """A simple loss function as a function of parameters `theta`."""
    
#     x, hat_Nf, Ncf = params
#     ngals      = Ncf - f*hat_Nf
#     ngals_pred = prior(ngals,f*hat_Nf)*x
#     resid      = np.abs(ngals_pred - ngals)
#     return np.sum(resid**p)

# %% [markdown]
# # Copacabana
#
# In this lines, I'll load the copacabana output and investigate the addition of the Beta Distribution.

# %%
import matplotlib.pyplot as plt
import matplotlib

import seaborn as sns; sns.set(color_codes=True)
plt.rcParams.update({'font.size': 16})
sns.set_style("whitegrid")

import numpy as np
from scipy.interpolate import interp1d
import scipy

# %%
import sys
sys.path.append("/home/s1/jesteves/git/ccopa/python/")
from main import copacabana
# Out:
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using Modified sklearn.mixture.GMM, modified to allow data weights

# %%
cfg='/home/s1/jesteves/git/ccopa/config_files/config_copa_dc2.yaml'
dataset='cosmoDC2'

copa = copacabana(cfg,dataset=dataset)

# %%
run_name = 'gauss003-r200'
cat = copa.load_copa_out('cluster',run_name)
gal = copa.load_copa_out('members',run_name)
# Out:
# Matching Copa output with main and BMA

# %% [markdown]
# ## Loading $\alpha$ and $\beta$
#
# We're making a correction on the $n_c$ only for this purpose. In another notebook I'll investigate why $n_c$ is biased.

# %%
area = np.array(np.pi*cat['R200']**2)

nbkg= cat['Nbkg']

Nc = cat['Norm']
Nf = nbkg*area
Ncf= (Nc/area+nbkg)*area

Nt = cat['Ngals_true']
Nft= cat['Nbkg_true']*area

ftrue = Nft/Nf

# %%
plt.hist((Nft+Nt)/(Nc+Nf),bins=20)
#plt.xscale('log')
plt.yscale('log')

# %%
np.std((Nft+Nt)/(Nc+Nf))
# Out:
# 0.0865257608885472

# %%
#Ncf = (Nt+Nft)

# %%
alpha = np.array(Nc).copy()
beta  = np.array(Nf).copy()
prior = alpha/(alpha+beta)

# %%
cids = np.array(cat['CID'])
gids = np.array(gal['CID'])
r200 = np.array(cat['R200'])
zcls = np.array(cat['redshift'])
keys = list(chunks(gids,cids))
ncls = len(cat)

# %%
ncls    = len(cat)
columns = ['flat','beta','old']

## compute the new probabilities
cla,res = [],[]
for i in range(ncls):
    print('alpha,beta: %.2f ,%.2f'%(alpha[i],beta[i]))
    b = BayesianProbability(alpha[i],beta[i],r2=r200[i])
    b.assign_probabilities(gal[keys[i]])
    b.compute_ngals()
    
    res.append(np.sum(b.prob['Pmem']['flat'])/b.prob['prior']['flat'])
    cla.append(b)
    del b
# Out:
# alpha,beta: 74.80 ,10.20
# alpha,beta: 21.01 ,4.10
# alpha,beta: 13.11 ,8.00
# alpha,beta: 21.11 ,7.19
# alpha,beta: 6.29 ,1.88
# alpha,beta: 59.94 ,22.59
# alpha,beta: 35.33 ,6.95
# alpha,beta: 3.59 ,6.85
# alpha,beta: 29.05 ,7.87
# alpha,beta: 4.79 ,2.89
# alpha,beta: 1.80 ,3.59
# alpha,beta: 68.66 ,14.22
# alpha,beta: 2.66 ,4.70
# alpha,beta: 13.31 ,9.35
# alpha,beta: 4.61 ,3.09
# alpha,beta: 1.56 ,2.82
# alpha,beta: 4.93 ,3.67
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 19.44 ,7.02
# alpha,beta: 8.74 ,6.23
# alpha,beta: 13.98 ,4.16
# alpha,beta: 7.39 ,6.02
# alpha,beta: 22.98 ,8.33
# alpha,beta: 4.63 ,2.56
# alpha,beta: 15.93 ,8.59
# alpha,beta: 57.65 ,10.29
# alpha,beta: 7.46 ,4.34
# alpha,beta: 33.29 ,20.41
# alpha,beta: 1.86 ,2.67
# alpha,beta: 31.64 ,6.61
# alpha,beta: 9.84 ,5.53
# alpha,beta: 14.80 ,3.48
# alpha,beta: 1.80 ,2.19
# alpha,beta: 2.12 ,4.15
# alpha,beta: 23.24 ,6.54
# alpha,beta: 13.65 ,5.40
# alpha,beta: 83.46 ,11.50
# alpha,beta: 5.61 ,3.85
# alpha,beta: 8.34 ,4.96
# alpha,beta: 6.55 ,3.56
# alpha,beta: 10.57 ,2.33
# alpha,beta: 3.60 ,3.89
# alpha,beta: 144.49 ,11.80
# alpha,beta: 7.50 ,3.35
# alpha,beta: 1.85 ,2.71
# alpha,beta: 0.92 ,2.48
# alpha,beta: 1.58 ,2.64
# alpha,beta: 30.40 ,4.21
# alpha,beta: 18.40 ,6.90
# alpha,beta: 7.66 ,2.33
# alpha,beta: 93.42 ,23.74
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:152: RuntimeWarning: invalid value encountered in multiply
# alpha,beta: 11.94 ,3.89
# alpha,beta: 89.10 ,14.02
# alpha,beta: 49.49 ,10.41
# alpha,beta: 1.59 ,2.22
# alpha,beta: 37.43 ,7.97
# alpha,beta: 5.66 ,4.43
# alpha,beta: 46.30 ,27.02
# alpha,beta: 12.09 ,5.05
# alpha,beta: 6.32 ,3.71
# alpha,beta: 23.63 ,5.76
# alpha,beta: 5.41 ,2.58
# alpha,beta: 39.69 ,7.74
# alpha,beta: 22.80 ,9.38
# alpha,beta: 7.95 ,5.75
# alpha,beta: 14.57 ,2.83
# alpha,beta: 38.21 ,17.44
# alpha,beta: 3.24 ,1.83
# alpha,beta: 3.59 ,3.62
# alpha,beta: 72.51 ,22.22
# alpha,beta: 14.46 ,6.71
# alpha,beta: 27.38 ,7.50
# alpha,beta: 9.28 ,5.44
# alpha,beta: 10.61 ,4.64
# alpha,beta: 10.16 ,6.74
# alpha,beta: 9.85 ,5.52
# alpha,beta: 7.51 ,3.77
# alpha,beta: 5.72 ,2.99
# alpha,beta: 31.19 ,5.46
# alpha,beta: -0.53 ,2.45
# alpha,beta: 12.26 ,6.71
# alpha,beta: 2.65 ,2.11
# alpha,beta: 20.52 ,17.30
# alpha,beta: 6.53 ,3.15
# alpha,beta: 6.57 ,3.54
# alpha,beta: 5.44 ,1.64
# alpha,beta: 2.87 ,3.92
# alpha,beta: 7.58 ,2.62
# alpha,beta: 35.60 ,12.06
# alpha,beta: 1.42 ,2.98
# alpha,beta: 7.60 ,2.83
# alpha,beta: 21.80 ,6.92
# alpha,beta: 5.19 ,4.39
# alpha,beta: 17.51 ,5.83
# alpha,beta: 4.52 ,2.68
# alpha,beta: 20.72 ,6.12
# alpha,beta: 3.14 ,2.57
# alpha,beta: 3.55 ,10.07
# alpha,beta: 21.07 ,8.29
# alpha,beta: 30.24 ,5.32
# alpha,beta: 4.79 ,3.74
# alpha,beta: 33.54 ,7.77
# alpha,beta: 11.98 ,6.47
# alpha,beta: 3.09 ,1.89
# alpha,beta: 5.22 ,2.11
# alpha,beta: 12.85 ,5.93
# alpha,beta: 18.09 ,6.73
# alpha,beta: 6.94 ,3.69
# alpha,beta: 30.97 ,10.46
# alpha,beta: 14.70 ,9.29
# alpha,beta: 1.73 ,2.94
# alpha,beta: 6.85 ,5.06
# alpha,beta: 14.75 ,8.56
# alpha,beta: 3.48 ,2.28
# alpha,beta: 19.94 ,5.49
# alpha,beta: 3.21 ,3.04
# alpha,beta: 57.93 ,6.00
# alpha,beta: 29.25 ,12.26
# alpha,beta: 3.83 ,2.19
# alpha,beta: 8.37 ,4.50
# alpha,beta: 17.14 ,4.43
# alpha,beta: -0.52 ,2.88
# alpha,beta: 12.04 ,4.03
# alpha,beta: 6.90 ,2.25
# alpha,beta: 3.41 ,4.20
# alpha,beta: 3.79 ,3.32
# alpha,beta: 42.73 ,6.18
# alpha,beta: 3.33 ,4.26
# alpha,beta: 8.40 ,3.46
# alpha,beta: 5.24 ,3.69
# alpha,beta: 13.06 ,8.31
# alpha,beta: 6.72 ,4.95
# alpha,beta: 9.06 ,8.89
# alpha,beta: 2.88 ,3.51
# alpha,beta: 14.60 ,8.00
# alpha,beta: 21.77 ,5.32
# alpha,beta: 35.68 ,9.36
# alpha,beta: 39.37 ,23.46
# alpha,beta: 43.07 ,6.57
# alpha,beta: 10.56 ,6.47
# alpha,beta: 2.60 ,4.17
# alpha,beta: 3.40 ,2.38
# alpha,beta: 4.51 ,4.08
# alpha,beta: 13.15 ,4.61
# alpha,beta: 28.76 ,6.34
# alpha,beta: 2.55 ,1.96
# alpha,beta: 5.28 ,2.83
# alpha,beta: 13.92 ,6.24
# alpha,beta: 6.47 ,3.81
# alpha,beta: 51.15 ,9.96
# alpha,beta: 13.89 ,5.26
# alpha,beta: 138.87 ,13.36
# alpha,beta: 9.98 ,2.92
# alpha,beta: 14.03 ,3.54
# alpha,beta: 3.51 ,4.82
# alpha,beta: 10.81 ,4.07
# alpha,beta: 8.13 ,9.60
# alpha,beta: 6.35 ,2.38
# alpha,beta: 17.45 ,5.31
# alpha,beta: 16.28 ,12.79
# alpha,beta: 8.19 ,2.71
# alpha,beta: 28.46 ,6.00
# alpha,beta: 19.54 ,5.69
# alpha,beta: 17.86 ,4.24
# alpha,beta: 7.60 ,7.21
# alpha,beta: 11.11 ,4.52
# alpha,beta: 2.38 ,5.57
# alpha,beta: 1.02 ,2.63
# alpha,beta: 29.42 ,12.89
# alpha,beta: 18.02 ,4.21
# alpha,beta: 5.83 ,3.31
# alpha,beta: 2.40 ,2.09
# alpha,beta: -1.17 ,4.89
# alpha,beta: 10.86 ,3.84
# alpha,beta: 4.07 ,3.09
# alpha,beta: 5.92 ,2.62
# alpha,beta: 7.84 ,6.08
# alpha,beta: 7.33 ,4.24
# alpha,beta: 56.05 ,15.86
# alpha,beta: 13.49 ,6.13
# alpha,beta: 21.51 ,3.31
# alpha,beta: 3.97 ,3.91
# alpha,beta: 13.56 ,6.77
# alpha,beta: 4.53 ,2.33
# alpha,beta: 22.59 ,5.01
# alpha,beta: 7.49 ,3.20
# alpha,beta: 7.39 ,5.45
# alpha,beta: 1.83 ,3.04
# alpha,beta: 77.16 ,9.78
# alpha,beta: 21.46 ,7.06
# alpha,beta: 5.23 ,4.19
# alpha,beta: 6.73 ,3.86
# alpha,beta: 117.02 ,8.06
# alpha,beta: 10.62 ,5.77
# alpha,beta: 12.08 ,2.99
# alpha,beta: 5.43 ,2.79
# alpha,beta: 27.91 ,7.09
# alpha,beta: 24.55 ,6.60
# alpha,beta: 89.19 ,14.30
# alpha,beta: -0.23 ,5.35
# alpha,beta: 23.48 ,6.07
# alpha,beta: 4.43 ,2.31
# alpha,beta: 3.58 ,3.37
# alpha,beta: 7.96 ,6.71
# alpha,beta: 15.20 ,12.07
# alpha,beta: 4.40 ,4.01
# alpha,beta: 7.16 ,2.43
# alpha,beta: 28.13 ,25.73
# alpha,beta: 2.72 ,2.40
# alpha,beta: 7.35 ,11.61
# alpha,beta: 8.11 ,7.74
# alpha,beta: 3.32 ,3.13
# alpha,beta: 17.78 ,16.80
# alpha,beta: 37.71 ,13.30
# alpha,beta: 12.43 ,5.10
# alpha,beta: 3.98 ,3.13
# alpha,beta: 8.87 ,3.65
# alpha,beta: 17.76 ,8.39
# alpha,beta: 4.45 ,3.65
# alpha,beta: 14.58 ,7.69
# alpha,beta: 18.85 ,6.86
# alpha,beta: 4.76 ,2.12
# alpha,beta: 16.43 ,4.93
# alpha,beta: 36.91 ,9.93
# alpha,beta: 64.20 ,9.71
# alpha,beta: 9.31 ,3.40
# alpha,beta: 10.23 ,4.02
# alpha,beta: 45.68 ,8.63
# alpha,beta: 12.67 ,4.95
# alpha,beta: 5.69 ,3.63
# alpha,beta: 14.33 ,5.83
# alpha,beta: 22.15 ,7.18
# alpha,beta: 19.88 ,8.15
# alpha,beta: 10.80 ,3.67
# alpha,beta: 3.99 ,2.75
# alpha,beta: 34.26 ,11.47
# alpha,beta: 7.47 ,3.75
# alpha,beta: 1.63 ,2.41
# alpha,beta: 4.04 ,3.42
# alpha,beta: 12.81 ,6.38
# alpha,beta: 1.01 ,3.88
# alpha,beta: 3.54 ,3.02
# alpha,beta: 5.30 ,2.47
# alpha,beta: 9.13 ,4.79
# alpha,beta: 13.16 ,3.94
# alpha,beta: 1.04 ,3.04
# alpha,beta: 10.87 ,6.62
# alpha,beta: 43.18 ,11.75
# alpha,beta: 13.67 ,2.32
# alpha,beta: 20.90 ,9.56
# alpha,beta: 20.43 ,4.84
# alpha,beta: 22.76 ,18.39
# alpha,beta: 6.04 ,2.47
# alpha,beta: 2.08 ,2.21
# alpha,beta: 8.80 ,4.76
# alpha,beta: 7.34 ,4.09
# alpha,beta: 7.43 ,4.16
# alpha,beta: 1.47 ,1.91
# alpha,beta: 8.29 ,4.98
# alpha,beta: 8.01 ,4.29
# alpha,beta: 65.41 ,13.49
# alpha,beta: 27.14 ,20.32
# alpha,beta: 29.06 ,12.87
# alpha,beta: 35.61 ,9.22
# alpha,beta: 1.93 ,6.91
# alpha,beta: 0.55 ,3.04
# alpha,beta: 77.03 ,13.26
# alpha,beta: 18.49 ,5.70
# alpha,beta: 7.29 ,3.15
# alpha,beta: 36.98 ,17.83
# alpha,beta: 5.96 ,6.84
# alpha,beta: 6.34 ,6.89
# alpha,beta: 4.75 ,2.36
# alpha,beta: 12.91 ,7.15
# alpha,beta: 4.47 ,4.87
# alpha,beta: 26.97 ,9.44
# alpha,beta: 12.63 ,10.26
# alpha,beta: 4.23 ,2.40
# alpha,beta: 32.30 ,11.35
# alpha,beta: 6.51 ,4.52
# alpha,beta: 8.19 ,7.32
# alpha,beta: 4.34 ,5.01
# alpha,beta: 2.61 ,3.96
# alpha,beta: 9.24 ,5.92
# alpha,beta: 13.82 ,3.88
# alpha,beta: 10.26 ,5.97
# alpha,beta: 8.32 ,6.67
# alpha,beta: 56.20 ,14.46
# alpha,beta: 45.30 ,13.99
# alpha,beta: 3.03 ,2.87
# alpha,beta: 43.30 ,6.22
# alpha,beta: 4.87 ,3.03
# alpha,beta: 6.58 ,4.07
# alpha,beta: 4.50 ,4.52
# alpha,beta: 14.86 ,5.17
# alpha,beta: 76.25 ,16.70
# alpha,beta: 73.10 ,6.40
# alpha,beta: 0.58 ,2.31
# alpha,beta: 24.78 ,4.96
# alpha,beta: 10.45 ,7.00
# alpha,beta: 29.06 ,6.26
# alpha,beta: 13.45 ,8.11
# alpha,beta: 1.85 ,2.67
# alpha,beta: 3.62 ,2.80
# alpha,beta: 3.84 ,3.99
# alpha,beta: 12.37 ,4.39
# alpha,beta: 56.08 ,18.91
# alpha,beta: 8.10 ,7.44
# alpha,beta: 4.78 ,3.15
# alpha,beta: 0.13 ,2.81
# alpha,beta: 32.99 ,4.97
# alpha,beta: 74.99 ,10.44
# alpha,beta: 19.82 ,8.57
# alpha,beta: 7.37 ,5.41
# alpha,beta: 12.25 ,3.54
# alpha,beta: 5.15 ,4.93
# alpha,beta: 27.05 ,11.82
# alpha,beta: 12.04 ,4.49
# alpha,beta: 4.81 ,3.32
# alpha,beta: 20.34 ,7.11
# alpha,beta: 17.04 ,4.47
# alpha,beta: 24.78 ,8.16
# alpha,beta: 4.47 ,2.32
# alpha,beta: 7.31 ,4.97
# alpha,beta: 5.04 ,4.38
# alpha,beta: 5.04 ,5.12
# alpha,beta: 1.58 ,2.49
# alpha,beta: 159.30 ,11.30
# alpha,beta: 32.19 ,11.00
# alpha,beta: 11.30 ,11.70
# alpha,beta: 4.80 ,2.13
# alpha,beta: 46.95 ,11.53
# alpha,beta: 4.56 ,4.67
# alpha,beta: 15.60 ,6.82
# alpha,beta: 1.07 ,2.40
# alpha,beta: 3.16 ,4.23
# alpha,beta: 27.61 ,6.54
# alpha,beta: 3.63 ,1.98
# alpha,beta: 23.89 ,6.99
# alpha,beta: 16.45 ,7.46
# alpha,beta: 28.95 ,7.32
# alpha,beta: 64.96 ,16.85
# alpha,beta: 8.61 ,4.70
# alpha,beta: 53.59 ,13.78
# alpha,beta: 14.40 ,6.04
# alpha,beta: 18.03 ,7.46
# alpha,beta: 6.00 ,2.13
# alpha,beta: 41.01 ,11.57
# alpha,beta: 49.46 ,11.28
# alpha,beta: 4.50 ,3.52
# alpha,beta: 6.26 ,6.02
# alpha,beta: 5.65 ,4.46
# alpha,beta: 19.88 ,10.29
# alpha,beta: 8.20 ,2.61
# alpha,beta: 11.51 ,2.73
# alpha,beta: 4.95 ,2.89
# alpha,beta: 3.07 ,7.29
# alpha,beta: 28.33 ,7.82
# alpha,beta: 21.43 ,8.39
# alpha,beta: 3.13 ,2.89
# alpha,beta: 20.20 ,5.44
# alpha,beta: 11.45 ,4.62
# alpha,beta: 58.99 ,16.79
# alpha,beta: 37.41 ,9.35
# alpha,beta: 5.90 ,2.91
# alpha,beta: 4.56 ,2.45
# alpha,beta: 7.87 ,3.03
# alpha,beta: 0.37 ,3.41
# alpha,beta: 11.25 ,3.97
# alpha,beta: 19.15 ,8.00
# alpha,beta: 4.17 ,3.04
# alpha,beta: 32.73 ,12.89
# alpha,beta: 7.30 ,3.28
# alpha,beta: 10.39 ,8.82
# alpha,beta: 28.34 ,11.02
# alpha,beta: 48.46 ,13.17
# alpha,beta: 3.33 ,2.55
# alpha,beta: 13.64 ,6.22
# alpha,beta: 2.51 ,2.24
# alpha,beta: 19.65 ,5.95
# alpha,beta: 24.95 ,8.73
# alpha,beta: 6.58 ,2.91
# alpha,beta: 18.35 ,5.48
# alpha,beta: 16.84 ,8.74
# alpha,beta: 24.95 ,9.57
# alpha,beta: 3.28 ,2.48
# alpha,beta: 4.08 ,2.85
# alpha,beta: 38.68 ,7.10
# alpha,beta: 18.14 ,5.81
# alpha,beta: 6.23 ,4.25
# alpha,beta: 12.85 ,5.81
# alpha,beta: 112.69 ,31.26
# alpha,beta: 2.98 ,5.56
# alpha,beta: 29.16 ,14.57
# alpha,beta: 26.13 ,10.52
# alpha,beta: 23.46 ,16.04
# alpha,beta: 10.57 ,4.41
# alpha,beta: 16.85 ,3.12
# alpha,beta: 38.80 ,8.70
# alpha,beta: 2.14 ,3.12
# alpha,beta: 9.40 ,5.21
# alpha,beta: 1.62 ,4.02
# alpha,beta: 5.24 ,2.31
# alpha,beta: 13.02 ,4.82
# alpha,beta: 11.18 ,3.97
# alpha,beta: 10.46 ,6.57
# alpha,beta: 9.49 ,2.63
# alpha,beta: 15.09 ,6.74
# alpha,beta: 24.26 ,13.56
# alpha,beta: 20.95 ,6.21
# alpha,beta: 46.77 ,41.56
# alpha,beta: 1.29 ,2.38
# alpha,beta: 5.84 ,3.57
# alpha,beta: 7.19 ,6.45
# alpha,beta: 19.37 ,5.22
# alpha,beta: 6.79 ,2.38
# alpha,beta: 39.53 ,12.85
# alpha,beta: 48.69 ,8.28
# alpha,beta: 77.22 ,7.23
# alpha,beta: 8.41 ,3.15
# alpha,beta: 7.46 ,3.99
# alpha,beta: 15.76 ,8.78
# alpha,beta: 35.16 ,8.80
# alpha,beta: 8.96 ,7.64
# alpha,beta: 16.06 ,5.98
# alpha,beta: 4.33 ,4.11
# alpha,beta: 3.18 ,2.28
# alpha,beta: 11.84 ,3.57
# alpha,beta: 4.20 ,4.44
# alpha,beta: 20.69 ,6.83
# alpha,beta: 22.56 ,8.26
# alpha,beta: 31.17 ,15.50
# alpha,beta: 14.36 ,4.68
# alpha,beta: 15.04 ,10.40
# alpha,beta: 12.30 ,5.80
# alpha,beta: 1.09 ,2.82
# alpha,beta: 7.59 ,7.14
# alpha,beta: 38.64 ,12.37
# alpha,beta: 10.26 ,4.72
# alpha,beta: 3.59 ,5.44
# alpha,beta: 9.16 ,3.42
# alpha,beta: 10.24 ,3.97
# alpha,beta: 26.94 ,12.37
# alpha,beta: 48.23 ,8.68
# alpha,beta: 21.58 ,5.99
# alpha,beta: 11.40 ,2.93
# alpha,beta: 7.89 ,3.36
# alpha,beta: 14.59 ,3.56
# alpha,beta: 15.20 ,5.31
# alpha,beta: 18.18 ,13.46
# alpha,beta: 22.35 ,4.98
# alpha,beta: 0.69 ,3.10
# alpha,beta: 5.85 ,4.44
# alpha,beta: 32.94 ,6.81
# alpha,beta: 7.40 ,3.95
# alpha,beta: 20.69 ,12.07
# alpha,beta: 25.67 ,4.27
# alpha,beta: 4.52 ,2.51
# alpha,beta: 2.84 ,3.43
# alpha,beta: 5.32 ,4.49
# alpha,beta: 23.65 ,18.19
# alpha,beta: 6.98 ,4.87
# alpha,beta: 11.84 ,10.49
# alpha,beta: 22.76 ,10.13
# alpha,beta: 4.80 ,6.77
# alpha,beta: 19.42 ,11.05
# alpha,beta: 5.74 ,2.38
# alpha,beta: 2.12 ,3.12
# alpha,beta: 16.13 ,4.40
# alpha,beta: 1.22 ,3.00
# alpha,beta: 9.71 ,2.86
# alpha,beta: 27.29 ,6.19
# alpha,beta: 46.23 ,13.48
# alpha,beta: 7.09 ,2.88
# alpha,beta: 46.19 ,9.63
# alpha,beta: 9.83 ,4.15
# alpha,beta: 21.23 ,5.01
# alpha,beta: 12.19 ,6.27
# alpha,beta: 1.06 ,3.65
# alpha,beta: 5.12 ,3.42
# alpha,beta: 11.16 ,3.99
# alpha,beta: 10.44 ,5.92
# alpha,beta: 19.61 ,6.00
# alpha,beta: 11.21 ,6.47
# alpha,beta: 12.01 ,4.39
# alpha,beta: 60.99 ,20.04
# alpha,beta: 8.08 ,5.01
# alpha,beta: 9.01 ,4.17
# alpha,beta: 22.17 ,4.60
# alpha,beta: 8.75 ,4.31
# alpha,beta: 33.64 ,11.96
# alpha,beta: 8.22 ,4.10
# alpha,beta: 23.51 ,18.15
# alpha,beta: 13.97 ,7.34
# alpha,beta: 17.15 ,8.84
# alpha,beta: 15.17 ,3.52
# alpha,beta: 18.06 ,9.41
# alpha,beta: 13.02 ,11.47
# alpha,beta: 16.80 ,5.38
# alpha,beta: 5.84 ,3.31
# alpha,beta: 47.14 ,8.51
# alpha,beta: 9.05 ,6.13
# alpha,beta: 23.43 ,10.17
# alpha,beta: 10.02 ,4.94
# alpha,beta: 7.01 ,4.17
# alpha,beta: 13.00 ,16.18
# alpha,beta: 28.68 ,18.95
# alpha,beta: 25.84 ,13.36
# alpha,beta: 8.11 ,6.10
# alpha,beta: 23.02 ,13.38
# alpha,beta: 8.67 ,2.55
# alpha,beta: 10.07 ,6.19
# alpha,beta: 6.80 ,4.45
# alpha,beta: 20.75 ,9.31
# alpha,beta: 5.95 ,6.92
# alpha,beta: 31.62 ,8.55
# alpha,beta: 8.10 ,7.63
# alpha,beta: 3.16 ,1.73
# alpha,beta: 28.52 ,9.28
# alpha,beta: 9.88 ,3.12
# alpha,beta: 79.56 ,10.40
# alpha,beta: 5.78 ,3.84
# alpha,beta: 2.04 ,5.13
# alpha,beta: 40.77 ,10.60
# alpha,beta: 2.49 ,5.11
# alpha,beta: 15.28 ,20.07
# alpha,beta: 9.40 ,3.44
# alpha,beta: 3.36 ,2.80
# alpha,beta: 3.09 ,4.85
# alpha,beta: 4.78 ,2.61
# alpha,beta: 75.93 ,12.14
# alpha,beta: 8.96 ,11.73
# alpha,beta: 14.67 ,4.26
# alpha,beta: 16.28 ,2.92
# alpha,beta: 6.43 ,3.40
# alpha,beta: 50.34 ,11.52
# alpha,beta: 11.64 ,5.68
# alpha,beta: 6.31 ,3.51
# alpha,beta: 4.71 ,2.78
# alpha,beta: 13.31 ,6.64
# alpha,beta: 11.32 ,8.24
# alpha,beta: 14.63 ,6.99
# alpha,beta: 12.54 ,3.10
# alpha,beta: 47.39 ,7.39
# alpha,beta: 2.77 ,2.55
# alpha,beta: 9.86 ,3.33
# alpha,beta: 13.34 ,5.95
# alpha,beta: 2.92 ,2.19
# alpha,beta: 6.91 ,2.33
# alpha,beta: 23.85 ,11.78
# alpha,beta: 62.65 ,31.49
# alpha,beta: 60.52 ,13.22
# alpha,beta: 33.95 ,11.24
# alpha,beta: 7.08 ,5.73
# alpha,beta: 21.36 ,5.94
# alpha,beta: 14.75 ,3.37
# alpha,beta: 16.17 ,7.03
# alpha,beta: 1.54 ,3.91
# alpha,beta: 157.09 ,12.73
# alpha,beta: 18.22 ,5.56
# alpha,beta: 39.43 ,9.00
# alpha,beta: 32.20 ,7.84
# alpha,beta: 23.68 ,12.38
# alpha,beta: 7.21 ,3.88
# alpha,beta: 6.21 ,6.03
# alpha,beta: 18.24 ,10.14
# alpha,beta: 6.68 ,4.00
# alpha,beta: 5.21 ,2.32
# alpha,beta: 8.72 ,4.21
# alpha,beta: 2.72 ,6.77
# alpha,beta: 10.68 ,7.64
# alpha,beta: 21.88 ,14.70
# alpha,beta: 28.57 ,12.78
# alpha,beta: 7.01 ,4.62
# alpha,beta: 58.98 ,12.23
# alpha,beta: 4.65 ,3.52
# alpha,beta: 1.79 ,2.61
# alpha,beta: 2.01 ,3.11
# alpha,beta: 5.85 ,2.13
# alpha,beta: 72.14 ,15.88
# alpha,beta: 14.19 ,7.38
# alpha,beta: 3.68 ,4.21
# alpha,beta: 32.41 ,7.05
# alpha,beta: 17.56 ,7.25
# alpha,beta: 16.39 ,7.79
# alpha,beta: 146.79 ,12.60
# alpha,beta: 35.48 ,8.03
# alpha,beta: 5.43 ,4.43
# alpha,beta: 26.11 ,8.81
# alpha,beta: 7.42 ,3.59
# alpha,beta: 135.06 ,15.45
# alpha,beta: 7.76 ,5.94
# alpha,beta: 9.40 ,4.50
# alpha,beta: 8.01 ,8.87
# alpha,beta: 75.87 ,11.02
# alpha,beta: 28.19 ,19.68
# alpha,beta: 7.47 ,3.71
# alpha,beta: 8.22 ,6.70
# alpha,beta: 54.72 ,11.42
# alpha,beta: 23.19 ,10.52
# alpha,beta: 41.48 ,9.38
# alpha,beta: 4.02 ,2.80
# alpha,beta: 32.30 ,13.64
# alpha,beta: 9.50 ,4.23
# alpha,beta: 28.62 ,6.66
# alpha,beta: 22.88 ,8.96
# alpha,beta: 28.19 ,14.47
# alpha,beta: 5.34 ,2.82
# alpha,beta: 12.64 ,7.75
# alpha,beta: 5.34 ,3.12
# alpha,beta: 10.02 ,5.83
# alpha,beta: 7.71 ,7.05
# alpha,beta: 7.11 ,1.89
# alpha,beta: 17.87 ,5.36
# alpha,beta: 8.33 ,3.21
# alpha,beta: 5.16 ,4.00
# alpha,beta: 0.48 ,4.83
# alpha,beta: 15.91 ,9.67
# alpha,beta: 6.60 ,3.68
# alpha,beta: 4.38 ,2.39
# alpha,beta: 1.67 ,2.29
# alpha,beta: 6.20 ,3.82
# alpha,beta: 7.70 ,5.47
# alpha,beta: 30.59 ,14.52
# alpha,beta: 2.75 ,6.10
# alpha,beta: 4.50 ,3.59
# alpha,beta: 11.54 ,4.89
# alpha,beta: 18.48 ,12.66
# alpha,beta: 1.20 ,2.30
# alpha,beta: 2.47 ,7.60
# alpha,beta: 86.12 ,18.61
# alpha,beta: 6.79 ,4.17
# alpha,beta: 26.78 ,9.28
# alpha,beta: 18.89 ,11.23
# alpha,beta: 16.46 ,4.66
# alpha,beta: 42.86 ,13.84
# alpha,beta: 16.65 ,7.05
# alpha,beta: 10.75 ,6.37
# alpha,beta: 8.67 ,3.37
# alpha,beta: 13.02 ,6.78
# alpha,beta: 25.93 ,9.09
# alpha,beta: 7.09 ,3.72
# alpha,beta: 48.16 ,18.41
# alpha,beta: 7.18 ,5.85
# alpha,beta: 15.40 ,4.05
# alpha,beta: 17.96 ,3.68
# alpha,beta: 28.45 ,9.46
# alpha,beta: 29.47 ,16.66
# alpha,beta: 35.03 ,9.29
# alpha,beta: 17.68 ,7.17
# alpha,beta: 28.22 ,11.66
# alpha,beta: 15.26 ,8.46
# alpha,beta: 98.84 ,8.83
# alpha,beta: 12.74 ,5.60
# alpha,beta: 8.25 ,4.33
# alpha,beta: 4.18 ,2.90
# alpha,beta: 11.84 ,4.08
# alpha,beta: 15.01 ,12.90
# alpha,beta: 13.72 ,4.23
# alpha,beta: 30.81 ,15.28
# alpha,beta: 6.45 ,3.64
# alpha,beta: 0.18 ,4.13
# alpha,beta: 40.91 ,14.42
# alpha,beta: 7.02 ,3.51
# alpha,beta: 9.62 ,5.89
# alpha,beta: 2.78 ,5.30
# alpha,beta: 2.59 ,17.74
# alpha,beta: 22.15 ,7.06
# alpha,beta: 6.52 ,4.14
# alpha,beta: 13.97 ,8.26
# alpha,beta: 12.48 ,5.91
# alpha,beta: 19.48 ,9.03
# alpha,beta: 3.62 ,6.15
# alpha,beta: 31.76 ,13.85
# alpha,beta: 18.10 ,17.79
# alpha,beta: 16.10 ,3.74
# alpha,beta: 65.08 ,14.10
# alpha,beta: 23.65 ,10.20
# alpha,beta: 20.53 ,2.98
# alpha,beta: 80.33 ,13.84
# alpha,beta: 11.29 ,10.58
# alpha,beta: 4.30 ,5.47
# alpha,beta: 4.91 ,2.65
# alpha,beta: 9.51 ,5.88
# alpha,beta: 9.28 ,5.43
# alpha,beta: 9.23 ,4.76
# alpha,beta: 3.84 ,2.51
# alpha,beta: 19.93 ,7.10
# alpha,beta: 19.83 ,15.21
# alpha,beta: 10.63 ,10.55
# alpha,beta: 27.06 ,7.64
# alpha,beta: 44.23 ,7.81
# alpha,beta: 28.97 ,7.30
# alpha,beta: 5.74 ,3.09
# alpha,beta: 4.56 ,4.64
# alpha,beta: 21.47 ,8.57
# alpha,beta: 118.52 ,12.14
# alpha,beta: 11.17 ,14.24
# alpha,beta: 29.94 ,8.39
# alpha,beta: 8.87 ,3.47
# alpha,beta: 2.51 ,2.99
# alpha,beta: 16.63 ,4.91
# alpha,beta: 14.59 ,3.76
# alpha,beta: 9.09 ,3.81
# alpha,beta: 50.54 ,10.05
# alpha,beta: 12.68 ,5.12
# alpha,beta: 12.68 ,3.75
# alpha,beta: 5.68 ,1.95
# alpha,beta: 2.77 ,2.06
# alpha,beta: 6.89 ,3.26
# alpha,beta: 2.76 ,2.91
# alpha,beta: 5.96 ,5.43
# alpha,beta: 44.54 ,9.65
# alpha,beta: 72.55 ,23.43
# alpha,beta: 3.20 ,3.44
# alpha,beta: 22.25 ,11.26
# alpha,beta: 1.20 ,3.22
# alpha,beta: 2.28 ,2.88
# alpha,beta: 18.12 ,4.44
# alpha,beta: 27.84 ,17.06
# alpha,beta: 2.88 ,4.81
# alpha,beta: 18.96 ,6.31
# alpha,beta: 3.63 ,2.98
# alpha,beta: 13.17 ,6.61
# alpha,beta: 23.67 ,6.44
# alpha,beta: 2.72 ,1.81
# alpha,beta: 8.11 ,3.17
# alpha,beta: 1.83 ,2.68
# alpha,beta: 8.91 ,4.32
# alpha,beta: 32.65 ,9.00
# alpha,beta: 31.30 ,9.95
# alpha,beta: 5.40 ,2.33
# alpha,beta: 9.23 ,5.15
# alpha,beta: 13.24 ,11.30
# alpha,beta: 29.18 ,7.74
# alpha,beta: 80.41 ,7.19
# alpha,beta: 2.62 ,2.52
# alpha,beta: 18.15 ,8.89
# alpha,beta: 23.37 ,3.03
# alpha,beta: 10.68 ,3.70
# alpha,beta: 6.42 ,2.95
# alpha,beta: 147.78 ,13.68
# alpha,beta: 1.18 ,2.83
# alpha,beta: 11.92 ,5.70
# alpha,beta: 19.90 ,8.53
# alpha,beta: 25.26 ,14.55
# alpha,beta: 5.81 ,2.73
# alpha,beta: 16.49 ,5.61
# alpha,beta: 9.02 ,2.78
# alpha,beta: 11.20 ,7.41
# alpha,beta: 29.73 ,20.77
# alpha,beta: 21.62 ,14.51
# alpha,beta: 79.22 ,10.56
# alpha,beta: 0.76 ,3.31
# alpha,beta: 23.27 ,11.82
# alpha,beta: 42.43 ,10.22
# alpha,beta: 9.41 ,2.76
# alpha,beta: 7.50 ,2.61
# alpha,beta: 34.23 ,16.19
# alpha,beta: 1.70 ,1.91
# alpha,beta: 9.26 ,4.66
# alpha,beta: 5.58 ,4.92
# alpha,beta: 9.76 ,8.12
# alpha,beta: 9.69 ,4.73
# alpha,beta: 11.57 ,5.80
# alpha,beta: 3.09 ,4.07
# alpha,beta: 18.99 ,13.70
# alpha,beta: 43.25 ,8.62
# alpha,beta: 10.21 ,4.02
# alpha,beta: 10.56 ,10.22
# alpha,beta: 56.69 ,12.18
# alpha,beta: 8.00 ,9.29
# alpha,beta: 13.34 ,4.19
# alpha,beta: 25.25 ,12.34
# alpha,beta: 6.82 ,2.27
# alpha,beta: 3.39 ,4.02
# alpha,beta: 7.16 ,2.92
# alpha,beta: 13.49 ,6.60
# alpha,beta: 19.72 ,5.89
# alpha,beta: 11.05 ,4.22
# alpha,beta: 37.94 ,12.07
# alpha,beta: 26.46 ,6.32
# alpha,beta: 0.99 ,2.09
# alpha,beta: 23.61 ,7.48
# alpha,beta: 19.79 ,20.79
# alpha,beta: 3.98 ,2.12
# alpha,beta: 27.86 ,8.59
# alpha,beta: 4.49 ,6.10
# alpha,beta: 15.16 ,5.41
# alpha,beta: 42.64 ,34.42
# alpha,beta: 1.11 ,2.75
# alpha,beta: 5.25 ,3.18
# alpha,beta: 12.91 ,8.84
# alpha,beta: 4.62 ,2.92
# alpha,beta: 4.46 ,4.49
# alpha,beta: 30.89 ,7.30
# alpha,beta: 51.83 ,12.84
# alpha,beta: 10.42 ,10.70
# alpha,beta: 13.96 ,12.34
# alpha,beta: 24.27 ,9.76
# alpha,beta: 17.15 ,11.93
# alpha,beta: 13.62 ,4.42
# alpha,beta: 10.98 ,8.36
# alpha,beta: 8.32 ,2.41
# alpha,beta: 13.38 ,8.70
# alpha,beta: 10.64 ,4.52
# alpha,beta: 7.47 ,3.09
# alpha,beta: 32.56 ,7.69
# alpha,beta: 1.88 ,3.82
# alpha,beta: 26.06 ,6.74
# alpha,beta: 3.19 ,2.69
# alpha,beta: 4.51 ,3.19
# alpha,beta: 15.51 ,6.81
# alpha,beta: 26.89 ,4.68
# alpha,beta: 4.16 ,3.29
# alpha,beta: 23.87 ,6.49
# alpha,beta: 7.71 ,5.37
# alpha,beta: 5.74 ,4.07
# alpha,beta: 11.36 ,8.00
# alpha,beta: 23.74 ,12.28
# alpha,beta: 3.67 ,2.39
# alpha,beta: 7.40 ,3.19
# alpha,beta: 66.10 ,12.14
# alpha,beta: 3.21 ,2.63
# alpha,beta: 29.17 ,6.46
# alpha,beta: 3.37 ,2.41
# alpha,beta: 15.05 ,8.49
# alpha,beta: 24.18 ,19.59
# alpha,beta: 2.39 ,3.36
# alpha,beta: 9.85 ,12.26
# alpha,beta: 6.43 ,3.94
# alpha,beta: 36.60 ,5.77
# alpha,beta: 4.96 ,4.97
# alpha,beta: 15.98 ,9.50
# alpha,beta: 18.27 ,7.81
# alpha,beta: 5.34 ,8.25
# alpha,beta: 8.87 ,4.82
# alpha,beta: 8.01 ,2.89
# alpha,beta: 14.56 ,3.17
# alpha,beta: 29.34 ,9.94
# alpha,beta: 8.23 ,4.13
# alpha,beta: 18.78 ,11.11
# alpha,beta: 2.53 ,3.76
# alpha,beta: 30.56 ,6.02
# alpha,beta: 25.13 ,18.19
# alpha,beta: 18.06 ,9.83
# alpha,beta: 11.74 ,3.82
# alpha,beta: 5.68 ,3.01
# alpha,beta: 42.06 ,10.96
# alpha,beta: 28.70 ,7.52
# alpha,beta: 3.46 ,3.33
# alpha,beta: 33.47 ,20.50
# alpha,beta: 10.19 ,3.93
# alpha,beta: 3.49 ,2.12
# alpha,beta: 14.16 ,13.04
# alpha,beta: 87.95 ,22.52
# alpha,beta: 36.15 ,7.73
# alpha,beta: 26.02 ,4.86
# alpha,beta: 27.14 ,12.51
# alpha,beta: 5.76 ,7.76
# alpha,beta: 15.75 ,7.15
# alpha,beta: 11.29 ,13.68
# alpha,beta: 5.55 ,1.97
# alpha,beta: 11.11 ,6.83
# alpha,beta: 88.71 ,10.14
# alpha,beta: 19.76 ,5.57
# alpha,beta: 12.00 ,4.39
# alpha,beta: 12.68 ,14.88
# alpha,beta: 8.56 ,5.55
# alpha,beta: 21.87 ,12.33
# alpha,beta: 7.64 ,2.28
# alpha,beta: 11.16 ,6.56
# alpha,beta: 14.12 ,2.66
# alpha,beta: 17.23 ,7.84
# alpha,beta: 9.62 ,4.41
# alpha,beta: 64.82 ,18.26
# alpha,beta: 48.70 ,10.43
# alpha,beta: 18.19 ,8.89
# alpha,beta: 14.91 ,5.69
# alpha,beta: 64.41 ,11.26
# alpha,beta: 5.56 ,2.05
# alpha,beta: 6.76 ,5.65
# alpha,beta: 5.82 ,1.83
# alpha,beta: 2.47 ,4.52
# alpha,beta: 56.68 ,7.88
# alpha,beta: 39.19 ,7.73
# alpha,beta: 1.14 ,3.52
# alpha,beta: 57.75 ,17.67
# alpha,beta: 36.91 ,18.28
# alpha,beta: 37.27 ,6.85
# alpha,beta: 7.59 ,8.63
# alpha,beta: 17.19 ,13.76
# alpha,beta: 41.35 ,17.63
# alpha,beta: 21.65 ,5.64
# alpha,beta: 7.00 ,4.63
# alpha,beta: 23.73 ,5.81
# alpha,beta: 12.01 ,6.92
# alpha,beta: 0.19 ,3.38
# alpha,beta: 43.56 ,10.34
# alpha,beta: 35.33 ,11.64
# alpha,beta: 3.59 ,3.55
# alpha,beta: 28.02 ,32.39
# alpha,beta: 12.13 ,3.63
# alpha,beta: 4.45 ,4.00
# alpha,beta: 8.83 ,13.55
# alpha,beta: 10.80 ,6.29
# alpha,beta: 21.34 ,12.33
# alpha,beta: 25.96 ,10.97
# alpha,beta: 23.45 ,10.40
# alpha,beta: 20.54 ,9.13
# alpha,beta: 47.65 ,12.94
# alpha,beta: 17.21 ,4.91
# alpha,beta: 8.49 ,4.62
# alpha,beta: 9.16 ,3.99
# alpha,beta: 5.68 ,3.58
# alpha,beta: 4.42 ,6.49
# alpha,beta: 14.64 ,11.52
# alpha,beta: 7.87 ,3.31
# alpha,beta: 12.03 ,5.96
# alpha,beta: 13.67 ,4.77
# alpha,beta: 22.19 ,7.40
# alpha,beta: 12.78 ,8.32
# alpha,beta: 15.88 ,5.86
# alpha,beta: 14.69 ,6.66
# alpha,beta: 12.72 ,7.71
# alpha,beta: 19.55 ,7.97
# alpha,beta: 37.00 ,10.85
# alpha,beta: 16.21 ,3.44
# alpha,beta: 35.09 ,18.34
# alpha,beta: 6.21 ,3.22
# alpha,beta: 8.60 ,5.94
# alpha,beta: 2.28 ,2.35
# alpha,beta: 44.61 ,16.10
# alpha,beta: 46.33 ,18.56
# alpha,beta: 37.01 ,14.81
# alpha,beta: 11.68 ,3.94
# alpha,beta: 27.53 ,11.67
# alpha,beta: 4.89 ,3.28
# alpha,beta: 25.41 ,17.97
# alpha,beta: 22.02 ,7.95
# alpha,beta: 31.25 ,12.27
# alpha,beta: 17.87 ,8.17
# alpha,beta: 23.90 ,7.32
# alpha,beta: 2.30 ,5.12
# alpha,beta: 32.64 ,19.13
# alpha,beta: 9.96 ,10.52
# alpha,beta: 43.94 ,12.24
# alpha,beta: 13.59 ,7.84
# alpha,beta: 37.04 ,18.47
# alpha,beta: 47.68 ,10.27
# alpha,beta: 5.26 ,4.16
# alpha,beta: 10.70 ,3.92
# alpha,beta: 7.69 ,2.70
# alpha,beta: 3.42 ,3.22
# alpha,beta: 7.86 ,5.44
# alpha,beta: 7.34 ,6.45
# alpha,beta: 28.30 ,4.67
# alpha,beta: 21.85 ,7.82
# alpha,beta: 35.48 ,10.33
# alpha,beta: 4.33 ,2.97
# alpha,beta: 6.27 ,5.44
# alpha,beta: 21.61 ,7.38
# alpha,beta: 13.39 ,2.83
# alpha,beta: 8.15 ,4.44
# alpha,beta: 71.41 ,8.96
# alpha,beta: 36.37 ,8.87
# alpha,beta: 19.32 ,7.51
# alpha,beta: 15.08 ,8.29
# alpha,beta: 16.27 ,4.32
# alpha,beta: 13.50 ,5.81
# alpha,beta: 28.46 ,9.33
# alpha,beta: 4.75 ,4.82
# alpha,beta: 16.66 ,5.83
# alpha,beta: 2.01 ,7.08
# alpha,beta: 21.44 ,4.60
# alpha,beta: 11.25 ,7.20
# alpha,beta: 33.91 ,8.31
# alpha,beta: 1.14 ,4.31
# alpha,beta: 37.00 ,21.72
# alpha,beta: 5.65 ,5.01
# alpha,beta: 4.63 ,4.53
# alpha,beta: 18.83 ,16.83
# alpha,beta: 27.19 ,9.75
# alpha,beta: 25.59 ,7.37
# alpha,beta: 12.63 ,3.96
# alpha,beta: -1.39 ,4.92
# alpha,beta: 10.69 ,5.46
# alpha,beta: 9.02 ,6.77
# alpha,beta: 15.04 ,10.43
# alpha,beta: 13.46 ,4.31
# alpha,beta: 29.41 ,5.03
# alpha,beta: 5.03 ,5.79
# alpha,beta: 38.75 ,11.66
# alpha,beta: 3.06 ,4.85
# alpha,beta: 9.71 ,9.00
# alpha,beta: 19.20 ,6.51
# alpha,beta: 9.80 ,4.33
# alpha,beta: 11.52 ,6.12
# alpha,beta: 4.18 ,3.39
# alpha,beta: 28.30 ,10.81
# alpha,beta: 52.97 ,8.96
# alpha,beta: 12.97 ,4.12
# alpha,beta: 64.92 ,18.51
# alpha,beta: 27.29 ,7.04
# alpha,beta: 22.15 ,9.16
# alpha,beta: 48.78 ,24.57
# alpha,beta: 48.37 ,11.23
# alpha,beta: 37.19 ,8.56
# alpha,beta: 20.40 ,6.58
# alpha,beta: 8.27 ,7.19
# alpha,beta: 18.75 ,6.61
# alpha,beta: 6.96 ,4.96
# alpha,beta: 4.74 ,3.67
# alpha,beta: 30.68 ,18.69
# alpha,beta: 6.58 ,2.45
# alpha,beta: 14.36 ,5.88
# alpha,beta: 9.14 ,9.41
# alpha,beta: 26.70 ,12.93
# alpha,beta: 1.55 ,6.99
# alpha,beta: 47.54 ,19.15
# alpha,beta: 12.31 ,5.28
# alpha,beta: 6.39 ,5.46
# alpha,beta: 15.76 ,8.26
# alpha,beta: 38.36 ,6.38
# alpha,beta: 2.47 ,3.30
# alpha,beta: 7.22 ,6.63
# alpha,beta: 19.09 ,5.25
# alpha,beta: 13.63 ,8.72
# alpha,beta: 6.54 ,8.98
# alpha,beta: 17.98 ,19.80
# alpha,beta: 8.87 ,5.82
# alpha,beta: 19.69 ,32.34
# alpha,beta: 17.81 ,6.49
# alpha,beta: 26.41 ,13.46
# alpha,beta: 10.80 ,6.02
# alpha,beta: 3.71 ,5.17
# alpha,beta: 4.67 ,4.05
# alpha,beta: 6.36 ,4.22
# alpha,beta: 28.58 ,5.52
# alpha,beta: 10.14 ,5.13
# alpha,beta: 7.25 ,4.88
# alpha,beta: 62.82 ,14.49
# alpha,beta: 5.03 ,8.17
# alpha,beta: 44.40 ,13.18
# alpha,beta: 7.40 ,3.77
# alpha,beta: 18.90 ,6.61
# alpha,beta: 6.63 ,8.87
# alpha,beta: 12.50 ,6.41
# alpha,beta: 20.03 ,7.51
# alpha,beta: 14.02 ,3.43
# alpha,beta: 32.72 ,8.12
# alpha,beta: 88.45 ,9.60
# alpha,beta: 42.47 ,8.48
# alpha,beta: 34.16 ,9.50
# alpha,beta: 11.72 ,10.51
# alpha,beta: 19.68 ,9.02
# alpha,beta: 15.44 ,9.10
# alpha,beta: 22.17 ,9.80
# alpha,beta: 53.43 ,5.48
# alpha,beta: 4.08 ,2.62
# alpha,beta: 5.96 ,3.72
# alpha,beta: 56.19 ,13.89
# alpha,beta: 10.46 ,5.41
# alpha,beta: 46.65 ,11.29
# alpha,beta: 7.42 ,4.99
# alpha,beta: 22.51 ,10.86
# alpha,beta: 0.78 ,3.60
# alpha,beta: 12.43 ,5.12
# alpha,beta: 11.78 ,4.59
# alpha,beta: 25.00 ,11.44
# alpha,beta: 11.48 ,5.01
# alpha,beta: 28.81 ,12.29
# alpha,beta: 7.02 ,6.78
# alpha,beta: 18.75 ,11.65
# alpha,beta: 147.00 ,12.76
# alpha,beta: 28.29 ,11.89
# alpha,beta: 16.68 ,7.92
# alpha,beta: 9.39 ,4.09
# alpha,beta: 17.93 ,8.11
# alpha,beta: 8.43 ,3.70
# alpha,beta: 12.41 ,4.78
# alpha,beta: 13.39 ,4.50
# alpha,beta: 35.39 ,5.83
# alpha,beta: 25.56 ,15.45
# alpha,beta: 21.81 ,11.90
# alpha,beta: 48.30 ,21.57
# alpha,beta: 10.87 ,7.18
# alpha,beta: 18.65 ,19.48
# alpha,beta: 21.54 ,8.18
# alpha,beta: 14.77 ,12.41
# alpha,beta: 6.46 ,6.28
# alpha,beta: 11.09 ,3.57
# alpha,beta: 14.61 ,6.00
# alpha,beta: 13.77 ,8.43
# alpha,beta: 7.66 ,4.70
# alpha,beta: 13.43 ,2.44
# alpha,beta: 48.36 ,16.42
# alpha,beta: 8.83 ,5.82
# alpha,beta: 8.34 ,3.17
# alpha,beta: 41.31 ,11.21
# alpha,beta: 14.33 ,14.27
# alpha,beta: 43.47 ,7.84
# alpha,beta: 81.86 ,21.19
# alpha,beta: 58.56 ,29.78
# alpha,beta: 20.17 ,4.89
# alpha,beta: 75.75 ,8.29
# alpha,beta: 52.86 ,16.81
# alpha,beta: 26.18 ,18.65
# alpha,beta: 13.81 ,7.61
# alpha,beta: 8.25 ,4.10
# alpha,beta: 65.42 ,21.67
# alpha,beta: 9.41 ,4.87
# alpha,beta: 10.67 ,5.52
# alpha,beta: 4.29 ,5.97
# alpha,beta: 8.24 ,5.42
# alpha,beta: 10.29 ,5.95
# alpha,beta: 1.22 ,10.41
# alpha,beta: 1.78 ,4.89
# alpha,beta: 13.87 ,4.39
# alpha,beta: 32.75 ,5.55
# alpha,beta: 8.08 ,5.55
# alpha,beta: 32.49 ,20.46
# alpha,beta: 19.85 ,15.67
# alpha,beta: 59.92 ,27.95
# alpha,beta: 13.25 ,15.77
# alpha,beta: 21.72 ,6.92
# alpha,beta: 29.12 ,18.62
# alpha,beta: 3.53 ,5.01
# alpha,beta: 1.50 ,10.69
# alpha,beta: 58.87 ,20.49
# alpha,beta: 2.70 ,4.96
# alpha,beta: 111.76 ,16.75
# alpha,beta: 11.73 ,6.29
# alpha,beta: 13.40 ,5.33
# alpha,beta: 25.86 ,6.76
# alpha,beta: 46.74 ,8.33
# alpha,beta: 8.74 ,6.27
# alpha,beta: 50.10 ,13.58
# alpha,beta: 9.01 ,4.04
# alpha,beta: 7.42 ,7.74
# alpha,beta: 43.80 ,9.76
# alpha,beta: 5.73 ,6.52
# alpha,beta: 49.24 ,22.74
# alpha,beta: 12.50 ,3.95
# alpha,beta: 25.22 ,9.97
# alpha,beta: 6.90 ,7.06
# alpha,beta: 55.61 ,10.84
# alpha,beta: 30.22 ,9.32
# alpha,beta: 18.42 ,12.38
# alpha,beta: 53.01 ,13.05
# alpha,beta: 16.51 ,6.13
# alpha,beta: 10.16 ,8.83
# alpha,beta: 28.58 ,8.36
# alpha,beta: 0.39 ,3.68
# alpha,beta: 17.92 ,25.16
# alpha,beta: 11.64 ,3.95
# alpha,beta: 6.13 ,2.04
# alpha,beta: 14.08 ,23.49
# alpha,beta: 65.71 ,16.25
# alpha,beta: 19.30 ,11.22
# alpha,beta: 7.46 ,4.13
# alpha,beta: 5.35 ,2.84
# alpha,beta: 110.18 ,31.59
# alpha,beta: 2.42 ,2.61
# alpha,beta: 17.91 ,18.27
# alpha,beta: 32.08 ,13.85
# alpha,beta: 33.12 ,9.55
# alpha,beta: 4.42 ,2.11
# alpha,beta: 58.97 ,14.55
# alpha,beta: 114.44 ,36.83
# alpha,beta: 12.29 ,9.49
# alpha,beta: 24.44 ,24.04
# alpha,beta: 86.44 ,26.13
# alpha,beta: 23.15 ,9.42
# alpha,beta: 32.30 ,7.96
# alpha,beta: 6.32 ,3.85
# alpha,beta: 19.49 ,14.00
# alpha,beta: 63.06 ,9.39
# alpha,beta: 10.06 ,3.88
# alpha,beta: 9.81 ,2.97
# alpha,beta: 47.63 ,13.64
# alpha,beta: 13.45 ,5.50
# alpha,beta: 1.59 ,2.99
# alpha,beta: 16.86 ,12.02
# alpha,beta: 5.60 ,6.89
# alpha,beta: 35.04 ,10.26
# alpha,beta: 17.17 ,15.70
# alpha,beta: 15.48 ,11.04
# alpha,beta: 6.62 ,3.52
# alpha,beta: 20.52 ,11.61
# alpha,beta: 21.28 ,6.99
# alpha,beta: 11.48 ,4.00
# alpha,beta: 40.41 ,9.32
# alpha,beta: 25.71 ,10.81
# alpha,beta: 5.78 ,4.75
# alpha,beta: 8.97 ,6.31
# alpha,beta: 3.74 ,2.84
# alpha,beta: 29.99 ,21.41
# alpha,beta: 51.39 ,11.74
# alpha,beta: 23.89 ,13.47
# alpha,beta: 17.23 ,17.37
# alpha,beta: 12.58 ,4.91
# alpha,beta: 8.95 ,2.57
# alpha,beta: 22.72 ,9.73
# alpha,beta: 7.18 ,6.64
# alpha,beta: 68.56 ,40.46
# alpha,beta: 43.40 ,10.91
# alpha,beta: 14.78 ,5.24
# alpha,beta: 20.13 ,15.06
# alpha,beta: 12.79 ,6.96
# alpha,beta: 21.60 ,5.82
# alpha,beta: 21.74 ,11.20
# alpha,beta: 9.62 ,3.83
# alpha,beta: 39.40 ,8.01
# alpha,beta: 7.38 ,6.93
# alpha,beta: 24.77 ,10.03
# alpha,beta: 17.89 ,5.02
# alpha,beta: 72.15 ,14.74
# alpha,beta: 18.83 ,12.47
# alpha,beta: 12.36 ,10.64
# alpha,beta: 45.01 ,18.34
# alpha,beta: 19.71 ,9.22
# alpha,beta: 5.92 ,4.27
# alpha,beta: 8.90 ,3.27
# alpha,beta: 40.45 ,11.87
# alpha,beta: 39.54 ,10.59
# alpha,beta: 55.08 ,9.38
# alpha,beta: 17.88 ,10.12
# alpha,beta: 8.00 ,3.62
# alpha,beta: 8.64 ,6.75
# alpha,beta: 109.70 ,25.62
# alpha,beta: 0.19 ,3.68
# alpha,beta: 5.26 ,3.69
# alpha,beta: 22.16 ,6.34
# alpha,beta: 18.89 ,6.57
# alpha,beta: 13.41 ,2.88
# alpha,beta: 61.23 ,9.86
# alpha,beta: 41.14 ,7.35
# alpha,beta: 16.38 ,10.70
# alpha,beta: 50.04 ,21.59
# alpha,beta: 6.93 ,6.04
# alpha,beta: 3.25 ,3.03
# alpha,beta: 25.23 ,11.80
# alpha,beta: 2.92 ,3.15
# alpha,beta: 1.77 ,3.22
# alpha,beta: 8.61 ,9.86
# alpha,beta: 8.39 ,4.43
# alpha,beta: 59.43 ,17.95
# alpha,beta: 68.67 ,12.91
# alpha,beta: 13.64 ,5.71
# alpha,beta: 14.19 ,6.49
# alpha,beta: 4.03 ,3.26
# alpha,beta: 8.34 ,6.69
# alpha,beta: 11.92 ,3.99
# alpha,beta: 11.86 ,7.53
# alpha,beta: 10.20 ,2.65
# alpha,beta: 10.31 ,4.28
# alpha,beta: 22.75 ,11.82
# alpha,beta: 7.20 ,8.01
# alpha,beta: 15.85 ,6.16
# alpha,beta: 19.26 ,7.97
# alpha,beta: 27.70 ,11.28
# alpha,beta: 24.36 ,13.32
# alpha,beta: 11.68 ,4.34
# alpha,beta: 13.98 ,3.92
# alpha,beta: 25.09 ,6.15
# alpha,beta: 10.98 ,6.51
# alpha,beta: 19.66 ,7.13
# alpha,beta: 31.11 ,24.67
# alpha,beta: 53.34 ,9.42
# alpha,beta: 7.59 ,7.35
# alpha,beta: 46.07 ,12.72
# alpha,beta: 10.64 ,10.49
# alpha,beta: 4.36 ,4.39
# alpha,beta: 17.68 ,10.94
# alpha,beta: 16.36 ,5.36
# alpha,beta: 18.58 ,12.09
# alpha,beta: 14.84 ,7.92
# alpha,beta: 7.18 ,3.72
# alpha,beta: 2.50 ,3.19
# alpha,beta: 6.58 ,3.62
# alpha,beta: 15.22 ,8.26
# alpha,beta: 5.43 ,3.84
# alpha,beta: 49.39 ,8.90
# alpha,beta: 6.06 ,7.54
# alpha,beta: 21.04 ,4.66
# alpha,beta: 12.20 ,5.21
# alpha,beta: 18.24 ,7.96
# alpha,beta: 3.43 ,2.93
# alpha,beta: 44.46 ,12.18
# alpha,beta: 4.90 ,12.90
# alpha,beta: 87.32 ,10.64
# alpha,beta: 11.37 ,7.87
# alpha,beta: 19.52 ,6.82
# alpha,beta: 14.87 ,9.14
# alpha,beta: 27.12 ,12.52
# alpha,beta: 7.30 ,5.82
# alpha,beta: 4.90 ,5.01
# alpha,beta: 38.74 ,17.03
# alpha,beta: 3.16 ,3.47
# alpha,beta: 38.86 ,11.59
# alpha,beta: 12.14 ,7.06
# alpha,beta: 5.11 ,4.08
# alpha,beta: 12.58 ,5.74
# alpha,beta: 43.23 ,9.54
# alpha,beta: 1.31 ,3.21
# alpha,beta: 16.28 ,17.70
# alpha,beta: 32.63 ,8.36
# alpha,beta: 56.73 ,17.73
# alpha,beta: 31.56 ,17.25
# alpha,beta: 10.63 ,6.98
# alpha,beta: 53.82 ,19.39
# alpha,beta: 30.36 ,12.03
# alpha,beta: 2.97 ,4.68
# alpha,beta: 24.48 ,8.02
# alpha,beta: 79.74 ,13.10
# alpha,beta: 52.14 ,17.69
# alpha,beta: 5.45 ,3.18
# alpha,beta: 42.35 ,8.23
# alpha,beta: 24.94 ,13.29
# alpha,beta: 5.49 ,5.89
# alpha,beta: 4.92 ,4.44
# alpha,beta: 38.83 ,28.09
# alpha,beta: 10.97 ,4.74
# alpha,beta: 4.73 ,5.57
# alpha,beta: 1.84 ,4.79
# alpha,beta: 12.73 ,4.76
# alpha,beta: 4.40 ,4.35
# alpha,beta: 18.97 ,9.24
# alpha,beta: 4.93 ,3.01
# alpha,beta: 4.84 ,4.18
# alpha,beta: 8.90 ,4.73
# alpha,beta: 25.19 ,9.11
# alpha,beta: 20.47 ,5.22
# alpha,beta: 2.61 ,8.52
# alpha,beta: 13.04 ,8.73
# alpha,beta: 56.01 ,19.32
# alpha,beta: 60.94 ,16.82
# alpha,beta: 24.10 ,18.79
# alpha,beta: 10.25 ,6.17
# alpha,beta: 45.64 ,25.49
# alpha,beta: 50.05 ,10.10
# alpha,beta: 49.11 ,22.50
# alpha,beta: 2.08 ,3.33
# alpha,beta: 37.61 ,10.01
# alpha,beta: 8.43 ,6.79
# alpha,beta: 11.28 ,5.35
# alpha,beta: 8.66 ,9.08
# alpha,beta: 10.40 ,4.63
# alpha,beta: 9.59 ,4.37
# alpha,beta: 9.09 ,4.13
# alpha,beta: 17.31 ,15.35
# alpha,beta: 48.59 ,15.65
# alpha,beta: 7.60 ,4.16
# alpha,beta: 19.23 ,8.95
# alpha,beta: 25.49 ,13.64
# alpha,beta: 6.73 ,3.15
# alpha,beta: 97.93 ,22.07
# alpha,beta: 67.32 ,15.49
# alpha,beta: 4.44 ,3.94
# alpha,beta: 14.68 ,11.92
# alpha,beta: 21.46 ,6.61
# alpha,beta: 36.68 ,12.72
# alpha,beta: 2.57 ,3.61
# alpha,beta: 48.19 ,11.80
# alpha,beta: 21.70 ,6.47
# alpha,beta: 10.04 ,5.23
# alpha,beta: 30.34 ,9.81
# alpha,beta: 21.85 ,8.15
# alpha,beta: 44.72 ,28.78
# alpha,beta: 37.70 ,14.02
# alpha,beta: 8.09 ,6.63
# alpha,beta: 7.97 ,5.28
# alpha,beta: 41.83 ,16.00
# alpha,beta: 3.47 ,3.11
# alpha,beta: 17.66 ,6.37
# alpha,beta: 18.21 ,10.56
# alpha,beta: 14.13 ,5.16
# alpha,beta: 14.28 ,7.89
# alpha,beta: 5.92 ,2.61
# alpha,beta: 29.80 ,6.81
# alpha,beta: 28.04 ,11.90
# alpha,beta: 2.92 ,4.46
# alpha,beta: 5.35 ,4.90
# alpha,beta: 12.45 ,8.70
# alpha,beta: 8.98 ,7.25
# alpha,beta: 11.71 ,4.77
# alpha,beta: 6.47 ,8.06
# alpha,beta: 20.93 ,9.56
# alpha,beta: 14.17 ,10.86
# alpha,beta: 21.41 ,19.19
# alpha,beta: 12.73 ,11.12
# alpha,beta: 8.96 ,11.62
# alpha,beta: 16.38 ,9.86
# alpha,beta: 5.56 ,35.10
# alpha,beta: 8.81 ,3.12
# alpha,beta: 7.50 ,10.15
# alpha,beta: 9.71 ,5.20
# alpha,beta: 12.06 ,7.48
# alpha,beta: 26.18 ,8.02
# alpha,beta: 8.31 ,6.35
# alpha,beta: 22.06 ,15.20
# alpha,beta: 7.45 ,5.21
# alpha,beta: 17.37 ,23.59
# alpha,beta: 14.68 ,12.24
# alpha,beta: 39.63 ,12.37
# alpha,beta: 21.22 ,5.13
# alpha,beta: 5.24 ,5.79
# alpha,beta: 18.93 ,9.11
# alpha,beta: 7.46 ,4.67
# alpha,beta: 5.76 ,4.49
# alpha,beta: 101.29 ,14.93
# alpha,beta: 15.30 ,4.49
# alpha,beta: 20.64 ,7.47
# alpha,beta: 19.49 ,8.43
# alpha,beta: 8.14 ,3.18
# alpha,beta: 1.87 ,3.59
# alpha,beta: 6.09 ,5.10
# alpha,beta: 30.03 ,16.57
# alpha,beta: 9.95 ,4.53
# alpha,beta: 21.35 ,11.85
# alpha,beta: 4.02 ,5.25
# alpha,beta: 31.95 ,9.08
# alpha,beta: 7.67 ,5.34
# alpha,beta: 11.61 ,9.09
# alpha,beta: 15.35 ,13.97
# alpha,beta: 31.30 ,13.82
# alpha,beta: 9.73 ,3.72
# alpha,beta: 30.97 ,5.31
# alpha,beta: 47.83 ,18.57
# alpha,beta: 19.24 ,21.57
# alpha,beta: 29.37 ,7.29
# alpha,beta: 0.96 ,4.15
# alpha,beta: 17.58 ,8.68
# alpha,beta: 17.36 ,7.71
# alpha,beta: 18.83 ,7.57
# alpha,beta: 25.18 ,9.06
# alpha,beta: 8.57 ,7.39
# alpha,beta: 36.05 ,14.01
# alpha,beta: 10.36 ,7.31
# alpha,beta: 17.10 ,6.49
# alpha,beta: 6.44 ,11.45
# alpha,beta: 19.46 ,12.20
# alpha,beta: 36.96 ,8.35
# alpha,beta: 41.97 ,23.37
# alpha,beta: 34.64 ,11.34
# alpha,beta: 90.28 ,21.54
# alpha,beta: 44.93 ,19.64
# alpha,beta: 15.76 ,8.44
# alpha,beta: 35.08 ,16.00
# alpha,beta: 7.93 ,9.14
# alpha,beta: 4.91 ,9.38
# alpha,beta: 10.86 ,7.45
# alpha,beta: 9.34 ,7.62
# alpha,beta: 41.52 ,10.60
# alpha,beta: 54.02 ,19.89
# alpha,beta: 13.27 ,3.66
# alpha,beta: 37.63 ,8.27
# alpha,beta: 4.07 ,6.74
# alpha,beta: 22.15 ,8.91
# alpha,beta: 112.68 ,18.12
# alpha,beta: 11.96 ,9.19
# alpha,beta: 18.01 ,10.71
# alpha,beta: 15.86 ,6.21
# alpha,beta: 14.45 ,3.62
# alpha,beta: 41.91 ,12.44
# alpha,beta: 25.50 ,11.79
# alpha,beta: 94.69 ,24.79
# alpha,beta: 21.54 ,6.62
# alpha,beta: 8.31 ,3.66
# alpha,beta: 4.55 ,3.95
# alpha,beta: 8.68 ,4.61
# alpha,beta: 3.20 ,7.21
# alpha,beta: 3.39 ,3.91
# alpha,beta: 20.79 ,7.97
# alpha,beta: 3.17 ,3.32
# alpha,beta: 9.68 ,5.23
# alpha,beta: 32.99 ,9.97
# alpha,beta: 10.62 ,2.99
# alpha,beta: 77.64 ,26.82
# alpha,beta: 13.31 ,9.75
# alpha,beta: 57.45 ,11.57
# alpha,beta: 37.34 ,11.12
# alpha,beta: 7.71 ,6.85
# alpha,beta: 8.22 ,5.13
# alpha,beta: 6.16 ,11.85
# alpha,beta: 29.97 ,12.84
# alpha,beta: 29.63 ,7.75
# alpha,beta: 33.25 ,13.81
# alpha,beta: 25.14 ,14.11
# alpha,beta: 5.93 ,3.59
# alpha,beta: 16.57 ,7.48
# alpha,beta: 10.79 ,7.36
# alpha,beta: 12.02 ,6.41
# alpha,beta: 13.05 ,14.95
# alpha,beta: 38.68 ,7.92
# alpha,beta: 19.70 ,6.10
# alpha,beta: 31.66 ,8.49
# alpha,beta: 19.20 ,6.05
# alpha,beta: 28.97 ,19.98
# alpha,beta: 21.38 ,15.93
# alpha,beta: 15.24 ,8.93
# alpha,beta: 14.24 ,5.87
# alpha,beta: 18.06 ,7.37
# alpha,beta: -0.75 ,8.02
# alpha,beta: 17.01 ,6.06
# alpha,beta: 8.14 ,10.52
# alpha,beta: 9.25 ,9.87
# alpha,beta: 5.66 ,4.78
# alpha,beta: 48.99 ,11.12
# alpha,beta: 106.78 ,35.73
# alpha,beta: 23.59 ,15.07
# alpha,beta: 9.82 ,6.82
# alpha,beta: 60.12 ,19.07
# alpha,beta: 9.25 ,4.14
# alpha,beta: 21.86 ,7.30
# alpha,beta: 19.11 ,10.86
# alpha,beta: 52.12 ,22.92
# alpha,beta: 36.17 ,15.46
# alpha,beta: 6.99 ,6.95
# alpha,beta: 16.38 ,12.91
# alpha,beta: 66.18 ,20.27
# alpha,beta: 23.33 ,7.12
# alpha,beta: 26.61 ,6.89
# alpha,beta: 14.59 ,6.45
# alpha,beta: 25.63 ,8.61
# alpha,beta: 39.43 ,13.34
# alpha,beta: 5.22 ,2.99
# alpha,beta: 23.66 ,7.80
# alpha,beta: 12.33 ,11.87
# alpha,beta: 13.99 ,5.58
# alpha,beta: 7.25 ,3.99
# alpha,beta: 40.99 ,17.21
# alpha,beta: 136.16 ,15.12
# alpha,beta: 9.94 ,9.70
# alpha,beta: 14.37 ,6.15
# alpha,beta: 72.48 ,14.42
# alpha,beta: 13.48 ,12.94
# alpha,beta: 7.87 ,8.30
# alpha,beta: 43.28 ,8.69
# alpha,beta: 7.45 ,5.72
# alpha,beta: 19.42 ,18.63
# alpha,beta: 31.80 ,9.45
# alpha,beta: 15.20 ,6.69
# alpha,beta: 16.31 ,8.14
# alpha,beta: 11.09 ,4.54
# alpha,beta: 7.35 ,4.53
# alpha,beta: 2.52 ,4.36
# alpha,beta: 30.27 ,15.71
# alpha,beta: 11.27 ,8.33
# alpha,beta: 31.79 ,9.56
# alpha,beta: 23.74 ,12.81
# alpha,beta: 36.28 ,16.93
# alpha,beta: 20.59 ,6.96
# alpha,beta: 71.59 ,19.66
# alpha,beta: 13.06 ,11.00
# alpha,beta: 4.31 ,3.83
# alpha,beta: 53.46 ,14.17
# alpha,beta: 2.00 ,5.45
# alpha,beta: 62.69 ,11.19
# alpha,beta: 11.43 ,27.33
# alpha,beta: 8.39 ,5.34
# alpha,beta: 13.37 ,10.63
# alpha,beta: 15.83 ,6.05
# alpha,beta: 36.41 ,12.61
# alpha,beta: 52.66 ,19.68
# alpha,beta: 1.81 ,5.78
# alpha,beta: 34.03 ,19.18
# alpha,beta: 8.75 ,16.95
# alpha,beta: 32.37 ,19.11
# alpha,beta: 34.93 ,10.88
# alpha,beta: 57.46 ,22.36
# alpha,beta: 26.12 ,24.64
# alpha,beta: 22.95 ,8.43
# alpha,beta: 9.23 ,7.26
# alpha,beta: 20.78 ,7.12
# alpha,beta: 69.69 ,13.89
# alpha,beta: 2.51 ,4.07
# alpha,beta: 34.11 ,10.18
# alpha,beta: 18.05 ,6.80
# alpha,beta: 10.90 ,4.02
# alpha,beta: 1.33 ,3.84
# alpha,beta: 27.17 ,7.72
# alpha,beta: 60.43 ,17.19
# alpha,beta: 2.53 ,3.15
# alpha,beta: 18.50 ,6.48
# alpha,beta: 17.07 ,6.19
# alpha,beta: 25.80 ,13.38
# alpha,beta: 1.95 ,4.23
# alpha,beta: 24.64 ,8.06
# alpha,beta: 15.95 ,7.08
# alpha,beta: 24.50 ,15.15
# alpha,beta: 7.69 ,3.36
# alpha,beta: 40.90 ,8.72
# alpha,beta: 18.87 ,7.92
# alpha,beta: 69.88 ,11.21
# alpha,beta: 18.10 ,7.20
# alpha,beta: 4.55 ,3.53
# alpha,beta: 10.91 ,6.19
# alpha,beta: 6.27 ,11.98
# alpha,beta: 19.54 ,15.59
# alpha,beta: 67.86 ,23.51
# alpha,beta: 4.04 ,3.69
# alpha,beta: 16.51 ,12.14
# alpha,beta: 52.03 ,17.04
# alpha,beta: 17.26 ,9.20
# alpha,beta: 1.06 ,8.37
# alpha,beta: 8.13 ,5.13
# alpha,beta: 13.04 ,13.66
# alpha,beta: 23.21 ,11.69
# alpha,beta: 9.76 ,6.60
# alpha,beta: 21.39 ,23.49
# alpha,beta: 14.21 ,6.28
# alpha,beta: 30.58 ,23.08
# alpha,beta: 2.73 ,4.37
# alpha,beta: 0.22 ,6.41
# alpha,beta: 15.60 ,10.25
# alpha,beta: 30.06 ,14.65
# alpha,beta: 13.85 ,8.11
# alpha,beta: 15.02 ,4.20
# alpha,beta: 14.99 ,7.91
# alpha,beta: 25.77 ,7.00
# alpha,beta: 50.64 ,22.58
# alpha,beta: 12.34 ,8.79
# alpha,beta: 10.65 ,4.34
# alpha,beta: 9.65 ,12.14
# alpha,beta: 3.84 ,4.78
# alpha,beta: 95.34 ,19.08
# alpha,beta: 30.72 ,12.88
# alpha,beta: -2.22 ,4.22
# alpha,beta: 11.89 ,7.89
# alpha,beta: 8.10 ,7.79
# alpha,beta: 21.78 ,16.65
# alpha,beta: 12.78 ,8.72
# alpha,beta: 13.04 ,11.26
# alpha,beta: 1.16 ,6.17
# alpha,beta: 4.33 ,4.55
# alpha,beta: 8.80 ,6.03
# alpha,beta: 17.39 ,8.36
# alpha,beta: 4.84 ,5.58
# alpha,beta: 21.88 ,10.03
# alpha,beta: 10.24 ,6.56
# alpha,beta: 7.76 ,7.89
# alpha,beta: 11.69 ,7.04
# alpha,beta: 50.92 ,8.69
# alpha,beta: 9.85 ,12.12
# alpha,beta: 12.12 ,3.83
# alpha,beta: 5.48 ,2.81
# alpha,beta: 28.28 ,18.67
# alpha,beta: 25.44 ,17.50
# alpha,beta: 38.88 ,11.19
# alpha,beta: 22.52 ,9.36
# alpha,beta: 14.52 ,11.51
# alpha,beta: 2.99 ,4.34
# alpha,beta: 49.65 ,19.30
# alpha,beta: 18.37 ,6.46
# alpha,beta: 13.16 ,8.24
# alpha,beta: 16.03 ,8.02
# alpha,beta: 10.63 ,7.04
# alpha,beta: 6.60 ,4.78
# alpha,beta: 18.51 ,11.39
# alpha,beta: 39.82 ,23.11
# alpha,beta: 32.15 ,7.99
# alpha,beta: 34.46 ,18.32
# alpha,beta: 8.51 ,8.34
# alpha,beta: 22.16 ,8.79
# alpha,beta: 19.33 ,13.11
# alpha,beta: 43.74 ,19.46
# alpha,beta: 51.20 ,20.79
# alpha,beta: 71.93 ,17.38
# alpha,beta: 15.54 ,8.10
# alpha,beta: 6.38 ,5.52
# alpha,beta: 3.40 ,5.29
# alpha,beta: 12.83 ,15.68
# alpha,beta: 51.29 ,10.67
# alpha,beta: 24.81 ,10.46
# alpha,beta: 10.48 ,8.51
# alpha,beta: 10.05 ,4.84
# alpha,beta: 53.06 ,15.82
# alpha,beta: 16.26 ,6.12
# alpha,beta: 30.48 ,14.46
# alpha,beta: 87.88 ,11.06
# alpha,beta: 25.53 ,9.10
# alpha,beta: 16.26 ,14.13
# alpha,beta: 25.15 ,9.64
# alpha,beta: 6.85 ,10.12
# alpha,beta: 19.98 ,11.38
# alpha,beta: 19.36 ,10.74
# alpha,beta: 5.63 ,4.86
# alpha,beta: 19.01 ,12.78
# alpha,beta: 7.56 ,3.45
# alpha,beta: 45.88 ,19.06
# alpha,beta: 9.79 ,5.59
# alpha,beta: 60.92 ,24.48
# alpha,beta: 34.82 ,13.52
# alpha,beta: 12.53 ,10.54
# alpha,beta: 5.69 ,4.56
# alpha,beta: 23.53 ,12.31
# alpha,beta: 27.09 ,15.72
# alpha,beta: 33.13 ,18.89
# alpha,beta: 17.82 ,8.01
# alpha,beta: 33.01 ,12.54
# alpha,beta: 8.16 ,4.69
# alpha,beta: 3.60 ,3.46
# alpha,beta: 52.49 ,17.53
# alpha,beta: 17.75 ,12.29
# alpha,beta: 12.47 ,4.77
# alpha,beta: 12.33 ,3.40
# alpha,beta: 49.84 ,17.23
# alpha,beta: 29.65 ,7.09
# alpha,beta: 23.44 ,22.87
# alpha,beta: 6.11 ,5.64
# alpha,beta: 17.78 ,6.05
# alpha,beta: 17.45 ,18.39
# alpha,beta: 18.63 ,10.19
# alpha,beta: 12.58 ,7.30
# alpha,beta: 47.56 ,14.35
# alpha,beta: 17.83 ,11.01
# alpha,beta: 3.69 ,12.46
# alpha,beta: 8.28 ,5.83
# alpha,beta: 31.27 ,24.07
# alpha,beta: 4.54 ,3.44
# alpha,beta: 29.75 ,12.25
# alpha,beta: 13.83 ,6.98
# alpha,beta: 16.60 ,19.54
# alpha,beta: 17.73 ,8.15
# alpha,beta: 11.74 ,22.29
# alpha,beta: 11.62 ,4.90
# alpha,beta: 34.83 ,9.09
# alpha,beta: 5.55 ,7.38
# alpha,beta: 35.66 ,18.75
# alpha,beta: 68.38 ,18.06
# alpha,beta: 36.83 ,24.20
# alpha,beta: 20.75 ,14.50
# alpha,beta: 32.61 ,22.40
# alpha,beta: 49.02 ,19.27
# alpha,beta: 23.21 ,15.58
# alpha,beta: 24.48 ,14.43
# alpha,beta: 10.36 ,7.84
# alpha,beta: 30.13 ,20.83
# alpha,beta: 20.61 ,7.92
# alpha,beta: 18.92 ,8.13
# alpha,beta: 33.14 ,13.50
# alpha,beta: 44.53 ,13.27
# alpha,beta: 130.07 ,30.73
# alpha,beta: 44.04 ,14.18
# alpha,beta: 8.16 ,4.37
# alpha,beta: 36.66 ,9.33
# alpha,beta: 37.19 ,14.24
# alpha,beta: 16.17 ,8.29
# alpha,beta: 16.60 ,4.97
# alpha,beta: 13.50 ,10.13
# alpha,beta: 8.63 ,5.21
# alpha,beta: 25.02 ,10.57
# alpha,beta: 8.57 ,8.37
# alpha,beta: 14.33 ,4.65
# alpha,beta: 24.87 ,8.60
# alpha,beta: 87.38 ,30.27
# alpha,beta: 37.02 ,14.73
# alpha,beta: 1.13 ,4.51
# alpha,beta: 14.62 ,5.42
# alpha,beta: 3.64 ,11.31
# alpha,beta: 15.67 ,8.08
# alpha,beta: 27.82 ,21.27
# alpha,beta: 15.10 ,10.62
# alpha,beta: 12.88 ,10.44
# alpha,beta: 52.82 ,17.46
# alpha,beta: 10.80 ,12.01
# alpha,beta: 22.94 ,11.70
# alpha,beta: 35.89 ,42.78
# alpha,beta: 84.22 ,20.01
# alpha,beta: 22.09 ,10.24
# alpha,beta: 28.79 ,22.36
# alpha,beta: 16.45 ,4.76
# alpha,beta: 22.36 ,16.51
# alpha,beta: 6.51 ,5.31
# alpha,beta: 8.07 ,12.98
# alpha,beta: 4.87 ,6.20
# alpha,beta: 47.73 ,14.40
# alpha,beta: 4.28 ,6.86
# alpha,beta: 24.37 ,12.62
# alpha,beta: 18.27 ,4.31
# alpha,beta: 70.04 ,12.37
# alpha,beta: 4.65 ,6.02
# alpha,beta: 41.96 ,16.48
# alpha,beta: 2.71 ,8.49
# alpha,beta: 89.21 ,26.25
# alpha,beta: 22.63 ,24.24
# alpha,beta: 17.07 ,7.74
# alpha,beta: 10.99 ,13.65
# alpha,beta: 14.97 ,11.22
# alpha,beta: 35.03 ,16.99
# alpha,beta: 27.92 ,31.02
# alpha,beta: 79.84 ,15.59
# alpha,beta: 20.52 ,9.22
# alpha,beta: 11.57 ,9.38
# alpha,beta: 9.01 ,5.25
# alpha,beta: 6.65 ,5.43
# alpha,beta: 42.63 ,15.14
# alpha,beta: 48.55 ,14.98
# alpha,beta: 10.50 ,5.03
# alpha,beta: 39.64 ,13.99
# alpha,beta: 12.76 ,12.83
# alpha,beta: 6.51 ,5.77
# alpha,beta: 11.12 ,7.90
# alpha,beta: 16.59 ,5.17
# alpha,beta: 6.45 ,4.91
# alpha,beta: 7.67 ,5.82
# alpha,beta: 14.54 ,7.62
# alpha,beta: 15.87 ,6.24
# alpha,beta: 5.91 ,5.29
# alpha,beta: 4.08 ,6.82
# alpha,beta: 22.12 ,32.68
# alpha,beta: 14.28 ,12.22
# alpha,beta: 25.32 ,11.38
# alpha,beta: 56.88 ,26.88
# alpha,beta: 4.35 ,6.44
# alpha,beta: 8.53 ,7.00
# alpha,beta: 5.93 ,5.61
# alpha,beta: 37.99 ,12.29
# alpha,beta: 18.59 ,10.37
# alpha,beta: 21.07 ,20.91
# alpha,beta: 10.44 ,9.89
# alpha,beta: 25.38 ,11.35
# alpha,beta: 6.64 ,8.48
# alpha,beta: 27.52 ,10.82
# alpha,beta: 71.29 ,25.57
# alpha,beta: 27.88 ,14.76
# alpha,beta: 20.93 ,14.95
# alpha,beta: 16.20 ,6.34
# alpha,beta: 33.89 ,19.33
# alpha,beta: 19.47 ,13.45
# alpha,beta: 53.46 ,14.07
# alpha,beta: 16.65 ,5.13
# alpha,beta: 55.78 ,16.57
# alpha,beta: 10.37 ,11.12
# alpha,beta: 10.64 ,8.46
# alpha,beta: 60.74 ,25.03
# alpha,beta: 4.06 ,15.80
# alpha,beta: 48.88 ,16.97
# alpha,beta: 14.04 ,10.90
# alpha,beta: 12.01 ,5.84
# alpha,beta: 10.31 ,6.12
# alpha,beta: 14.60 ,9.38
# alpha,beta: 6.71 ,4.22
# alpha,beta: 7.95 ,10.31
# alpha,beta: 20.19 ,12.14
# alpha,beta: 67.01 ,15.15
# alpha,beta: 32.04 ,8.88
# alpha,beta: 19.81 ,16.84
# alpha,beta: 3.74 ,6.36
# alpha,beta: 34.61 ,15.44
# alpha,beta: 49.47 ,13.53
# alpha,beta: 9.91 ,8.20
# alpha,beta: 18.46 ,9.67
# alpha,beta: 18.37 ,7.79
# alpha,beta: 41.94 ,21.36
# alpha,beta: 1.89 ,5.24
# alpha,beta: 25.24 ,9.04
# alpha,beta: 8.33 ,5.51
# alpha,beta: 19.12 ,11.43
# alpha,beta: 64.43 ,19.51
# alpha,beta: 21.97 ,17.17
# alpha,beta: 97.22 ,29.12
# alpha,beta: 17.01 ,7.59
# alpha,beta: 59.98 ,22.29
# alpha,beta: 37.27 ,17.43
# alpha,beta: 53.17 ,12.01
# alpha,beta: 19.90 ,6.05
# alpha,beta: 46.68 ,10.08
# alpha,beta: 16.67 ,10.10
# alpha,beta: 22.55 ,16.27
# alpha,beta: 17.53 ,10.36
# alpha,beta: 11.37 ,9.39
# alpha,beta: 49.39 ,17.51
# alpha,beta: 14.31 ,12.42
# alpha,beta: 7.03 ,6.35
# alpha,beta: 16.88 ,4.66
# alpha,beta: 54.59 ,27.88
# alpha,beta: 66.59 ,25.02
# alpha,beta: 22.94 ,6.73
# alpha,beta: 3.17 ,6.73
# alpha,beta: 33.08 ,12.78
# alpha,beta: 19.03 ,8.68
# alpha,beta: 16.16 ,6.03
# alpha,beta: 10.59 ,10.61
# alpha,beta: 21.30 ,11.31
# alpha,beta: 32.03 ,27.52
# alpha,beta: 7.69 ,7.68
# alpha,beta: 8.54 ,7.04
# alpha,beta: 30.01 ,8.19
# alpha,beta: 29.93 ,22.37
# alpha,beta: 41.98 ,19.15
# alpha,beta: 10.56 ,8.81
# alpha,beta: 6.22 ,2.86
# alpha,beta: 29.67 ,28.10
# alpha,beta: 11.22 ,11.17
# alpha,beta: 23.86 ,19.38
# alpha,beta: 8.43 ,13.50
# alpha,beta: 15.93 ,10.43
# alpha,beta: 37.01 ,23.79
# alpha,beta: 33.37 ,17.01
# alpha,beta: 40.14 ,13.64
# alpha,beta: 13.02 ,7.69
# alpha,beta: 7.29 ,14.94
# alpha,beta: 72.55 ,21.42
# alpha,beta: 12.69 ,8.06
# alpha,beta: 44.27 ,27.26
# alpha,beta: 24.93 ,7.58
# alpha,beta: 25.98 ,27.89
# alpha,beta: 15.57 ,7.07
# alpha,beta: 11.57 ,8.82
# alpha,beta: 49.12 ,13.33
# alpha,beta: 18.01 ,7.72
# alpha,beta: 14.46 ,8.31
# alpha,beta: 14.67 ,22.35
# alpha,beta: 15.17 ,8.96
# alpha,beta: 18.11 ,9.73
# alpha,beta: 53.00 ,32.50
# alpha,beta: 18.78 ,9.82
# alpha,beta: 5.64 ,5.84
# alpha,beta: 41.01 ,8.17
# alpha,beta: 42.26 ,18.41
# alpha,beta: 46.75 ,14.42
# alpha,beta: 45.24 ,13.31
# alpha,beta: 127.90 ,26.02
# alpha,beta: 34.20 ,28.37
# alpha,beta: 44.06 ,41.61
# alpha,beta: 19.62 ,19.53
# alpha,beta: 2.02 ,4.10
# alpha,beta: 21.42 ,15.46
# alpha,beta: 25.76 ,18.31
# alpha,beta: 25.98 ,18.49
# alpha,beta: 24.91 ,11.64
# alpha,beta: 5.96 ,5.14
# alpha,beta: 30.62 ,24.80
# alpha,beta: 46.41 ,16.69
# alpha,beta: 6.06 ,6.43
# alpha,beta: 11.96 ,16.50
# alpha,beta: 14.46 ,11.02
# alpha,beta: 6.34 ,8.94
# alpha,beta: 29.18 ,14.21
# alpha,beta: 32.51 ,15.54
# alpha,beta: 13.12 ,9.69
# alpha,beta: 1.97 ,7.50
# alpha,beta: 9.33 ,11.08
# alpha,beta: 8.89 ,8.95
# alpha,beta: 6.20 ,8.14
# alpha,beta: 15.53 ,11.49
# alpha,beta: 26.64 ,11.20
# alpha,beta: 28.68 ,14.55
# alpha,beta: 12.67 ,6.28
# alpha,beta: 8.94 ,7.52
# alpha,beta: 19.30 ,9.54
# alpha,beta: 14.29 ,8.16
# alpha,beta: 59.09 ,27.40
# alpha,beta: 44.39 ,15.74
# alpha,beta: 23.66 ,12.40
# alpha,beta: 23.21 ,17.51
# alpha,beta: 52.73 ,23.57
# alpha,beta: 25.96 ,15.92
# alpha,beta: 56.02 ,21.58
# alpha,beta: 28.16 ,15.92
# alpha,beta: 18.69 ,6.83
# alpha,beta: 27.30 ,13.71
# alpha,beta: 48.11 ,12.92
# alpha,beta: 11.66 ,13.61
# alpha,beta: 41.37 ,26.86
# alpha,beta: 27.27 ,19.17
# alpha,beta: 7.14 ,9.18
# alpha,beta: 5.26 ,6.09
# alpha,beta: 8.64 ,6.94
# alpha,beta: 9.30 ,8.14
# alpha,beta: 6.62 ,5.13
# alpha,beta: 10.97 ,11.15
# alpha,beta: 60.51 ,15.70
# alpha,beta: 35.42 ,21.00
# alpha,beta: 21.91 ,12.83
# alpha,beta: 21.05 ,17.20
# alpha,beta: 33.56 ,15.41
# alpha,beta: 5.56 ,6.40
# alpha,beta: 28.85 ,22.17
# alpha,beta: 67.29 ,25.85
# alpha,beta: 25.74 ,16.15
# alpha,beta: 16.17 ,10.69
# alpha,beta: 20.27 ,18.42
# alpha,beta: 45.00 ,13.04
# alpha,beta: 16.39 ,10.26
# alpha,beta: 46.22 ,16.23
# alpha,beta: 11.44 ,9.10
# alpha,beta: 53.26 ,19.84
# alpha,beta: 24.15 ,11.18
# alpha,beta: 32.08 ,12.59
# alpha,beta: 9.82 ,7.10
# alpha,beta: 20.10 ,10.76
# alpha,beta: 29.80 ,14.20
# alpha,beta: 23.46 ,23.03
# alpha,beta: 40.51 ,18.09
# alpha,beta: 6.34 ,10.09
# alpha,beta: 37.98 ,20.30
# alpha,beta: 12.10 ,8.89
# alpha,beta: 22.61 ,11.87
# alpha,beta: 14.78 ,13.18
# alpha,beta: 20.24 ,20.98
# alpha,beta: 24.29 ,12.90
# alpha,beta: 35.06 ,15.61
# alpha,beta: 48.55 ,21.59
# alpha,beta: 11.50 ,10.45
# alpha,beta: 17.80 ,8.45
# alpha,beta: 132.45 ,19.83
# alpha,beta: 9.74 ,8.25
# alpha,beta: 55.50 ,19.84
# alpha,beta: 15.31 ,14.98
# alpha,beta: 4.26 ,8.91
# alpha,beta: 39.13 ,21.74
# alpha,beta: 5.67 ,6.95
# alpha,beta: 25.36 ,13.09
# alpha,beta: 23.06 ,7.48
# alpha,beta: 36.27 ,14.67
# alpha,beta: 5.00 ,10.59
# alpha,beta: 17.62 ,9.52
# alpha,beta: 8.07 ,8.91
# alpha,beta: 60.10 ,16.10
# alpha,beta: 14.05 ,8.19
# alpha,beta: 8.40 ,6.98
# alpha,beta: 30.56 ,17.89
# alpha,beta: 7.77 ,8.34
# alpha,beta: 1.89 ,14.90
# alpha,beta: 2.39 ,6.46
# alpha,beta: 50.36 ,32.52
# alpha,beta: 30.10 ,24.39
# alpha,beta: 73.39 ,20.45
# alpha,beta: 9.69 ,6.02
# alpha,beta: 6.07 ,8.02
# alpha,beta: 50.76 ,24.40
# alpha,beta: 17.77 ,16.36
# alpha,beta: 26.14 ,12.29
# alpha,beta: 28.45 ,28.73
# alpha,beta: 16.60 ,8.34
# alpha,beta: 10.23 ,8.09
# alpha,beta: 26.51 ,13.26
# alpha,beta: 22.49 ,18.08
# alpha,beta: 22.88 ,20.81
# alpha,beta: 17.75 ,7.34
# alpha,beta: 3.63 ,10.71
# alpha,beta: 75.33 ,22.97
# alpha,beta: 12.14 ,15.04
# alpha,beta: 28.52 ,16.87
# alpha,beta: 3.59 ,9.29
# alpha,beta: 19.58 ,9.44
# alpha,beta: 13.35 ,9.19
# alpha,beta: 17.20 ,12.74
# alpha,beta: 6.37 ,8.97
# alpha,beta: 14.25 ,13.00
# alpha,beta: 63.95 ,28.26
# alpha,beta: 46.79 ,28.20
# alpha,beta: 47.89 ,31.00

# %%
ngals = np.array([cla[i].prob['Ngals']['flat'] for i in range(ncls)])
x = np.array([np.sum(cla[i].prob['Pmem']['flat']) for i in range(ncls)])/prior

# %%
# Loss function
def Prior(a,b):
    return a/(a+b)

def get_log(x):
    xlog = np.log10(x)
    xlog[np.isinf(xlog)] = -99
    xlog[np.isnan(xlog)] = -99
    return xlog

def get_frac_residual(x,y):
    res = y/(x+1e-6)
    log_res = get_log(res)
    return res,log_res

def compute_new_gals(x,f,Ncf,Nf):
    return Prior(Ncf-f*hat_Nf,f*hat_Nf)*x

def loss(f, x, hat_Nf, Ncf, p=2., vec=False):
    """Loss function
    x: (float) sum(Pmem)/prior0 
    hat_Nf:(float) number of estimated background galaxies
    Ncf: (float) total number of galaxies in the cluster area
    """
    ngals      = Ncf #- f*hat_Nf
    ngals_pred = Prior(ngals-f*hat_Nf,f*hat_Nf)*x+f*hat_Nf
    ngals_pred = np.where(ngals_pred<0.,1e-9,ngals_pred)
    
    sigma = 0.2*ngals
    #resid = (ngals-ngals_pred)/sigma
    
    resid = np.abs(get_frac_residual(ngals,ngals_pred))[1]
    if vec:
        return np.sum((resid/np.log10(sigma))**p)
    else:
        return resid**p

# def loss(hat_Nf, x, Ncf, p=2., vec=False):
#     """Loss function
#     x: (float) sum(Pmem)/prior0 
#     hat_Nf:(float) number of estimated background galaxies
#     Ncf: (float) total number of galaxies in the cluster area
#     """
#     ngals      = Ncf #- f*hat_Nf
#     #ngals = np.where(ngals<0.,1e-9,ngals)
#     ngals_pred = prior(ngals-hat_Nf,hat_Nf)*x+hat_Nf
#     ngals_pred = np.where(ngals_pred<0.,1e-9,ngals_pred)
#     #ngals_pred = ((ngals-f*hat_Nf)/ngals)*x+f*hat_Nf
#     #resid      = np.abs( (ngals_pred - ngals) )
#     resid      = np.abs(get_frac_residual(ngals,ngals_pred))[0]
#     if vec:
#         return np.sum((resid/0.4)**p)
#     else:
#         return resid**p

# %%
from scipy.optimize import minimize
i=np.where(zcls>0.55)[0]
# minimize the loss function
results = minimize(loss, 1., args=(x[i],Nf[i],Ncf[i],2,True))
print(results)
# Out:
#       fun: 957.2904631802894
#  hess_inv: array([[2.88069714e-07]])
#       jac: array([1.52587891e-05])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 100
#       nit: 11
#      njev: 33
#    status: 2
#   success: False
#         x: array([1.08743876])

# %%
def get_bins(variable,xedges):
    nbins   = len(xedges)-1
    means = (xedges[1:]+xedges[:-1])/2.
    indices = []
    for i in range(nbins):
        idx = np.where((variable >= xedges[i]) & (variable <= xedges[i + 1]))[0]
        indices.append(idx)
    return indices, means

# %%
w = cat['Ngals']>0.
zbins = np.linspace(0.09,1.,16)
keys,zmed = get_bins(zcls[w],zbins)

fmed = np.array([np.mean(ftrue[w][i]) for i in keys])
ferr = np.array([np.std(ftrue[w][i]) for i in keys])

res = []
# for i in keys:
#     results = minimize(loss, 1., args=(x[w][i],Nf[w][i],Ncf[w][i],2,True))
#     res.append(results.x[0])

for i in range(ncls):
    results = minimize(loss, 1., args=(x[w][i],Ncf[w][i],2))
    res.append(results.x[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-407-da8f24fc1c36> in <module>()
#      12
#      13 for i in range(ncls):
# ---> 14     results = minimize(loss, 1., args=(x[w][i],Ncf[w][i],2))
#      15     res.append(results.x[0])
#
# IndexError: index 2053 is out of bounds for axis 0 with size 2053

# %%
# resb = np.array([np.mean(np.array(res)[i]) for i in keys])

# plt.scatter(zmed,resb)
plt.scatter(zmed,np.array(res),s=100)
# plt.ylim(0.,10.)
plt.errorbar(zmed,fmed,yerr=ferr)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
def compute_new_gals(x,f,Ncf,hat_Nf):
    return Prior(Ncf-f*hat_Nf,f*hat_Nf)*x

# %%
finterp = scipy.interpolate.interp1d(zmed,fmed,fill_value=(1,1), bounds_error=False)

# %%
fnew = finterp(zcls)
new_gals = [compute_new_gals(x[i],fnew[i],Ncf[i],Nf[i]) for i in range(ncls)]

# %%
plt.scatter(new_gals,ngals)

# %%
residual = get_frac_residual(Nt,new_gals)[0]
residual_old = get_frac_residual(Nt,ngals)[0]
residual0 = get_frac_residual(Nt,cat['Ngals'])[0]

resb = np.array([np.mean(residual[i]) for i in keys])
resbo = np.array([np.mean(residual_old[i]) for i in keys])
resb0 = np.array([np.mean(residual0[i]) for i in keys])

plt.scatter(zmed,np.abs(resb-1))
plt.scatter(zmed,np.abs(resbo-1))
plt.scatter(zmed,np.abs(resb0-1))
# Out:
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in log10
#
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log10

# %%
def get_variable(cat,label):
    nt0= np.array(cat['Ngals_true']).copy()
    ng0= np.array(cat[label]).copy()
    
    w, = np.where(ng0>0.)
    return nt0[w],ng0[w]

def remove_outliers(x,n=1.5):
    q25,q75 = np.nanpercentile(x,[25,75])
    iqr     = q75-q25
    lo, up  = q25-n*iqr, q75+n*iqr
    mask    = (x<up)&(x>lo)
    return mask

def get_scatter(x,xt):
    residual     = x/xt
    log_residual = np.log10(residual)
    
    check    = np.logical_not(np.isnan(log_residual) | np.isinf(log_residual))
    mask     = remove_outliers(log_residual,n=1.5)&(check)
    
    bias            = 10**np.nanmean(log_residual[mask])
    log_scatter     = np.nanstd(log_residual[mask])
    scatter         = 10**(log_scatter)-1
    
    out_fraction    = 1-1.*np.count_nonzero(mask)/len(x)
    out = {'residual':residual,'log_residual':log_residual,'bias': bias, 
           'scatter':scatter, 'log_scatter':log_scatter, 'outlier_fraction': out_fraction,'mask':mask}
    return out

def plot_scatter_distribution(cat,col,label="data",xmin=0.25,xmax=2.25,logx=False):
    ngalst, ngals = get_variable(cat,col)
    
    w = np.where(ngalst>1)[0]
    res  = get_scatter(ngals[w],ngalst[w])
    print(r'mean: %.3f'%(res['bias']))
    print(r'rms : %.3f'%(res['scatter']))
    print(r'out. frac. : %.3f'%(res['outlier_fraction']))
    
    if logx:
        xbins    = np.linspace(np.log10(xmin),np.log10(xmax),30)
        residual = res['log_residual']
        xm       = np.log10(res['bias'])
        xlo,xup  = xm-2*res['log_scatter'],xm+2*res['log_scatter']
        
    else:
        xbins = np.linspace(xmin,xmax,30)
        residual = res['residual']
        xm       = res['bias']
        xlo,xup  = 10**(np.log10(xm)-2*res['log_scatter']),10**(np.log10(xm)+2*res['log_scatter'])
    print(xbins)
    check     = np.logical_not(np.isnan(residual))&np.logical_not(np.isinf(residual))
    _ = plt.hist(residual[check],bins=xbins,label='out. perc = %.2f %%'%(100*res['outlier_fraction']))
    _ = plt.hist(residual[res['mask']],bins=xbins,label=r'precision = %.2f %%'%(100*res['scatter']))
    plt.axvline(xm,color='k',ls='--')
    plt.axvline(xlo,color='r',ls='--')
    plt.axvline(xup,color='r',ls='--')
    plt.title(label)
    # plt.yscale('log')
    plt.xlabel('ratio')
    plt.legend()

# %%
plot_scatter_distribution(cat,'Ngals')
# Out:
# mean: 1.004
# rms : 0.300
# out. frac. : 0.052
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
cat['Ngals_flat']=ngals
cat['Ngals_corr']=new_gals

# %%
plot_scatter_distribution(cat,'Ngals_corr')
# Out:
# mean: 1.066
# rms : 0.383
# out. frac. : 0.043
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
plot_scatter_distribution(cat,'Ngals_flat')
# Out:
# mean: 1.229
# rms : 0.347
# out. frac. : 0.029
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
i=100
fvec = np.linspace(0.01,3.,1000)
lf   = loss(fvec, x[i],Nf[i],Ncf[i])

# %%
plt.plot(fvec,lf)
plt.axvline(ftrue[i])
#plt.axvline(2.7)

# %%
x[i]/Nt[i]
# Out:
# 1.0692147057960497

# %%
fmax=2.
ngals      = Ncf[i] - fmax*Nf[i]
ngals_pred = prior(ngals,fmax*Nf[i])*x[i]

print(ngals)
# Out:
# 11.710124910245298

# %%
Ncf[i]
# Out:
# 46.30070881509009

# %%
Nt[i]
# Out:
# 31

# %%
Ncf[i]-(ngals_pred+fmax*Nf[i])
# Out:
# 3.327104854696387

# %%
x[i]#*ftrue[i]
# Out:
# 112.85089911601989

# %%
ftrue[i]
# Out:
# 1.3420652567565963

# %%
ftrue[i]
# Out:
# 1.0915495911954882

# %%
results.x[0]
# Out:
# 1.0

# %%
Nft[i]/Nf[i]
# Out:
# 0.21872869242740806

# %%
residual = Nft/Nf
plt.scatter(zcls,residual,s=10)
plt.ylim(0.,2.)
# Out:
# (0.0, 2.0)

# %%
Nft[i]/Nf[i]
# Out:
# <Column name='Nbkg_true' dtype='float64' length=282>
#   4.404027348150755
# 0.21872869242740806
#   1.087804888548256
#  0.8378338668800833
#  1.4404520069099909
# 0.23107494132952625
#  0.4942058746475528
#  1.3300429427014022
#  1.4447107803498418
#  0.9241754773603862
#  0.1700467596442785
# 0.27625489581428375
#                 ...
#  0.9638143637511959
#  0.5376564332542714
#  0.7538234968785757
# 0.22578180181882135
#  0.7492522373109783
#  0.5607990148940459
#   1.309621032676981
# 0.11678554736103011
#   2.200147861313426
#   1.237275971347987
#  0.6736767489477418
#   1.836484485253901

# %%
## Correcting Nc 
## Only for test purposes

# Nc = 1.34*Nc

# %%
# alpha = np.array(Nt).copy()
# beta  = np.array(Nft).copy()

# %% [markdown]
# ## Bayesian Approach: Membership probabilities
#
# Let's compute the new membership probabilities.

# %%
import scipy
from scipy.interpolate import interp1d

import numpy as np
from collections import defaultdict

class BayesianProbability:
    ''' Assign Membership Probabilities For Copacabana Galaxies

    input: a, b, gal
    output: collection('prior','marginal','pdfs','pdfs_field','Pmem','Pr','Pz','Pc')

    a: Estimated number of galaxies inside the cluster area
    b: Estimated number of field galaxies inside the cluster area
    gal: table of galaxies, columns: redshift,pdf,pdfr,pdfz,pdfc
    '''
    def __init__(self, a, b, r2=1):
        self.alpha = np.where(a<=0.,.1,a)
        self.beta  = b
        self.r2    = r2
        self.betaDist = scipy.stats.beta(self.alpha, self.beta)

        self.prob  = defaultdict(dict)
        # ['prior','marginal','pdfs','pdfs_field','Pmem','Pr','Pz','Pc']

        ## init the prior
        self.compute_flat_prior()

    def load_pdfs(self,gal):
        zcls = np.array(gal['redshift']).copy()
        self.p0 = np.array(gal['Pmem']).copy()
        
        self.pdfz = np.array(gal['pdfz'][:]).copy()
        self.pdfr = np.array(gal['pdfr'][:]).copy()
        self.pdfc = get_color_pdf(zcls,gal['pdfc'][:]).copy()
        
        self.pdfzf= np.array(gal['pdfz_bkg'][:]).copy()
        self.pdfrf= np.array(gal['pdfr_bkg'][:]).copy()*(np.pi*self.r2**2)
        self.pdfcf= get_color_pdf(zcls,gal['pdfc_bkg'][:]).copy()
        
        self.pdf = filter_3pdf(self.pdfz,self.pdfc,self.pdfr)
        self.pdff= filter_3pdf(self.pdfzf,self.pdfcf,self.pdfrf)
        
    def compute_flat_prior(self):
        pm0 = self.betaDist.mean()
        priors = {'flat':pm0,'beta':None}
        self.prob['prior'] = priors

    def compute_marginal(self,name,prior_type):
        pm0 = self.prob['prior'][prior_type]
        pf,pff = self.pick_pdf(name)
        res    = pf*pm0 + pff*(1-pm0)
        self.prob['marginal'][name] = res.copy()
    
    def compute_prob(self,label,name,prior_type,eps=1e-9):
        pm0 = self.prob['prior'][prior_type]
        pdf,pdff = self.pick_pdf(name)
        mar = pdf*pm0 + pdff*(1-pm0)
        res = pdf*pm0/(mar+eps)
        pmem= filter_prob(res.copy())
        self.prob[label][prior_type] = pmem.copy()
    
    def compute_likelihood(self):
        self.pvec = np.linspace(0.,1.,1000)
        pm0   = self.prob['prior']['flat']
        radii = np.linspace(0,self.r2,100)
        pdf   = radial_pdf(radii,self.r2)
        mar   = pdf*pm0+(1-pm0)*(np.pi*self.r2**2)
        p0 = pdf*pm0/(mar+1e-9)
        self.likelihood = get_likelihood(self.pvec,p0,pdf)
    
    def pick_pdf(self,name):
        if name=='pdfr':
            return [self.pdfr,self.pdfrf]
        
        elif name=='pdfc':
            return [self.pdfc,self.pdfcf]

        elif name=='pdfz':
            return [self.pdfz,self.pdfzf]
        
        elif name=='pdf':
            return [self.pdf,self.pdff]
        else:
            print('error')
            
    def compute_beta_prior(self):
        prior = join_pdfs(self.pvec,self.likelihood,self.betaDist.pdf(self.pvec))
        pm0   = mean_pdf(self.pvec,prior)

        self.prob['prior']['beta'] = pm0
        self.prior = prior

    def assign_prob(self,name,label,prior_type):
        self.compute_marginal(name,prior_type)
        self.compute_prob(label,name,prior_type)
    
    def assign_prob_old(self,name,label):
        pdf, pdff = self.pick_pdf(name)
        if name!='Pmem':
            res = doProb(pdf, pdff, self.alpha, self.beta, normed=False)
        else:
            res = doProb(pdf, pdff, self.alpha, self.beta, normed=False)

        self.prob[label]['old'] = res.copy()
    
    def assign_probabilities(self,gal):
        self.names = ['pdf','pdfr','pdfz','pdfc']
        self.labels= ['Pmem','Pr','Pz','Pc']

        ## loading pdfs
        self.load_pdfs(gal)

        ## memb. prob. flat prior
        for label,name in zip(self.labels,self.names):
            self.assign_prob(name,label,'flat')

        ## estimating beta prior
        self.compute_likelihood()
        self.compute_beta_prior()
        
        ## memb. prob. beta prior
        for label,name in zip(self.labels,self.names):
            self.assign_prob(name,label,'beta')

        ## for check purposes
        ## old probabilities definition
        for label,name in zip(self.labels,self.names):
            self.assign_prob_old(name,label)
    
    def compute_ngals(self):
        for col in ['flat','beta','old']:
            self.prob['Ngals'][col] = np.nansum(self.prob['Pmem'][col][:]).copy()

    def plot_prior_distribution(self):
        plt.plot(self.pvec,self.betaDist.pdf(self.pvec),'b',label='Beta')
        plt.plot(self.pvec,self.likelihood,'k',label='P(model|member)')
        plt.plot(self.pvec,self.prior,'r',label='Beta*P(model|member)')
        plt.axvline(self.prob['prior']['flat'],color='b',ls='--')
        plt.axvline(self.prob['prior']['beta'],color='r',ls='--')
        plt.legend()
        plt.xlabel("Prior Probability")
        plt.ylabel('Density')
        plt.title(r'$\alpha, \beta = %.1f, %.1f$'%(self.alpha,self.beta), fontsize=16)
        pass

def interpData(x,y,x_new):
    out = interp1d(x, y, kind='linear', fill_value='extrapolate')
    return out(x_new)

def join_pdfs(x,pdf1,pdf2,eps=1e-9):
    prod = pdf1*pdf2
    norm = scipy.integrate.simps(prod,x=x)
    return prod/(norm+eps)

def mean_pdf(x,pdf):
    xmean = scipy.integrate.simps(x*pdf,x=x)
    return xmean

def get_likelihood(xnew,x,pdf,eps=1e-9):
    _,xb,pdfb = bin_data(x,pdf)
    like = interpData(xb,pdfb,xnew)
    like = np.where(np.isnan(like),0,like)
    norm = scipy.integrate.simps(like,x=xnew)
    return like/(norm+eps)

def bin_data(x,y,nbins=20):
    xbins = np.linspace(0,1.,nbins+1)#np.percentile(x,np.linspace(0,100,nbins+1))
    xmean = np.zeros_like(xbins[1:])
    ymean = np.zeros_like(xbins[1:])
    
    i=0
    for xl,xh in zip(xbins[:-1],xbins[1:]):
        w, = np.where((x>xl)&(x<=xh))
        if w.size>0:
            xmean[i] = np.nanmean(x[w])
            ymean[i] = np.nanmean(y[w])
        i+=1
    return xbins,xmean,ymean

def filter_prob(x,val=0):
    x[np.isnan(x)]=0
    x = np.where(x<0,0.,x)
    x = np.where(x>1,1.,x)
    return x

def filter_pdf(pdf):
    pdf = np.where(pdf>1e6,1e6,pdf)
    return pdf

def filter_3pdf(x,y,z):
    pdf = x*y*z
    pdf = filter_pdf(pdf)
    return pdf

## to do: smooth the color pdfs 
## https://stackoverflow.com/questions/20618804/how-to-smooth-a-curve-in-the-right-way
def get_color_pdf(zcls,pdfc):
    return np.array(np.where(zcls<0.35,pdfc[:,0],pdfc[:,2]))
#     return np.ones_like(pdfc[:,0])

### To Remove
def doProb(Pgals,Pbkg,Ngals,Nbkg, normed=True,eps=1e-12):
    ratio = (Ngals+Nbkg)/( np.sum(Ngals*Pgals) + np.sum(Nbkg*Pbkg) )
    Pgals *= ratio
    Pbkg  *= ratio
    
    if normed:
        Pgals /= (Pgals.sum()+eps)
        Pbkg  /= (Pbkg.sum()+eps)
    
    prob = (Ngals*Pgals)/(Ngals*Pgals+Nbkg*Pbkg+eps)
    # prob[np.isnan(prob)] = 0.

    prob = np.where(prob>1,1.,prob)
    prob = np.where(prob<0.,0.,prob)
    return prob
def profileNFW(R,R200,c=3):
    #Radial NFW profile implementation. Takes array of radii, value of R200,
    #and NFW concentration parameter (set to 3 by default)
    if R200>0:
        Rs=float(R200)/c
        r=R/Rs
        r=np.where(np.logical_or(r<=1e-5,r==1.),r+0.001,r)
        pre=1./((r**2)-1)
        arctan_coeff=2./(np.sqrt(np.abs(r**2-1)))
        arctan_arg=np.sqrt(np.abs((r-1)/(r+1)))
        sigma=np.where(r>1,pre*(1-arctan_coeff*np.arctan(arctan_arg)),pre*(1-arctan_coeff*np.arctanh(arctan_arg)))

        return sigma*2*Rs

    else:
        bogusval=-99.*np.ones_like(R)
        return bogusval

def radial_pdf(radii,R200,c=3.5,rc=0.2):
    radii   = np.where(radii<rc/2.,rc/2.,radii)
    density = profileNFW(radii,R200,c=c) ## without norm
    density = np.where(radii<rc,np.mean(density[radii<rc]), density)
    return density

# %%
def chunks(ids1, ids2):
    """Yield successive n-sized chunks from data"""
    for id in ids2:
        w, = np.where( ids1==id )
        yield w

# %%
def set_new_columns(table,columns,val=0.):
    for col in columns:
        table[col] = val
    return table

# %% [markdown]
# ### Prior Example
#
# For a given cluster, we show the prior distribution.

# %%
cids = np.array(cat['CID'])
gids = np.array(gal['CID'])
r200 = np.array(cat['R200'])
keys = list(chunks(gids,cids))

# %%
ncls    = len(cat)
columns = ['flat','beta','old']

## compute the new probabilities
cla,res = [],[]
for i in range(ncls):
    print('alpha,beta: %.2f ,%.2f'%(alpha[i],beta[i]))
    b = BayesianProbability(alpha[i],beta[i],r2=r200[i])
    b.assign_probabilities(gal[keys[i]])
    b.compute_ngals()
    
    res.append(b.prob)
    cla.append(b)
    del b
# Out:
# alpha,beta: 74.80 ,10.20
# alpha,beta: 21.01 ,4.10
# alpha,beta: 13.11 ,8.00
# alpha,beta: 21.11 ,7.19
# alpha,beta: 6.29 ,1.88
# alpha,beta: 59.94 ,22.59
# alpha,beta: 35.33 ,6.95
# alpha,beta: 3.59 ,6.85
# alpha,beta: 29.05 ,7.87
# alpha,beta: 4.79 ,2.89
# alpha,beta: 1.80 ,3.59
# alpha,beta: 68.66 ,14.22
# alpha,beta: 2.66 ,4.70
# alpha,beta: 13.31 ,9.35
# alpha,beta: 4.61 ,3.09
# alpha,beta: 1.56 ,2.82
# alpha,beta: 4.93 ,3.67
# alpha,beta: 19.44 ,7.02
# alpha,beta: 8.74 ,6.23
# alpha,beta: 13.98 ,4.16
# alpha,beta: 7.39 ,6.02
# alpha,beta: 22.98 ,8.33
# alpha,beta: 4.63 ,2.56
# alpha,beta: 15.93 ,8.59
# alpha,beta: 57.65 ,10.29
# alpha,beta: 7.46 ,4.34
# alpha,beta: 33.29 ,20.41
# alpha,beta: 1.86 ,2.67
# alpha,beta: 31.64 ,6.61
# alpha,beta: 9.84 ,5.53
# alpha,beta: 14.80 ,3.48
# alpha,beta: 1.80 ,2.19
# alpha,beta: 2.12 ,4.15
# alpha,beta: 23.24 ,6.54
# alpha,beta: 13.65 ,5.40
# alpha,beta: 83.46 ,11.50
# alpha,beta: 5.61 ,3.85
# alpha,beta: 8.34 ,4.96
# alpha,beta: 6.55 ,3.56
# alpha,beta: 10.57 ,2.33
# alpha,beta: 3.60 ,3.89
# alpha,beta: 144.49 ,11.80
# alpha,beta: 7.50 ,3.35
# alpha,beta: 1.85 ,2.71
# alpha,beta: 0.92 ,2.48
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:152: RuntimeWarning: invalid value encountered in multiply
# alpha,beta: 1.58 ,2.64
# alpha,beta: 30.40 ,4.21
# alpha,beta: 18.40 ,6.90
# alpha,beta: 7.66 ,2.33
# alpha,beta: 93.42 ,23.74
# alpha,beta: 11.94 ,3.89
# alpha,beta: 89.10 ,14.02
# alpha,beta: 49.49 ,10.41
# alpha,beta: 1.59 ,2.22
# alpha,beta: 37.43 ,7.97
# alpha,beta: 5.66 ,4.43
# alpha,beta: 46.30 ,27.02
# alpha,beta: 12.09 ,5.05
# alpha,beta: 6.32 ,3.71
# alpha,beta: 23.63 ,5.76
# alpha,beta: 5.41 ,2.58
# alpha,beta: 39.69 ,7.74
# alpha,beta: 22.80 ,9.38
# alpha,beta: 7.95 ,5.75
# alpha,beta: 14.57 ,2.83
# alpha,beta: 38.21 ,17.44
# alpha,beta: 3.24 ,1.83
# alpha,beta: 3.59 ,3.62
# alpha,beta: 72.51 ,22.22
# alpha,beta: 14.46 ,6.71
# alpha,beta: 27.38 ,7.50
# alpha,beta: 9.28 ,5.44
# alpha,beta: 10.61 ,4.64
# alpha,beta: 10.16 ,6.74
# alpha,beta: 9.85 ,5.52
# alpha,beta: 7.51 ,3.77
# alpha,beta: 5.72 ,2.99
# alpha,beta: 31.19 ,5.46
# alpha,beta: -0.53 ,2.45
# alpha,beta: 12.26 ,6.71
# alpha,beta: 2.65 ,2.11
# alpha,beta: 20.52 ,17.30
# alpha,beta: 6.53 ,3.15
# alpha,beta: 6.57 ,3.54
# alpha,beta: 5.44 ,1.64
# alpha,beta: 2.87 ,3.92
# alpha,beta: 7.58 ,2.62
# alpha,beta: 35.60 ,12.06
# alpha,beta: 1.42 ,2.98
# alpha,beta: 7.60 ,2.83
# alpha,beta: 21.80 ,6.92
# alpha,beta: 5.19 ,4.39
# alpha,beta: 17.51 ,5.83
# alpha,beta: 4.52 ,2.68
# alpha,beta: 20.72 ,6.12
# alpha,beta: 3.14 ,2.57
# alpha,beta: 3.55 ,10.07
# alpha,beta: 21.07 ,8.29
# alpha,beta: 30.24 ,5.32
# alpha,beta: 4.79 ,3.74
# alpha,beta: 33.54 ,7.77
# alpha,beta: 11.98 ,6.47
# alpha,beta: 3.09 ,1.89
# alpha,beta: 5.22 ,2.11
# alpha,beta: 12.85 ,5.93
# alpha,beta: 18.09 ,6.73
# alpha,beta: 6.94 ,3.69
# alpha,beta: 30.97 ,10.46
# alpha,beta: 14.70 ,9.29
# alpha,beta: 1.73 ,2.94
# alpha,beta: 6.85 ,5.06
# alpha,beta: 14.75 ,8.56
# alpha,beta: 3.48 ,2.28
# alpha,beta: 19.94 ,5.49
# alpha,beta: 3.21 ,3.04
# alpha,beta: 57.93 ,6.00
# alpha,beta: 29.25 ,12.26
# alpha,beta: 3.83 ,2.19
# alpha,beta: 8.37 ,4.50
# alpha,beta: 17.14 ,4.43
# alpha,beta: -0.52 ,2.88
# alpha,beta: 12.04 ,4.03
# alpha,beta: 6.90 ,2.25
# alpha,beta: 3.41 ,4.20
# alpha,beta: 3.79 ,3.32
# alpha,beta: 42.73 ,6.18
# alpha,beta: 3.33 ,4.26
# alpha,beta: 8.40 ,3.46
# alpha,beta: 5.24 ,3.69
# alpha,beta: 13.06 ,8.31
# alpha,beta: 6.72 ,4.95
# alpha,beta: 9.06 ,8.89
# alpha,beta: 2.88 ,3.51
# alpha,beta: 14.60 ,8.00
# alpha,beta: 21.77 ,5.32
# alpha,beta: 35.68 ,9.36
# alpha,beta: 39.37 ,23.46
# alpha,beta: 43.07 ,6.57
# alpha,beta: 10.56 ,6.47
# alpha,beta: 2.60 ,4.17
# alpha,beta: 3.40 ,2.38
# alpha,beta: 4.51 ,4.08
# alpha,beta: 13.15 ,4.61
# alpha,beta: 28.76 ,6.34
# alpha,beta: 2.55 ,1.96
# alpha,beta: 5.28 ,2.83
# alpha,beta: 13.92 ,6.24
# alpha,beta: 6.47 ,3.81
# alpha,beta: 51.15 ,9.96
# alpha,beta: 13.89 ,5.26
# alpha,beta: 138.87 ,13.36
# alpha,beta: 9.98 ,2.92
# alpha,beta: 14.03 ,3.54
# alpha,beta: 3.51 ,4.82
# alpha,beta: 10.81 ,4.07
# alpha,beta: 8.13 ,9.60
# alpha,beta: 6.35 ,2.38
# alpha,beta: 17.45 ,5.31
# alpha,beta: 16.28 ,12.79
# alpha,beta: 8.19 ,2.71
# alpha,beta: 28.46 ,6.00
# alpha,beta: 19.54 ,5.69
# alpha,beta: 17.86 ,4.24
# alpha,beta: 7.60 ,7.21
# alpha,beta: 11.11 ,4.52
# alpha,beta: 2.38 ,5.57
# alpha,beta: 1.02 ,2.63
# alpha,beta: 29.42 ,12.89
# alpha,beta: 18.02 ,4.21
# alpha,beta: 5.83 ,3.31
# alpha,beta: 2.40 ,2.09
# alpha,beta: -1.17 ,4.89
# alpha,beta: 10.86 ,3.84
# alpha,beta: 4.07 ,3.09
# alpha,beta: 5.92 ,2.62
# alpha,beta: 7.84 ,6.08
# alpha,beta: 7.33 ,4.24
# alpha,beta: 56.05 ,15.86
# alpha,beta: 13.49 ,6.13
# alpha,beta: 21.51 ,3.31
# alpha,beta: 3.97 ,3.91
# alpha,beta: 13.56 ,6.77
# alpha,beta: 4.53 ,2.33
# alpha,beta: 22.59 ,5.01
# alpha,beta: 7.49 ,3.20
# alpha,beta: 7.39 ,5.45
# alpha,beta: 1.83 ,3.04
# alpha,beta: 77.16 ,9.78
# alpha,beta: 21.46 ,7.06
# alpha,beta: 5.23 ,4.19
# alpha,beta: 6.73 ,3.86
# alpha,beta: 117.02 ,8.06
# alpha,beta: 10.62 ,5.77
# alpha,beta: 12.08 ,2.99
# alpha,beta: 5.43 ,2.79
# alpha,beta: 27.91 ,7.09
# alpha,beta: 24.55 ,6.60
# alpha,beta: 89.19 ,14.30
# alpha,beta: -0.23 ,5.35
# alpha,beta: 23.48 ,6.07
# alpha,beta: 4.43 ,2.31
# alpha,beta: 3.58 ,3.37
# alpha,beta: 7.96 ,6.71
# alpha,beta: 15.20 ,12.07
# alpha,beta: 4.40 ,4.01
# alpha,beta: 7.16 ,2.43
# alpha,beta: 28.13 ,25.73
# alpha,beta: 2.72 ,2.40
# alpha,beta: 7.35 ,11.61
# alpha,beta: 8.11 ,7.74
# alpha,beta: 3.32 ,3.13
# alpha,beta: 17.78 ,16.80
# alpha,beta: 37.71 ,13.30
# alpha,beta: 12.43 ,5.10
# alpha,beta: 3.98 ,3.13
# alpha,beta: 8.87 ,3.65
# alpha,beta: 17.76 ,8.39
# alpha,beta: 4.45 ,3.65
# alpha,beta: 14.58 ,7.69
# alpha,beta: 18.85 ,6.86
# alpha,beta: 4.76 ,2.12
# alpha,beta: 16.43 ,4.93
# alpha,beta: 36.91 ,9.93
# alpha,beta: 64.20 ,9.71
# alpha,beta: 9.31 ,3.40
# alpha,beta: 10.23 ,4.02
# alpha,beta: 45.68 ,8.63
# alpha,beta: 12.67 ,4.95
# alpha,beta: 5.69 ,3.63
# alpha,beta: 14.33 ,5.83
# alpha,beta: 22.15 ,7.18
# alpha,beta: 19.88 ,8.15
# alpha,beta: 10.80 ,3.67
# alpha,beta: 3.99 ,2.75
# alpha,beta: 34.26 ,11.47
# alpha,beta: 7.47 ,3.75
# alpha,beta: 1.63 ,2.41
# alpha,beta: 4.04 ,3.42
# alpha,beta: 12.81 ,6.38
# alpha,beta: 1.01 ,3.88
# alpha,beta: 3.54 ,3.02
# alpha,beta: 5.30 ,2.47
# alpha,beta: 9.13 ,4.79
# alpha,beta: 13.16 ,3.94
# alpha,beta: 1.04 ,3.04
# alpha,beta: 10.87 ,6.62
# alpha,beta: 43.18 ,11.75
# alpha,beta: 13.67 ,2.32
# alpha,beta: 20.90 ,9.56
# alpha,beta: 20.43 ,4.84
# alpha,beta: 22.76 ,18.39
# alpha,beta: 6.04 ,2.47
# alpha,beta: 2.08 ,2.21
# alpha,beta: 8.80 ,4.76
# alpha,beta: 7.34 ,4.09
# alpha,beta: 7.43 ,4.16
# alpha,beta: 1.47 ,1.91
# alpha,beta: 8.29 ,4.98
# alpha,beta: 8.01 ,4.29
# alpha,beta: 65.41 ,13.49
# alpha,beta: 27.14 ,20.32
# alpha,beta: 29.06 ,12.87
# alpha,beta: 35.61 ,9.22
# alpha,beta: 1.93 ,6.91
# alpha,beta: 0.55 ,3.04
# alpha,beta: 77.03 ,13.26
# alpha,beta: 18.49 ,5.70
# alpha,beta: 7.29 ,3.15
# alpha,beta: 36.98 ,17.83
# alpha,beta: 5.96 ,6.84
# alpha,beta: 6.34 ,6.89
# alpha,beta: 4.75 ,2.36
# alpha,beta: 12.91 ,7.15
# alpha,beta: 4.47 ,4.87
# alpha,beta: 26.97 ,9.44
# alpha,beta: 12.63 ,10.26
# alpha,beta: 4.23 ,2.40
# alpha,beta: 32.30 ,11.35
# alpha,beta: 6.51 ,4.52
# alpha,beta: 8.19 ,7.32
# alpha,beta: 4.34 ,5.01
# alpha,beta: 2.61 ,3.96
# alpha,beta: 9.24 ,5.92
# alpha,beta: 13.82 ,3.88
# alpha,beta: 10.26 ,5.97
# alpha,beta: 8.32 ,6.67
# alpha,beta: 56.20 ,14.46
# alpha,beta: 45.30 ,13.99
# alpha,beta: 3.03 ,2.87
# alpha,beta: 43.30 ,6.22
# alpha,beta: 4.87 ,3.03
# alpha,beta: 6.58 ,4.07
# alpha,beta: 4.50 ,4.52
# alpha,beta: 14.86 ,5.17
# alpha,beta: 76.25 ,16.70
# alpha,beta: 73.10 ,6.40
# alpha,beta: 0.58 ,2.31
# alpha,beta: 24.78 ,4.96
# alpha,beta: 10.45 ,7.00
# alpha,beta: 29.06 ,6.26
# alpha,beta: 13.45 ,8.11
# alpha,beta: 1.85 ,2.67
# alpha,beta: 3.62 ,2.80
# alpha,beta: 3.84 ,3.99
# alpha,beta: 12.37 ,4.39
# alpha,beta: 56.08 ,18.91
# alpha,beta: 8.10 ,7.44
# alpha,beta: 4.78 ,3.15
# alpha,beta: 0.13 ,2.81
# alpha,beta: 32.99 ,4.97
# alpha,beta: 74.99 ,10.44
# alpha,beta: 19.82 ,8.57
# alpha,beta: 7.37 ,5.41
# alpha,beta: 12.25 ,3.54
# alpha,beta: 5.15 ,4.93
# alpha,beta: 27.05 ,11.82
# alpha,beta: 12.04 ,4.49
# alpha,beta: 4.81 ,3.32
# alpha,beta: 20.34 ,7.11
# alpha,beta: 17.04 ,4.47
# alpha,beta: 24.78 ,8.16
# alpha,beta: 4.47 ,2.32
# alpha,beta: 7.31 ,4.97
# alpha,beta: 5.04 ,4.38
# alpha,beta: 5.04 ,5.12
# alpha,beta: 1.58 ,2.49
# alpha,beta: 159.30 ,11.30
# alpha,beta: 32.19 ,11.00
# alpha,beta: 11.30 ,11.70
# alpha,beta: 4.80 ,2.13
# alpha,beta: 46.95 ,11.53
# alpha,beta: 4.56 ,4.67
# alpha,beta: 15.60 ,6.82
# alpha,beta: 1.07 ,2.40
# alpha,beta: 3.16 ,4.23
# alpha,beta: 27.61 ,6.54
# alpha,beta: 3.63 ,1.98
# alpha,beta: 23.89 ,6.99
# alpha,beta: 16.45 ,7.46
# alpha,beta: 28.95 ,7.32
# alpha,beta: 64.96 ,16.85
# alpha,beta: 8.61 ,4.70
# alpha,beta: 53.59 ,13.78
# alpha,beta: 14.40 ,6.04
# alpha,beta: 18.03 ,7.46
# alpha,beta: 6.00 ,2.13
# alpha,beta: 41.01 ,11.57
# alpha,beta: 49.46 ,11.28
# alpha,beta: 4.50 ,3.52
# alpha,beta: 6.26 ,6.02
# alpha,beta: 5.65 ,4.46
# alpha,beta: 19.88 ,10.29
# alpha,beta: 8.20 ,2.61
# alpha,beta: 11.51 ,2.73
# alpha,beta: 4.95 ,2.89
# alpha,beta: 3.07 ,7.29
# alpha,beta: 28.33 ,7.82
# alpha,beta: 21.43 ,8.39
# alpha,beta: 3.13 ,2.89
# alpha,beta: 20.20 ,5.44
# alpha,beta: 11.45 ,4.62
# alpha,beta: 58.99 ,16.79
# alpha,beta: 37.41 ,9.35
# alpha,beta: 5.90 ,2.91
# alpha,beta: 4.56 ,2.45
# alpha,beta: 7.87 ,3.03
# alpha,beta: 0.37 ,3.41
# alpha,beta: 11.25 ,3.97
# alpha,beta: 19.15 ,8.00
# alpha,beta: 4.17 ,3.04
# alpha,beta: 32.73 ,12.89
# alpha,beta: 7.30 ,3.28
# alpha,beta: 10.39 ,8.82
# alpha,beta: 28.34 ,11.02
# alpha,beta: 48.46 ,13.17
# alpha,beta: 3.33 ,2.55
# alpha,beta: 13.64 ,6.22
# alpha,beta: 2.51 ,2.24
# alpha,beta: 19.65 ,5.95
# alpha,beta: 24.95 ,8.73
# alpha,beta: 6.58 ,2.91
# alpha,beta: 18.35 ,5.48
# alpha,beta: 16.84 ,8.74
# alpha,beta: 24.95 ,9.57
# alpha,beta: 3.28 ,2.48
# alpha,beta: 4.08 ,2.85
# alpha,beta: 38.68 ,7.10
# alpha,beta: 18.14 ,5.81
# alpha,beta: 6.23 ,4.25
# alpha,beta: 12.85 ,5.81
# alpha,beta: 112.69 ,31.26
# alpha,beta: 2.98 ,5.56
# alpha,beta: 29.16 ,14.57
# alpha,beta: 26.13 ,10.52
# alpha,beta: 23.46 ,16.04
# alpha,beta: 10.57 ,4.41
# alpha,beta: 16.85 ,3.12
# alpha,beta: 38.80 ,8.70
# alpha,beta: 2.14 ,3.12
# alpha,beta: 9.40 ,5.21
# alpha,beta: 1.62 ,4.02
# alpha,beta: 5.24 ,2.31
# alpha,beta: 13.02 ,4.82
# alpha,beta: 11.18 ,3.97
# alpha,beta: 10.46 ,6.57
# alpha,beta: 9.49 ,2.63
# alpha,beta: 15.09 ,6.74
# alpha,beta: 24.26 ,13.56
# alpha,beta: 20.95 ,6.21
# alpha,beta: 46.77 ,41.56
# alpha,beta: 1.29 ,2.38
# alpha,beta: 5.84 ,3.57
# alpha,beta: 7.19 ,6.45
# alpha,beta: 19.37 ,5.22
# alpha,beta: 6.79 ,2.38
# alpha,beta: 39.53 ,12.85
# alpha,beta: 48.69 ,8.28
# alpha,beta: 77.22 ,7.23
# alpha,beta: 8.41 ,3.15
# alpha,beta: 7.46 ,3.99
# alpha,beta: 15.76 ,8.78
# alpha,beta: 35.16 ,8.80
# alpha,beta: 8.96 ,7.64
# alpha,beta: 16.06 ,5.98
# alpha,beta: 4.33 ,4.11
# alpha,beta: 3.18 ,2.28
# alpha,beta: 11.84 ,3.57
# alpha,beta: 4.20 ,4.44
# alpha,beta: 20.69 ,6.83
# alpha,beta: 22.56 ,8.26
# alpha,beta: 31.17 ,15.50
# alpha,beta: 14.36 ,4.68
# alpha,beta: 15.04 ,10.40
# alpha,beta: 12.30 ,5.80
# alpha,beta: 1.09 ,2.82
# alpha,beta: 7.59 ,7.14
# alpha,beta: 38.64 ,12.37
# alpha,beta: 10.26 ,4.72
# alpha,beta: 3.59 ,5.44
# alpha,beta: 9.16 ,3.42
# alpha,beta: 10.24 ,3.97
# alpha,beta: 26.94 ,12.37
# alpha,beta: 48.23 ,8.68
# alpha,beta: 21.58 ,5.99
# alpha,beta: 11.40 ,2.93
# alpha,beta: 7.89 ,3.36
# alpha,beta: 14.59 ,3.56
# alpha,beta: 15.20 ,5.31
# alpha,beta: 18.18 ,13.46
# alpha,beta: 22.35 ,4.98
# alpha,beta: 0.69 ,3.10
# alpha,beta: 5.85 ,4.44
# alpha,beta: 32.94 ,6.81
# alpha,beta: 7.40 ,3.95
# alpha,beta: 20.69 ,12.07
# alpha,beta: 25.67 ,4.27
# alpha,beta: 4.52 ,2.51
# alpha,beta: 2.84 ,3.43
# alpha,beta: 5.32 ,4.49
# alpha,beta: 23.65 ,18.19
# alpha,beta: 6.98 ,4.87
# alpha,beta: 11.84 ,10.49
# alpha,beta: 22.76 ,10.13
# alpha,beta: 4.80 ,6.77
# alpha,beta: 19.42 ,11.05
# alpha,beta: 5.74 ,2.38
# alpha,beta: 2.12 ,3.12
# alpha,beta: 16.13 ,4.40
# alpha,beta: 1.22 ,3.00
# alpha,beta: 9.71 ,2.86
# alpha,beta: 27.29 ,6.19
# alpha,beta: 46.23 ,13.48
# alpha,beta: 7.09 ,2.88
# alpha,beta: 46.19 ,9.63
# alpha,beta: 9.83 ,4.15
# alpha,beta: 21.23 ,5.01
# alpha,beta: 12.19 ,6.27
# alpha,beta: 1.06 ,3.65
# alpha,beta: 5.12 ,3.42
# alpha,beta: 11.16 ,3.99
# alpha,beta: 10.44 ,5.92
# alpha,beta: 19.61 ,6.00
# alpha,beta: 11.21 ,6.47
# alpha,beta: 12.01 ,4.39
# alpha,beta: 60.99 ,20.04
# alpha,beta: 8.08 ,5.01
# alpha,beta: 9.01 ,4.17
# alpha,beta: 22.17 ,4.60
# alpha,beta: 8.75 ,4.31
# alpha,beta: 33.64 ,11.96
# alpha,beta: 8.22 ,4.10
# alpha,beta: 23.51 ,18.15
# alpha,beta: 13.97 ,7.34
# alpha,beta: 17.15 ,8.84
# alpha,beta: 15.17 ,3.52
# alpha,beta: 18.06 ,9.41
# alpha,beta: 13.02 ,11.47
# alpha,beta: 16.80 ,5.38
# alpha,beta: 5.84 ,3.31
# alpha,beta: 47.14 ,8.51
# alpha,beta: 9.05 ,6.13
# alpha,beta: 23.43 ,10.17
# alpha,beta: 10.02 ,4.94
# alpha,beta: 7.01 ,4.17
# alpha,beta: 13.00 ,16.18
# alpha,beta: 28.68 ,18.95
# alpha,beta: 25.84 ,13.36
# alpha,beta: 8.11 ,6.10
# alpha,beta: 23.02 ,13.38
# alpha,beta: 8.67 ,2.55
# alpha,beta: 10.07 ,6.19
# alpha,beta: 6.80 ,4.45
# alpha,beta: 20.75 ,9.31
# alpha,beta: 5.95 ,6.92
# alpha,beta: 31.62 ,8.55
# alpha,beta: 8.10 ,7.63
# alpha,beta: 3.16 ,1.73
# alpha,beta: 28.52 ,9.28
# alpha,beta: 9.88 ,3.12
# alpha,beta: 79.56 ,10.40
# alpha,beta: 5.78 ,3.84
# alpha,beta: 2.04 ,5.13
# alpha,beta: 40.77 ,10.60
# alpha,beta: 2.49 ,5.11
# alpha,beta: 15.28 ,20.07
# alpha,beta: 9.40 ,3.44
# alpha,beta: 3.36 ,2.80
# alpha,beta: 3.09 ,4.85
# alpha,beta: 4.78 ,2.61
# alpha,beta: 75.93 ,12.14
# alpha,beta: 8.96 ,11.73
# alpha,beta: 14.67 ,4.26
# alpha,beta: 16.28 ,2.92
# alpha,beta: 6.43 ,3.40
# alpha,beta: 50.34 ,11.52
# alpha,beta: 11.64 ,5.68
# alpha,beta: 6.31 ,3.51
# alpha,beta: 4.71 ,2.78
# alpha,beta: 13.31 ,6.64
# alpha,beta: 11.32 ,8.24
# alpha,beta: 14.63 ,6.99
# alpha,beta: 12.54 ,3.10
# alpha,beta: 47.39 ,7.39
# alpha,beta: 2.77 ,2.55
# alpha,beta: 9.86 ,3.33
# alpha,beta: 13.34 ,5.95
# alpha,beta: 2.92 ,2.19
# alpha,beta: 6.91 ,2.33
# alpha,beta: 23.85 ,11.78
# alpha,beta: 62.65 ,31.49
# alpha,beta: 60.52 ,13.22
# alpha,beta: 33.95 ,11.24
# alpha,beta: 7.08 ,5.73
# alpha,beta: 21.36 ,5.94
# alpha,beta: 14.75 ,3.37
# alpha,beta: 16.17 ,7.03
# alpha,beta: 1.54 ,3.91
# alpha,beta: 157.09 ,12.73
# alpha,beta: 18.22 ,5.56
# alpha,beta: 39.43 ,9.00
# alpha,beta: 32.20 ,7.84
# alpha,beta: 23.68 ,12.38
# alpha,beta: 7.21 ,3.88
# alpha,beta: 6.21 ,6.03
# alpha,beta: 18.24 ,10.14
# alpha,beta: 6.68 ,4.00
# alpha,beta: 5.21 ,2.32
# alpha,beta: 8.72 ,4.21
# alpha,beta: 2.72 ,6.77
# alpha,beta: 10.68 ,7.64
# alpha,beta: 21.88 ,14.70
# alpha,beta: 28.57 ,12.78
# alpha,beta: 7.01 ,4.62
# alpha,beta: 58.98 ,12.23
# alpha,beta: 4.65 ,3.52
# alpha,beta: 1.79 ,2.61
# alpha,beta: 2.01 ,3.11
# alpha,beta: 5.85 ,2.13
# alpha,beta: 72.14 ,15.88
# alpha,beta: 14.19 ,7.38
# alpha,beta: 3.68 ,4.21
# alpha,beta: 32.41 ,7.05
# alpha,beta: 17.56 ,7.25
# alpha,beta: 16.39 ,7.79
# alpha,beta: 146.79 ,12.60
# alpha,beta: 35.48 ,8.03
# alpha,beta: 5.43 ,4.43
# alpha,beta: 26.11 ,8.81
# alpha,beta: 7.42 ,3.59
# alpha,beta: 135.06 ,15.45
# alpha,beta: 7.76 ,5.94
# alpha,beta: 9.40 ,4.50
# alpha,beta: 8.01 ,8.87
# alpha,beta: 75.87 ,11.02
# alpha,beta: 28.19 ,19.68
# alpha,beta: 7.47 ,3.71
# alpha,beta: 8.22 ,6.70
# alpha,beta: 54.72 ,11.42
# alpha,beta: 23.19 ,10.52
# alpha,beta: 41.48 ,9.38
# alpha,beta: 4.02 ,2.80
# alpha,beta: 32.30 ,13.64
# alpha,beta: 9.50 ,4.23
# alpha,beta: 28.62 ,6.66
# alpha,beta: 22.88 ,8.96
# alpha,beta: 28.19 ,14.47
# alpha,beta: 5.34 ,2.82
# alpha,beta: 12.64 ,7.75
# alpha,beta: 5.34 ,3.12
# alpha,beta: 10.02 ,5.83
# alpha,beta: 7.71 ,7.05
# alpha,beta: 7.11 ,1.89
# alpha,beta: 17.87 ,5.36
# alpha,beta: 8.33 ,3.21
# alpha,beta: 5.16 ,4.00
# alpha,beta: 0.48 ,4.83
# alpha,beta: 15.91 ,9.67
# alpha,beta: 6.60 ,3.68
# alpha,beta: 4.38 ,2.39
# alpha,beta: 1.67 ,2.29
# alpha,beta: 6.20 ,3.82
# alpha,beta: 7.70 ,5.47
# alpha,beta: 30.59 ,14.52
# alpha,beta: 2.75 ,6.10
# alpha,beta: 4.50 ,3.59
# alpha,beta: 11.54 ,4.89
# alpha,beta: 18.48 ,12.66
# alpha,beta: 1.20 ,2.30
# alpha,beta: 2.47 ,7.60
# alpha,beta: 86.12 ,18.61
# alpha,beta: 6.79 ,4.17
# alpha,beta: 26.78 ,9.28
# alpha,beta: 18.89 ,11.23
# alpha,beta: 16.46 ,4.66
# alpha,beta: 42.86 ,13.84
# alpha,beta: 16.65 ,7.05
# alpha,beta: 10.75 ,6.37
# alpha,beta: 8.67 ,3.37
# alpha,beta: 13.02 ,6.78
# alpha,beta: 25.93 ,9.09
# alpha,beta: 7.09 ,3.72
# alpha,beta: 48.16 ,18.41
# alpha,beta: 7.18 ,5.85
# alpha,beta: 15.40 ,4.05
# alpha,beta: 17.96 ,3.68
# alpha,beta: 28.45 ,9.46
# alpha,beta: 29.47 ,16.66
# alpha,beta: 35.03 ,9.29
# alpha,beta: 17.68 ,7.17
# alpha,beta: 28.22 ,11.66
# alpha,beta: 15.26 ,8.46
# alpha,beta: 98.84 ,8.83
# alpha,beta: 12.74 ,5.60
# alpha,beta: 8.25 ,4.33
# alpha,beta: 4.18 ,2.90
# alpha,beta: 11.84 ,4.08
# alpha,beta: 15.01 ,12.90
# alpha,beta: 13.72 ,4.23
# alpha,beta: 30.81 ,15.28
# alpha,beta: 6.45 ,3.64
# alpha,beta: 0.18 ,4.13
# alpha,beta: 40.91 ,14.42
# alpha,beta: 7.02 ,3.51
# alpha,beta: 9.62 ,5.89
# alpha,beta: 2.78 ,5.30
# alpha,beta: 2.59 ,17.74
# alpha,beta: 22.15 ,7.06
# alpha,beta: 6.52 ,4.14
# alpha,beta: 13.97 ,8.26
# alpha,beta: 12.48 ,5.91
# alpha,beta: 19.48 ,9.03
# alpha,beta: 3.62 ,6.15
# alpha,beta: 31.76 ,13.85
# alpha,beta: 18.10 ,17.79
# alpha,beta: 16.10 ,3.74
# alpha,beta: 65.08 ,14.10
# alpha,beta: 23.65 ,10.20
# alpha,beta: 20.53 ,2.98
# alpha,beta: 80.33 ,13.84
# alpha,beta: 11.29 ,10.58
# alpha,beta: 4.30 ,5.47
# alpha,beta: 4.91 ,2.65
# alpha,beta: 9.51 ,5.88
# alpha,beta: 9.28 ,5.43
# alpha,beta: 9.23 ,4.76
# alpha,beta: 3.84 ,2.51
# alpha,beta: 19.93 ,7.10
# alpha,beta: 19.83 ,15.21
# alpha,beta: 10.63 ,10.55
# alpha,beta: 27.06 ,7.64
# alpha,beta: 44.23 ,7.81
# alpha,beta: 28.97 ,7.30
# alpha,beta: 5.74 ,3.09
# alpha,beta: 4.56 ,4.64
# alpha,beta: 21.47 ,8.57
# alpha,beta: 118.52 ,12.14
# alpha,beta: 11.17 ,14.24
# alpha,beta: 29.94 ,8.39
# alpha,beta: 8.87 ,3.47
# alpha,beta: 2.51 ,2.99
# alpha,beta: 16.63 ,4.91
# alpha,beta: 14.59 ,3.76
# alpha,beta: 9.09 ,3.81
# alpha,beta: 50.54 ,10.05
# alpha,beta: 12.68 ,5.12
# alpha,beta: 12.68 ,3.75
# alpha,beta: 5.68 ,1.95
# alpha,beta: 2.77 ,2.06
# alpha,beta: 6.89 ,3.26
# alpha,beta: 2.76 ,2.91
# alpha,beta: 5.96 ,5.43
# alpha,beta: 44.54 ,9.65
# alpha,beta: 72.55 ,23.43
# alpha,beta: 3.20 ,3.44
# alpha,beta: 22.25 ,11.26
# alpha,beta: 1.20 ,3.22
# alpha,beta: 2.28 ,2.88
# alpha,beta: 18.12 ,4.44
# alpha,beta: 27.84 ,17.06
# alpha,beta: 2.88 ,4.81
# alpha,beta: 18.96 ,6.31
# alpha,beta: 3.63 ,2.98
# alpha,beta: 13.17 ,6.61
# alpha,beta: 23.67 ,6.44
# alpha,beta: 2.72 ,1.81
# alpha,beta: 8.11 ,3.17
# alpha,beta: 1.83 ,2.68
# alpha,beta: 8.91 ,4.32
# alpha,beta: 32.65 ,9.00
# alpha,beta: 31.30 ,9.95
# alpha,beta: 5.40 ,2.33
# alpha,beta: 9.23 ,5.15
# alpha,beta: 13.24 ,11.30
# alpha,beta: 29.18 ,7.74
# alpha,beta: 80.41 ,7.19
# alpha,beta: 2.62 ,2.52
# alpha,beta: 18.15 ,8.89
# alpha,beta: 23.37 ,3.03
# alpha,beta: 10.68 ,3.70
# alpha,beta: 6.42 ,2.95
# alpha,beta: 147.78 ,13.68
# alpha,beta: 1.18 ,2.83
# alpha,beta: 11.92 ,5.70
# alpha,beta: 19.90 ,8.53
# alpha,beta: 25.26 ,14.55
# alpha,beta: 5.81 ,2.73
# alpha,beta: 16.49 ,5.61
# alpha,beta: 9.02 ,2.78
# alpha,beta: 11.20 ,7.41
# alpha,beta: 29.73 ,20.77
# alpha,beta: 21.62 ,14.51
# alpha,beta: 79.22 ,10.56
# alpha,beta: 0.76 ,3.31
# alpha,beta: 23.27 ,11.82
# alpha,beta: 42.43 ,10.22
# alpha,beta: 9.41 ,2.76
# alpha,beta: 7.50 ,2.61
# alpha,beta: 34.23 ,16.19
# alpha,beta: 1.70 ,1.91
# alpha,beta: 9.26 ,4.66
# alpha,beta: 5.58 ,4.92
# alpha,beta: 9.76 ,8.12
# alpha,beta: 9.69 ,4.73
# alpha,beta: 11.57 ,5.80
# alpha,beta: 3.09 ,4.07
# alpha,beta: 18.99 ,13.70
# alpha,beta: 43.25 ,8.62
# alpha,beta: 10.21 ,4.02
# alpha,beta: 10.56 ,10.22
# alpha,beta: 56.69 ,12.18
# alpha,beta: 8.00 ,9.29
# alpha,beta: 13.34 ,4.19
# alpha,beta: 25.25 ,12.34
# alpha,beta: 6.82 ,2.27
# alpha,beta: 3.39 ,4.02
# alpha,beta: 7.16 ,2.92
# alpha,beta: 13.49 ,6.60
# alpha,beta: 19.72 ,5.89
# alpha,beta: 11.05 ,4.22
# alpha,beta: 37.94 ,12.07
# alpha,beta: 26.46 ,6.32
# alpha,beta: 0.99 ,2.09
# alpha,beta: 23.61 ,7.48
# alpha,beta: 19.79 ,20.79
# alpha,beta: 3.98 ,2.12
# alpha,beta: 27.86 ,8.59
# alpha,beta: 4.49 ,6.10
# alpha,beta: 15.16 ,5.41
# alpha,beta: 42.64 ,34.42
# alpha,beta: 1.11 ,2.75
# alpha,beta: 5.25 ,3.18
# alpha,beta: 12.91 ,8.84
# alpha,beta: 4.62 ,2.92
# alpha,beta: 4.46 ,4.49
# alpha,beta: 30.89 ,7.30
# alpha,beta: 51.83 ,12.84
# alpha,beta: 10.42 ,10.70
# alpha,beta: 13.96 ,12.34
# alpha,beta: 24.27 ,9.76
# alpha,beta: 17.15 ,11.93
# alpha,beta: 13.62 ,4.42
# alpha,beta: 10.98 ,8.36
# alpha,beta: 8.32 ,2.41
# alpha,beta: 13.38 ,8.70
# alpha,beta: 10.64 ,4.52
# alpha,beta: 7.47 ,3.09
# alpha,beta: 32.56 ,7.69
# alpha,beta: 1.88 ,3.82
# alpha,beta: 26.06 ,6.74
# alpha,beta: 3.19 ,2.69
# alpha,beta: 4.51 ,3.19
# alpha,beta: 15.51 ,6.81
# alpha,beta: 26.89 ,4.68
# alpha,beta: 4.16 ,3.29
# alpha,beta: 23.87 ,6.49
# alpha,beta: 7.71 ,5.37
# alpha,beta: 5.74 ,4.07
# alpha,beta: 11.36 ,8.00
# alpha,beta: 23.74 ,12.28
# alpha,beta: 3.67 ,2.39
# alpha,beta: 7.40 ,3.19
# alpha,beta: 66.10 ,12.14
# alpha,beta: 3.21 ,2.63
# alpha,beta: 29.17 ,6.46
# alpha,beta: 3.37 ,2.41
# alpha,beta: 15.05 ,8.49
# alpha,beta: 24.18 ,19.59
# alpha,beta: 2.39 ,3.36
# alpha,beta: 9.85 ,12.26
# alpha,beta: 6.43 ,3.94
# alpha,beta: 36.60 ,5.77
# alpha,beta: 4.96 ,4.97
# alpha,beta: 15.98 ,9.50
# alpha,beta: 18.27 ,7.81
# alpha,beta: 5.34 ,8.25
# alpha,beta: 8.87 ,4.82
# alpha,beta: 8.01 ,2.89
# alpha,beta: 14.56 ,3.17
# alpha,beta: 29.34 ,9.94
# alpha,beta: 8.23 ,4.13
# alpha,beta: 18.78 ,11.11
# alpha,beta: 2.53 ,3.76
# alpha,beta: 30.56 ,6.02
# alpha,beta: 25.13 ,18.19
# alpha,beta: 18.06 ,9.83
# alpha,beta: 11.74 ,3.82
# alpha,beta: 5.68 ,3.01
# alpha,beta: 42.06 ,10.96
# alpha,beta: 28.70 ,7.52
# alpha,beta: 3.46 ,3.33
# alpha,beta: 33.47 ,20.50
# alpha,beta: 10.19 ,3.93
# alpha,beta: 3.49 ,2.12
# alpha,beta: 14.16 ,13.04
# alpha,beta: 87.95 ,22.52
# alpha,beta: 36.15 ,7.73
# alpha,beta: 26.02 ,4.86
# alpha,beta: 27.14 ,12.51
# alpha,beta: 5.76 ,7.76
# alpha,beta: 15.75 ,7.15
# alpha,beta: 11.29 ,13.68
# alpha,beta: 5.55 ,1.97
# alpha,beta: 11.11 ,6.83
# alpha,beta: 88.71 ,10.14
# alpha,beta: 19.76 ,5.57
# alpha,beta: 12.00 ,4.39
# alpha,beta: 12.68 ,14.88
# alpha,beta: 8.56 ,5.55
# alpha,beta: 21.87 ,12.33
# alpha,beta: 7.64 ,2.28
# alpha,beta: 11.16 ,6.56
# alpha,beta: 14.12 ,2.66
# alpha,beta: 17.23 ,7.84
# alpha,beta: 9.62 ,4.41
# alpha,beta: 64.82 ,18.26
# alpha,beta: 48.70 ,10.43
# alpha,beta: 18.19 ,8.89
# alpha,beta: 14.91 ,5.69
# alpha,beta: 64.41 ,11.26
# alpha,beta: 5.56 ,2.05
# alpha,beta: 6.76 ,5.65
# alpha,beta: 5.82 ,1.83
# alpha,beta: 2.47 ,4.52
# alpha,beta: 56.68 ,7.88
# alpha,beta: 39.19 ,7.73
# alpha,beta: 1.14 ,3.52
# alpha,beta: 57.75 ,17.67
# alpha,beta: 36.91 ,18.28
# alpha,beta: 37.27 ,6.85
# alpha,beta: 7.59 ,8.63
# alpha,beta: 17.19 ,13.76
# alpha,beta: 41.35 ,17.63
# alpha,beta: 21.65 ,5.64
# alpha,beta: 7.00 ,4.63
# alpha,beta: 23.73 ,5.81
# alpha,beta: 12.01 ,6.92
# alpha,beta: 0.19 ,3.38
# alpha,beta: 43.56 ,10.34
# alpha,beta: 35.33 ,11.64
# alpha,beta: 3.59 ,3.55
# alpha,beta: 28.02 ,32.39
# alpha,beta: 12.13 ,3.63
# alpha,beta: 4.45 ,4.00
# alpha,beta: 8.83 ,13.55
# alpha,beta: 10.80 ,6.29
# alpha,beta: 21.34 ,12.33
# alpha,beta: 25.96 ,10.97
# alpha,beta: 23.45 ,10.40
# alpha,beta: 20.54 ,9.13
# alpha,beta: 47.65 ,12.94
# alpha,beta: 17.21 ,4.91
# alpha,beta: 8.49 ,4.62
# alpha,beta: 9.16 ,3.99
# alpha,beta: 5.68 ,3.58
# alpha,beta: 4.42 ,6.49
# alpha,beta: 14.64 ,11.52
# alpha,beta: 7.87 ,3.31
# alpha,beta: 12.03 ,5.96
# alpha,beta: 13.67 ,4.77
# alpha,beta: 22.19 ,7.40
# alpha,beta: 12.78 ,8.32
# alpha,beta: 15.88 ,5.86
# alpha,beta: 14.69 ,6.66
# alpha,beta: 12.72 ,7.71
# alpha,beta: 19.55 ,7.97
# alpha,beta: 37.00 ,10.85
# alpha,beta: 16.21 ,3.44
# alpha,beta: 35.09 ,18.34
# alpha,beta: 6.21 ,3.22
# alpha,beta: 8.60 ,5.94
# alpha,beta: 2.28 ,2.35
# alpha,beta: 44.61 ,16.10
# alpha,beta: 46.33 ,18.56
# alpha,beta: 37.01 ,14.81
# alpha,beta: 11.68 ,3.94
# alpha,beta: 27.53 ,11.67
# alpha,beta: 4.89 ,3.28
# alpha,beta: 25.41 ,17.97
# alpha,beta: 22.02 ,7.95
# alpha,beta: 31.25 ,12.27
# alpha,beta: 17.87 ,8.17
# alpha,beta: 23.90 ,7.32
# alpha,beta: 2.30 ,5.12
# alpha,beta: 32.64 ,19.13
# alpha,beta: 9.96 ,10.52
# alpha,beta: 43.94 ,12.24
# alpha,beta: 13.59 ,7.84
# alpha,beta: 37.04 ,18.47
# alpha,beta: 47.68 ,10.27
# alpha,beta: 5.26 ,4.16
# alpha,beta: 10.70 ,3.92
# alpha,beta: 7.69 ,2.70
# alpha,beta: 3.42 ,3.22
# alpha,beta: 7.86 ,5.44
# alpha,beta: 7.34 ,6.45
# alpha,beta: 28.30 ,4.67
# alpha,beta: 21.85 ,7.82
# alpha,beta: 35.48 ,10.33
# alpha,beta: 4.33 ,2.97
# alpha,beta: 6.27 ,5.44
# alpha,beta: 21.61 ,7.38
# alpha,beta: 13.39 ,2.83
# alpha,beta: 8.15 ,4.44
# alpha,beta: 71.41 ,8.96
# alpha,beta: 36.37 ,8.87
# alpha,beta: 19.32 ,7.51
# alpha,beta: 15.08 ,8.29
# alpha,beta: 16.27 ,4.32
# alpha,beta: 13.50 ,5.81
# alpha,beta: 28.46 ,9.33
# alpha,beta: 4.75 ,4.82
# alpha,beta: 16.66 ,5.83
# alpha,beta: 2.01 ,7.08
# alpha,beta: 21.44 ,4.60
# alpha,beta: 11.25 ,7.20
# alpha,beta: 33.91 ,8.31
# alpha,beta: 1.14 ,4.31
# alpha,beta: 37.00 ,21.72
# alpha,beta: 5.65 ,5.01
# alpha,beta: 4.63 ,4.53
# alpha,beta: 18.83 ,16.83
# alpha,beta: 27.19 ,9.75
# alpha,beta: 25.59 ,7.37
# alpha,beta: 12.63 ,3.96
# alpha,beta: -1.39 ,4.92
# alpha,beta: 10.69 ,5.46
# alpha,beta: 9.02 ,6.77
# alpha,beta: 15.04 ,10.43
# alpha,beta: 13.46 ,4.31
# alpha,beta: 29.41 ,5.03
# alpha,beta: 5.03 ,5.79
# alpha,beta: 38.75 ,11.66
# alpha,beta: 3.06 ,4.85
# alpha,beta: 9.71 ,9.00
# alpha,beta: 19.20 ,6.51
# alpha,beta: 9.80 ,4.33
# alpha,beta: 11.52 ,6.12
# alpha,beta: 4.18 ,3.39
# alpha,beta: 28.30 ,10.81
# alpha,beta: 52.97 ,8.96
# alpha,beta: 12.97 ,4.12
# alpha,beta: 64.92 ,18.51
# alpha,beta: 27.29 ,7.04
# alpha,beta: 22.15 ,9.16
# alpha,beta: 48.78 ,24.57
# alpha,beta: 48.37 ,11.23
# alpha,beta: 37.19 ,8.56
# alpha,beta: 20.40 ,6.58
# alpha,beta: 8.27 ,7.19
# alpha,beta: 18.75 ,6.61
# alpha,beta: 6.96 ,4.96
# alpha,beta: 4.74 ,3.67
# alpha,beta: 30.68 ,18.69
# alpha,beta: 6.58 ,2.45
# alpha,beta: 14.36 ,5.88
# alpha,beta: 9.14 ,9.41
# alpha,beta: 26.70 ,12.93
# alpha,beta: 1.55 ,6.99
# alpha,beta: 47.54 ,19.15
# alpha,beta: 12.31 ,5.28
# alpha,beta: 6.39 ,5.46
# alpha,beta: 15.76 ,8.26
# alpha,beta: 38.36 ,6.38
# alpha,beta: 2.47 ,3.30
# alpha,beta: 7.22 ,6.63
# alpha,beta: 19.09 ,5.25
# alpha,beta: 13.63 ,8.72
# alpha,beta: 6.54 ,8.98
# alpha,beta: 17.98 ,19.80
# alpha,beta: 8.87 ,5.82
# alpha,beta: 19.69 ,32.34
# alpha,beta: 17.81 ,6.49
# alpha,beta: 26.41 ,13.46
# alpha,beta: 10.80 ,6.02
# alpha,beta: 3.71 ,5.17
# alpha,beta: 4.67 ,4.05
# alpha,beta: 6.36 ,4.22
# alpha,beta: 28.58 ,5.52
# alpha,beta: 10.14 ,5.13
# alpha,beta: 7.25 ,4.88
# alpha,beta: 62.82 ,14.49
# alpha,beta: 5.03 ,8.17
# alpha,beta: 44.40 ,13.18
# alpha,beta: 7.40 ,3.77
# alpha,beta: 18.90 ,6.61
# alpha,beta: 6.63 ,8.87
# alpha,beta: 12.50 ,6.41
# alpha,beta: 20.03 ,7.51
# alpha,beta: 14.02 ,3.43
# alpha,beta: 32.72 ,8.12
# alpha,beta: 88.45 ,9.60
# alpha,beta: 42.47 ,8.48
# alpha,beta: 34.16 ,9.50
# alpha,beta: 11.72 ,10.51
# alpha,beta: 19.68 ,9.02
# alpha,beta: 15.44 ,9.10
# alpha,beta: 22.17 ,9.80
# alpha,beta: 53.43 ,5.48
# alpha,beta: 4.08 ,2.62
# alpha,beta: 5.96 ,3.72
# alpha,beta: 56.19 ,13.89
# alpha,beta: 10.46 ,5.41
# alpha,beta: 46.65 ,11.29
# alpha,beta: 7.42 ,4.99
# alpha,beta: 22.51 ,10.86
# alpha,beta: 0.78 ,3.60
# alpha,beta: 12.43 ,5.12
# alpha,beta: 11.78 ,4.59
# alpha,beta: 25.00 ,11.44
# alpha,beta: 11.48 ,5.01
# alpha,beta: 28.81 ,12.29
# alpha,beta: 7.02 ,6.78
# alpha,beta: 18.75 ,11.65
# alpha,beta: 147.00 ,12.76
# alpha,beta: 28.29 ,11.89
# alpha,beta: 16.68 ,7.92
# alpha,beta: 9.39 ,4.09
# alpha,beta: 17.93 ,8.11
# alpha,beta: 8.43 ,3.70
# alpha,beta: 12.41 ,4.78
# alpha,beta: 13.39 ,4.50
# alpha,beta: 35.39 ,5.83
# alpha,beta: 25.56 ,15.45
# alpha,beta: 21.81 ,11.90
# alpha,beta: 48.30 ,21.57
# alpha,beta: 10.87 ,7.18
# alpha,beta: 18.65 ,19.48
# alpha,beta: 21.54 ,8.18
# alpha,beta: 14.77 ,12.41
# alpha,beta: 6.46 ,6.28
# alpha,beta: 11.09 ,3.57
# alpha,beta: 14.61 ,6.00
# alpha,beta: 13.77 ,8.43
# alpha,beta: 7.66 ,4.70
# alpha,beta: 13.43 ,2.44
# alpha,beta: 48.36 ,16.42
# alpha,beta: 8.83 ,5.82
# alpha,beta: 8.34 ,3.17
# alpha,beta: 41.31 ,11.21
# alpha,beta: 14.33 ,14.27
# alpha,beta: 43.47 ,7.84
# alpha,beta: 81.86 ,21.19
# alpha,beta: 58.56 ,29.78
# alpha,beta: 20.17 ,4.89
# alpha,beta: 75.75 ,8.29
# alpha,beta: 52.86 ,16.81
# alpha,beta: 26.18 ,18.65
# alpha,beta: 13.81 ,7.61
# alpha,beta: 8.25 ,4.10
# alpha,beta: 65.42 ,21.67
# alpha,beta: 9.41 ,4.87
# alpha,beta: 10.67 ,5.52
# alpha,beta: 4.29 ,5.97
# alpha,beta: 8.24 ,5.42
# alpha,beta: 10.29 ,5.95
# alpha,beta: 1.22 ,10.41
# alpha,beta: 1.78 ,4.89
# alpha,beta: 13.87 ,4.39
# alpha,beta: 32.75 ,5.55
# alpha,beta: 8.08 ,5.55
# alpha,beta: 32.49 ,20.46
# alpha,beta: 19.85 ,15.67
# alpha,beta: 59.92 ,27.95
# alpha,beta: 13.25 ,15.77
# alpha,beta: 21.72 ,6.92
# alpha,beta: 29.12 ,18.62
# alpha,beta: 3.53 ,5.01
# alpha,beta: 1.50 ,10.69
# alpha,beta: 58.87 ,20.49
# alpha,beta: 2.70 ,4.96
# alpha,beta: 111.76 ,16.75
# alpha,beta: 11.73 ,6.29
# alpha,beta: 13.40 ,5.33
# alpha,beta: 25.86 ,6.76
# alpha,beta: 46.74 ,8.33
# alpha,beta: 8.74 ,6.27
# alpha,beta: 50.10 ,13.58
# alpha,beta: 9.01 ,4.04
# alpha,beta: 7.42 ,7.74
# alpha,beta: 43.80 ,9.76
# alpha,beta: 5.73 ,6.52
# alpha,beta: 49.24 ,22.74
# alpha,beta: 12.50 ,3.95
# alpha,beta: 25.22 ,9.97
# alpha,beta: 6.90 ,7.06
# alpha,beta: 55.61 ,10.84
# alpha,beta: 30.22 ,9.32
# alpha,beta: 18.42 ,12.38
# alpha,beta: 53.01 ,13.05
# alpha,beta: 16.51 ,6.13
# alpha,beta: 10.16 ,8.83
# alpha,beta: 28.58 ,8.36
# alpha,beta: 0.39 ,3.68
# alpha,beta: 17.92 ,25.16
# alpha,beta: 11.64 ,3.95
# alpha,beta: 6.13 ,2.04
# alpha,beta: 14.08 ,23.49
# alpha,beta: 65.71 ,16.25
# alpha,beta: 19.30 ,11.22
# alpha,beta: 7.46 ,4.13
# alpha,beta: 5.35 ,2.84
# alpha,beta: 110.18 ,31.59
# alpha,beta: 2.42 ,2.61
# alpha,beta: 17.91 ,18.27
# alpha,beta: 32.08 ,13.85
# alpha,beta: 33.12 ,9.55
# alpha,beta: 4.42 ,2.11
# alpha,beta: 58.97 ,14.55
# alpha,beta: 114.44 ,36.83
# alpha,beta: 12.29 ,9.49
# alpha,beta: 24.44 ,24.04
# alpha,beta: 86.44 ,26.13
# alpha,beta: 23.15 ,9.42
# alpha,beta: 32.30 ,7.96
# alpha,beta: 6.32 ,3.85
# alpha,beta: 19.49 ,14.00
# alpha,beta: 63.06 ,9.39
# alpha,beta: 10.06 ,3.88
# alpha,beta: 9.81 ,2.97
# alpha,beta: 47.63 ,13.64
# alpha,beta: 13.45 ,5.50
# alpha,beta: 1.59 ,2.99
# alpha,beta: 16.86 ,12.02
# alpha,beta: 5.60 ,6.89
# alpha,beta: 35.04 ,10.26
# alpha,beta: 17.17 ,15.70
# alpha,beta: 15.48 ,11.04
# alpha,beta: 6.62 ,3.52
# alpha,beta: 20.52 ,11.61
# alpha,beta: 21.28 ,6.99
# alpha,beta: 11.48 ,4.00
# alpha,beta: 40.41 ,9.32
# alpha,beta: 25.71 ,10.81
# alpha,beta: 5.78 ,4.75
# alpha,beta: 8.97 ,6.31
# alpha,beta: 3.74 ,2.84
# alpha,beta: 29.99 ,21.41
# alpha,beta: 51.39 ,11.74
# alpha,beta: 23.89 ,13.47
# alpha,beta: 17.23 ,17.37
# alpha,beta: 12.58 ,4.91
# alpha,beta: 8.95 ,2.57
# alpha,beta: 22.72 ,9.73
# alpha,beta: 7.18 ,6.64
# alpha,beta: 68.56 ,40.46
# alpha,beta: 43.40 ,10.91
# alpha,beta: 14.78 ,5.24
# alpha,beta: 20.13 ,15.06
# alpha,beta: 12.79 ,6.96
# alpha,beta: 21.60 ,5.82
# alpha,beta: 21.74 ,11.20
# alpha,beta: 9.62 ,3.83
# alpha,beta: 39.40 ,8.01
# alpha,beta: 7.38 ,6.93
# alpha,beta: 24.77 ,10.03
# alpha,beta: 17.89 ,5.02
# alpha,beta: 72.15 ,14.74
# alpha,beta: 18.83 ,12.47
# alpha,beta: 12.36 ,10.64
# alpha,beta: 45.01 ,18.34
# alpha,beta: 19.71 ,9.22
# alpha,beta: 5.92 ,4.27
# alpha,beta: 8.90 ,3.27
# alpha,beta: 40.45 ,11.87
# alpha,beta: 39.54 ,10.59
# alpha,beta: 55.08 ,9.38
# alpha,beta: 17.88 ,10.12
# alpha,beta: 8.00 ,3.62
# alpha,beta: 8.64 ,6.75
# alpha,beta: 109.70 ,25.62
# alpha,beta: 0.19 ,3.68
# alpha,beta: 5.26 ,3.69
# alpha,beta: 22.16 ,6.34
# alpha,beta: 18.89 ,6.57
# alpha,beta: 13.41 ,2.88
# alpha,beta: 61.23 ,9.86
# alpha,beta: 41.14 ,7.35
# alpha,beta: 16.38 ,10.70
# alpha,beta: 50.04 ,21.59
# alpha,beta: 6.93 ,6.04
# alpha,beta: 3.25 ,3.03
# alpha,beta: 25.23 ,11.80
# alpha,beta: 2.92 ,3.15
# alpha,beta: 1.77 ,3.22
# alpha,beta: 8.61 ,9.86
# alpha,beta: 8.39 ,4.43
# alpha,beta: 59.43 ,17.95
# alpha,beta: 68.67 ,12.91
# alpha,beta: 13.64 ,5.71
# alpha,beta: 14.19 ,6.49
# alpha,beta: 4.03 ,3.26
# alpha,beta: 8.34 ,6.69
# alpha,beta: 11.92 ,3.99
# alpha,beta: 11.86 ,7.53
# alpha,beta: 10.20 ,2.65
# alpha,beta: 10.31 ,4.28
# alpha,beta: 22.75 ,11.82
# alpha,beta: 7.20 ,8.01
# alpha,beta: 15.85 ,6.16
# alpha,beta: 19.26 ,7.97
# alpha,beta: 27.70 ,11.28
# alpha,beta: 24.36 ,13.32
# alpha,beta: 11.68 ,4.34
# alpha,beta: 13.98 ,3.92
# alpha,beta: 25.09 ,6.15
# alpha,beta: 10.98 ,6.51
# alpha,beta: 19.66 ,7.13
# alpha,beta: 31.11 ,24.67
# alpha,beta: 53.34 ,9.42
# alpha,beta: 7.59 ,7.35
# alpha,beta: 46.07 ,12.72
# alpha,beta: 10.64 ,10.49
# alpha,beta: 4.36 ,4.39
# alpha,beta: 17.68 ,10.94
# alpha,beta: 16.36 ,5.36
# alpha,beta: 18.58 ,12.09
# alpha,beta: 14.84 ,7.92
# alpha,beta: 7.18 ,3.72
# alpha,beta: 2.50 ,3.19
# alpha,beta: 6.58 ,3.62
# alpha,beta: 15.22 ,8.26
# alpha,beta: 5.43 ,3.84
# alpha,beta: 49.39 ,8.90
# alpha,beta: 6.06 ,7.54
# alpha,beta: 21.04 ,4.66
# alpha,beta: 12.20 ,5.21
# alpha,beta: 18.24 ,7.96
# alpha,beta: 3.43 ,2.93
# alpha,beta: 44.46 ,12.18
# alpha,beta: 4.90 ,12.90
# alpha,beta: 87.32 ,10.64
# alpha,beta: 11.37 ,7.87
# alpha,beta: 19.52 ,6.82
# alpha,beta: 14.87 ,9.14
# alpha,beta: 27.12 ,12.52
# alpha,beta: 7.30 ,5.82
# alpha,beta: 4.90 ,5.01
# alpha,beta: 38.74 ,17.03
# alpha,beta: 3.16 ,3.47
# alpha,beta: 38.86 ,11.59
# alpha,beta: 12.14 ,7.06
# alpha,beta: 5.11 ,4.08
# alpha,beta: 12.58 ,5.74
# alpha,beta: 43.23 ,9.54
# alpha,beta: 1.31 ,3.21
# alpha,beta: 16.28 ,17.70
# alpha,beta: 32.63 ,8.36
# alpha,beta: 56.73 ,17.73
# alpha,beta: 31.56 ,17.25
# alpha,beta: 10.63 ,6.98
# alpha,beta: 53.82 ,19.39
# alpha,beta: 30.36 ,12.03
# alpha,beta: 2.97 ,4.68
# alpha,beta: 24.48 ,8.02
# alpha,beta: 79.74 ,13.10
# alpha,beta: 52.14 ,17.69
# alpha,beta: 5.45 ,3.18
# alpha,beta: 42.35 ,8.23
# alpha,beta: 24.94 ,13.29
# alpha,beta: 5.49 ,5.89
# alpha,beta: 4.92 ,4.44
# alpha,beta: 38.83 ,28.09
# alpha,beta: 10.97 ,4.74
# alpha,beta: 4.73 ,5.57
# alpha,beta: 1.84 ,4.79
# alpha,beta: 12.73 ,4.76
# alpha,beta: 4.40 ,4.35
# alpha,beta: 18.97 ,9.24
# alpha,beta: 4.93 ,3.01
# alpha,beta: 4.84 ,4.18
# alpha,beta: 8.90 ,4.73
# alpha,beta: 25.19 ,9.11
# alpha,beta: 20.47 ,5.22
# alpha,beta: 2.61 ,8.52
# alpha,beta: 13.04 ,8.73
# alpha,beta: 56.01 ,19.32
# alpha,beta: 60.94 ,16.82
# alpha,beta: 24.10 ,18.79
# alpha,beta: 10.25 ,6.17
# alpha,beta: 45.64 ,25.49
# alpha,beta: 50.05 ,10.10
# alpha,beta: 49.11 ,22.50
# alpha,beta: 2.08 ,3.33
# alpha,beta: 37.61 ,10.01
# alpha,beta: 8.43 ,6.79
# alpha,beta: 11.28 ,5.35
# alpha,beta: 8.66 ,9.08
# alpha,beta: 10.40 ,4.63
# alpha,beta: 9.59 ,4.37
# alpha,beta: 9.09 ,4.13
# alpha,beta: 17.31 ,15.35
# alpha,beta: 48.59 ,15.65
# alpha,beta: 7.60 ,4.16
# alpha,beta: 19.23 ,8.95
# alpha,beta: 25.49 ,13.64
# alpha,beta: 6.73 ,3.15
# alpha,beta: 97.93 ,22.07
# alpha,beta: 67.32 ,15.49
# alpha,beta: 4.44 ,3.94
# alpha,beta: 14.68 ,11.92
# alpha,beta: 21.46 ,6.61
# alpha,beta: 36.68 ,12.72
# alpha,beta: 2.57 ,3.61
# alpha,beta: 48.19 ,11.80
# alpha,beta: 21.70 ,6.47
# alpha,beta: 10.04 ,5.23
# alpha,beta: 30.34 ,9.81
# alpha,beta: 21.85 ,8.15
# alpha,beta: 44.72 ,28.78
# alpha,beta: 37.70 ,14.02
# alpha,beta: 8.09 ,6.63
# alpha,beta: 7.97 ,5.28
# alpha,beta: 41.83 ,16.00
# alpha,beta: 3.47 ,3.11
# alpha,beta: 17.66 ,6.37
# alpha,beta: 18.21 ,10.56
# alpha,beta: 14.13 ,5.16
# alpha,beta: 14.28 ,7.89
# alpha,beta: 5.92 ,2.61
# alpha,beta: 29.80 ,6.81
# alpha,beta: 28.04 ,11.90
# alpha,beta: 2.92 ,4.46
# alpha,beta: 5.35 ,4.90
# alpha,beta: 12.45 ,8.70
# alpha,beta: 8.98 ,7.25
# alpha,beta: 11.71 ,4.77
# alpha,beta: 6.47 ,8.06
# alpha,beta: 20.93 ,9.56
# alpha,beta: 14.17 ,10.86
# alpha,beta: 21.41 ,19.19
# alpha,beta: 12.73 ,11.12
# alpha,beta: 8.96 ,11.62
# alpha,beta: 16.38 ,9.86
# alpha,beta: 5.56 ,35.10
# alpha,beta: 8.81 ,3.12
# alpha,beta: 7.50 ,10.15
# alpha,beta: 9.71 ,5.20
# alpha,beta: 12.06 ,7.48
# alpha,beta: 26.18 ,8.02
# alpha,beta: 8.31 ,6.35
# alpha,beta: 22.06 ,15.20
# alpha,beta: 7.45 ,5.21
# alpha,beta: 17.37 ,23.59
# alpha,beta: 14.68 ,12.24
# alpha,beta: 39.63 ,12.37
# alpha,beta: 21.22 ,5.13
# alpha,beta: 5.24 ,5.79
# alpha,beta: 18.93 ,9.11
# alpha,beta: 7.46 ,4.67
# alpha,beta: 5.76 ,4.49
# alpha,beta: 101.29 ,14.93
# alpha,beta: 15.30 ,4.49
# alpha,beta: 20.64 ,7.47
# alpha,beta: 19.49 ,8.43
# alpha,beta: 8.14 ,3.18
# alpha,beta: 1.87 ,3.59
# alpha,beta: 6.09 ,5.10
# alpha,beta: 30.03 ,16.57
# alpha,beta: 9.95 ,4.53
# alpha,beta: 21.35 ,11.85
# alpha,beta: 4.02 ,5.25
# alpha,beta: 31.95 ,9.08
# alpha,beta: 7.67 ,5.34
# alpha,beta: 11.61 ,9.09
# alpha,beta: 15.35 ,13.97
# alpha,beta: 31.30 ,13.82
# alpha,beta: 9.73 ,3.72
# alpha,beta: 30.97 ,5.31
# alpha,beta: 47.83 ,18.57
# alpha,beta: 19.24 ,21.57
# alpha,beta: 29.37 ,7.29
# alpha,beta: 0.96 ,4.15
# alpha,beta: 17.58 ,8.68
# alpha,beta: 17.36 ,7.71
# alpha,beta: 18.83 ,7.57
# alpha,beta: 25.18 ,9.06
# alpha,beta: 8.57 ,7.39
# alpha,beta: 36.05 ,14.01
# alpha,beta: 10.36 ,7.31
# alpha,beta: 17.10 ,6.49
# alpha,beta: 6.44 ,11.45
# alpha,beta: 19.46 ,12.20
# alpha,beta: 36.96 ,8.35
# alpha,beta: 41.97 ,23.37
# alpha,beta: 34.64 ,11.34
# alpha,beta: 90.28 ,21.54
# alpha,beta: 44.93 ,19.64
# alpha,beta: 15.76 ,8.44
# alpha,beta: 35.08 ,16.00
# alpha,beta: 7.93 ,9.14
# alpha,beta: 4.91 ,9.38
# alpha,beta: 10.86 ,7.45
# alpha,beta: 9.34 ,7.62
# alpha,beta: 41.52 ,10.60
# alpha,beta: 54.02 ,19.89
# alpha,beta: 13.27 ,3.66
# alpha,beta: 37.63 ,8.27
# alpha,beta: 4.07 ,6.74
# alpha,beta: 22.15 ,8.91
# alpha,beta: 112.68 ,18.12
# alpha,beta: 11.96 ,9.19
# alpha,beta: 18.01 ,10.71
# alpha,beta: 15.86 ,6.21
# alpha,beta: 14.45 ,3.62
# alpha,beta: 41.91 ,12.44
# alpha,beta: 25.50 ,11.79
# alpha,beta: 94.69 ,24.79
# alpha,beta: 21.54 ,6.62
# alpha,beta: 8.31 ,3.66
# alpha,beta: 4.55 ,3.95
# alpha,beta: 8.68 ,4.61
# alpha,beta: 3.20 ,7.21
# alpha,beta: 3.39 ,3.91
# alpha,beta: 20.79 ,7.97
# alpha,beta: 3.17 ,3.32
# alpha,beta: 9.68 ,5.23
# alpha,beta: 32.99 ,9.97
# alpha,beta: 10.62 ,2.99
# alpha,beta: 77.64 ,26.82
# alpha,beta: 13.31 ,9.75
# alpha,beta: 57.45 ,11.57
# alpha,beta: 37.34 ,11.12
# alpha,beta: 7.71 ,6.85
# alpha,beta: 8.22 ,5.13
# alpha,beta: 6.16 ,11.85
# alpha,beta: 29.97 ,12.84
# alpha,beta: 29.63 ,7.75
# alpha,beta: 33.25 ,13.81
# alpha,beta: 25.14 ,14.11
# alpha,beta: 5.93 ,3.59
# alpha,beta: 16.57 ,7.48
# alpha,beta: 10.79 ,7.36
# alpha,beta: 12.02 ,6.41
# alpha,beta: 13.05 ,14.95
# alpha,beta: 38.68 ,7.92
# alpha,beta: 19.70 ,6.10
# alpha,beta: 31.66 ,8.49
# alpha,beta: 19.20 ,6.05
# alpha,beta: 28.97 ,19.98
# alpha,beta: 21.38 ,15.93
# alpha,beta: 15.24 ,8.93
# alpha,beta: 14.24 ,5.87
# alpha,beta: 18.06 ,7.37
# alpha,beta: -0.75 ,8.02
# alpha,beta: 17.01 ,6.06
# alpha,beta: 8.14 ,10.52
# alpha,beta: 9.25 ,9.87
# alpha,beta: 5.66 ,4.78
# alpha,beta: 48.99 ,11.12
# alpha,beta: 106.78 ,35.73
# alpha,beta: 23.59 ,15.07
# alpha,beta: 9.82 ,6.82
# alpha,beta: 60.12 ,19.07
# alpha,beta: 9.25 ,4.14
# alpha,beta: 21.86 ,7.30
# alpha,beta: 19.11 ,10.86
# alpha,beta: 52.12 ,22.92
# alpha,beta: 36.17 ,15.46
# alpha,beta: 6.99 ,6.95
# alpha,beta: 16.38 ,12.91
# alpha,beta: 66.18 ,20.27
# alpha,beta: 23.33 ,7.12
# alpha,beta: 26.61 ,6.89
# alpha,beta: 14.59 ,6.45
# alpha,beta: 25.63 ,8.61
# alpha,beta: 39.43 ,13.34
# alpha,beta: 5.22 ,2.99
# alpha,beta: 23.66 ,7.80
# alpha,beta: 12.33 ,11.87
# alpha,beta: 13.99 ,5.58
# alpha,beta: 7.25 ,3.99
# alpha,beta: 40.99 ,17.21
# alpha,beta: 136.16 ,15.12
# alpha,beta: 9.94 ,9.70
# alpha,beta: 14.37 ,6.15
# alpha,beta: 72.48 ,14.42
# alpha,beta: 13.48 ,12.94
# alpha,beta: 7.87 ,8.30
# alpha,beta: 43.28 ,8.69
# alpha,beta: 7.45 ,5.72
# alpha,beta: 19.42 ,18.63
# alpha,beta: 31.80 ,9.45
# alpha,beta: 15.20 ,6.69
# alpha,beta: 16.31 ,8.14
# alpha,beta: 11.09 ,4.54
# alpha,beta: 7.35 ,4.53
# alpha,beta: 2.52 ,4.36
# alpha,beta: 30.27 ,15.71
# alpha,beta: 11.27 ,8.33
# alpha,beta: 31.79 ,9.56
# alpha,beta: 23.74 ,12.81
# alpha,beta: 36.28 ,16.93
# alpha,beta: 20.59 ,6.96
# alpha,beta: 71.59 ,19.66
# alpha,beta: 13.06 ,11.00
# alpha,beta: 4.31 ,3.83
# alpha,beta: 53.46 ,14.17
# alpha,beta: 2.00 ,5.45
# alpha,beta: 62.69 ,11.19
# alpha,beta: 11.43 ,27.33
# alpha,beta: 8.39 ,5.34
# alpha,beta: 13.37 ,10.63
# alpha,beta: 15.83 ,6.05
# alpha,beta: 36.41 ,12.61
# alpha,beta: 52.66 ,19.68
# alpha,beta: 1.81 ,5.78
# alpha,beta: 34.03 ,19.18
# alpha,beta: 8.75 ,16.95
# alpha,beta: 32.37 ,19.11
# alpha,beta: 34.93 ,10.88
# alpha,beta: 57.46 ,22.36
# alpha,beta: 26.12 ,24.64
# alpha,beta: 22.95 ,8.43
# alpha,beta: 9.23 ,7.26
# alpha,beta: 20.78 ,7.12
# alpha,beta: 69.69 ,13.89
# alpha,beta: 2.51 ,4.07
# alpha,beta: 34.11 ,10.18
# alpha,beta: 18.05 ,6.80
# alpha,beta: 10.90 ,4.02
# alpha,beta: 1.33 ,3.84
# alpha,beta: 27.17 ,7.72
# alpha,beta: 60.43 ,17.19
# alpha,beta: 2.53 ,3.15
# alpha,beta: 18.50 ,6.48
# alpha,beta: 17.07 ,6.19
# alpha,beta: 25.80 ,13.38
# alpha,beta: 1.95 ,4.23
# alpha,beta: 24.64 ,8.06
# alpha,beta: 15.95 ,7.08
# alpha,beta: 24.50 ,15.15
# alpha,beta: 7.69 ,3.36
# alpha,beta: 40.90 ,8.72
# alpha,beta: 18.87 ,7.92
# alpha,beta: 69.88 ,11.21
# alpha,beta: 18.10 ,7.20
# alpha,beta: 4.55 ,3.53
# alpha,beta: 10.91 ,6.19
# alpha,beta: 6.27 ,11.98
# alpha,beta: 19.54 ,15.59
# alpha,beta: 67.86 ,23.51
# alpha,beta: 4.04 ,3.69
# alpha,beta: 16.51 ,12.14
# alpha,beta: 52.03 ,17.04
# alpha,beta: 17.26 ,9.20
# alpha,beta: 1.06 ,8.37
# alpha,beta: 8.13 ,5.13
# alpha,beta: 13.04 ,13.66
# alpha,beta: 23.21 ,11.69
# alpha,beta: 9.76 ,6.60
# alpha,beta: 21.39 ,23.49
# alpha,beta: 14.21 ,6.28
# alpha,beta: 30.58 ,23.08
# alpha,beta: 2.73 ,4.37
# alpha,beta: 0.22 ,6.41
# alpha,beta: 15.60 ,10.25
# alpha,beta: 30.06 ,14.65
# alpha,beta: 13.85 ,8.11
# alpha,beta: 15.02 ,4.20
# alpha,beta: 14.99 ,7.91
# alpha,beta: 25.77 ,7.00
# alpha,beta: 50.64 ,22.58
# alpha,beta: 12.34 ,8.79
# alpha,beta: 10.65 ,4.34
# alpha,beta: 9.65 ,12.14
# alpha,beta: 3.84 ,4.78
# alpha,beta: 95.34 ,19.08
# alpha,beta: 30.72 ,12.88
# alpha,beta: -2.22 ,4.22
# alpha,beta: 11.89 ,7.89
# alpha,beta: 8.10 ,7.79
# alpha,beta: 21.78 ,16.65
# alpha,beta: 12.78 ,8.72
# alpha,beta: 13.04 ,11.26
# alpha,beta: 1.16 ,6.17
# alpha,beta: 4.33 ,4.55
# alpha,beta: 8.80 ,6.03
# alpha,beta: 17.39 ,8.36
# alpha,beta: 4.84 ,5.58
# alpha,beta: 21.88 ,10.03
# alpha,beta: 10.24 ,6.56
# alpha,beta: 7.76 ,7.89
# alpha,beta: 11.69 ,7.04
# alpha,beta: 50.92 ,8.69
# alpha,beta: 9.85 ,12.12
# alpha,beta: 12.12 ,3.83
# alpha,beta: 5.48 ,2.81
# alpha,beta: 28.28 ,18.67
# alpha,beta: 25.44 ,17.50
# alpha,beta: 38.88 ,11.19
# alpha,beta: 22.52 ,9.36
# alpha,beta: 14.52 ,11.51
# alpha,beta: 2.99 ,4.34
# alpha,beta: 49.65 ,19.30
# alpha,beta: 18.37 ,6.46
# alpha,beta: 13.16 ,8.24
# alpha,beta: 16.03 ,8.02
# alpha,beta: 10.63 ,7.04
# alpha,beta: 6.60 ,4.78
# alpha,beta: 18.51 ,11.39
# alpha,beta: 39.82 ,23.11
# alpha,beta: 32.15 ,7.99
# alpha,beta: 34.46 ,18.32
# alpha,beta: 8.51 ,8.34
# alpha,beta: 22.16 ,8.79
# alpha,beta: 19.33 ,13.11
# alpha,beta: 43.74 ,19.46
# alpha,beta: 51.20 ,20.79
# alpha,beta: 71.93 ,17.38
# alpha,beta: 15.54 ,8.10
# alpha,beta: 6.38 ,5.52
# alpha,beta: 3.40 ,5.29
# alpha,beta: 12.83 ,15.68
# alpha,beta: 51.29 ,10.67
# alpha,beta: 24.81 ,10.46
# alpha,beta: 10.48 ,8.51
# alpha,beta: 10.05 ,4.84
# alpha,beta: 53.06 ,15.82
# alpha,beta: 16.26 ,6.12
# alpha,beta: 30.48 ,14.46
# alpha,beta: 87.88 ,11.06
# alpha,beta: 25.53 ,9.10
# alpha,beta: 16.26 ,14.13
# alpha,beta: 25.15 ,9.64
# alpha,beta: 6.85 ,10.12
# alpha,beta: 19.98 ,11.38
# alpha,beta: 19.36 ,10.74
# alpha,beta: 5.63 ,4.86
# alpha,beta: 19.01 ,12.78
# alpha,beta: 7.56 ,3.45
# alpha,beta: 45.88 ,19.06
# alpha,beta: 9.79 ,5.59
# alpha,beta: 60.92 ,24.48
# alpha,beta: 34.82 ,13.52
# alpha,beta: 12.53 ,10.54
# alpha,beta: 5.69 ,4.56
# alpha,beta: 23.53 ,12.31
# alpha,beta: 27.09 ,15.72
# alpha,beta: 33.13 ,18.89
# alpha,beta: 17.82 ,8.01
# alpha,beta: 33.01 ,12.54
# alpha,beta: 8.16 ,4.69
# alpha,beta: 3.60 ,3.46
# alpha,beta: 52.49 ,17.53
# alpha,beta: 17.75 ,12.29
# alpha,beta: 12.47 ,4.77
# alpha,beta: 12.33 ,3.40
# alpha,beta: 49.84 ,17.23
# alpha,beta: 29.65 ,7.09
# alpha,beta: 23.44 ,22.87
# alpha,beta: 6.11 ,5.64
# alpha,beta: 17.78 ,6.05
# alpha,beta: 17.45 ,18.39
# alpha,beta: 18.63 ,10.19
# alpha,beta: 12.58 ,7.30
# alpha,beta: 47.56 ,14.35
# alpha,beta: 17.83 ,11.01
# alpha,beta: 3.69 ,12.46
# alpha,beta: 8.28 ,5.83
# alpha,beta: 31.27 ,24.07
# alpha,beta: 4.54 ,3.44
# alpha,beta: 29.75 ,12.25
# alpha,beta: 13.83 ,6.98
# alpha,beta: 16.60 ,19.54
# alpha,beta: 17.73 ,8.15
# alpha,beta: 11.74 ,22.29
# alpha,beta: 11.62 ,4.90
# alpha,beta: 34.83 ,9.09
# alpha,beta: 5.55 ,7.38
# alpha,beta: 35.66 ,18.75
# alpha,beta: 68.38 ,18.06
# alpha,beta: 36.83 ,24.20
# alpha,beta: 20.75 ,14.50
# alpha,beta: 32.61 ,22.40
# alpha,beta: 49.02 ,19.27
# alpha,beta: 23.21 ,15.58
# alpha,beta: 24.48 ,14.43
# alpha,beta: 10.36 ,7.84
# alpha,beta: 30.13 ,20.83
# alpha,beta: 20.61 ,7.92
# alpha,beta: 18.92 ,8.13
# alpha,beta: 33.14 ,13.50
# alpha,beta: 44.53 ,13.27
# alpha,beta: 130.07 ,30.73
# alpha,beta: 44.04 ,14.18
# alpha,beta: 8.16 ,4.37
# alpha,beta: 36.66 ,9.33
# alpha,beta: 37.19 ,14.24
# alpha,beta: 16.17 ,8.29
# alpha,beta: 16.60 ,4.97
# alpha,beta: 13.50 ,10.13
# alpha,beta: 8.63 ,5.21
# alpha,beta: 25.02 ,10.57
# alpha,beta: 8.57 ,8.37
# alpha,beta: 14.33 ,4.65
# alpha,beta: 24.87 ,8.60
# alpha,beta: 87.38 ,30.27
# alpha,beta: 37.02 ,14.73
# alpha,beta: 1.13 ,4.51
# alpha,beta: 14.62 ,5.42
# alpha,beta: 3.64 ,11.31
# alpha,beta: 15.67 ,8.08
# alpha,beta: 27.82 ,21.27
# alpha,beta: 15.10 ,10.62
# alpha,beta: 12.88 ,10.44
# alpha,beta: 52.82 ,17.46
# alpha,beta: 10.80 ,12.01
# alpha,beta: 22.94 ,11.70
# alpha,beta: 35.89 ,42.78
# alpha,beta: 84.22 ,20.01
# alpha,beta: 22.09 ,10.24
# alpha,beta: 28.79 ,22.36
# alpha,beta: 16.45 ,4.76
# alpha,beta: 22.36 ,16.51
# alpha,beta: 6.51 ,5.31
# alpha,beta: 8.07 ,12.98
# alpha,beta: 4.87 ,6.20
# alpha,beta: 47.73 ,14.40
# alpha,beta: 4.28 ,6.86
# alpha,beta: 24.37 ,12.62
# alpha,beta: 18.27 ,4.31
# alpha,beta: 70.04 ,12.37
# alpha,beta: 4.65 ,6.02
# alpha,beta: 41.96 ,16.48
# alpha,beta: 2.71 ,8.49
# alpha,beta: 89.21 ,26.25
# alpha,beta: 22.63 ,24.24
# alpha,beta: 17.07 ,7.74
# alpha,beta: 10.99 ,13.65
# alpha,beta: 14.97 ,11.22
# alpha,beta: 35.03 ,16.99
# alpha,beta: 27.92 ,31.02
# alpha,beta: 79.84 ,15.59
# alpha,beta: 20.52 ,9.22
# alpha,beta: 11.57 ,9.38
# alpha,beta: 9.01 ,5.25
# alpha,beta: 6.65 ,5.43
# alpha,beta: 42.63 ,15.14
# alpha,beta: 48.55 ,14.98
# alpha,beta: 10.50 ,5.03
# alpha,beta: 39.64 ,13.99
# alpha,beta: 12.76 ,12.83
# alpha,beta: 6.51 ,5.77
# alpha,beta: 11.12 ,7.90
# alpha,beta: 16.59 ,5.17
# alpha,beta: 6.45 ,4.91
# alpha,beta: 7.67 ,5.82
# alpha,beta: 14.54 ,7.62
# alpha,beta: 15.87 ,6.24
# alpha,beta: 5.91 ,5.29
# alpha,beta: 4.08 ,6.82
# alpha,beta: 22.12 ,32.68
# alpha,beta: 14.28 ,12.22
# alpha,beta: 25.32 ,11.38
# alpha,beta: 56.88 ,26.88
# alpha,beta: 4.35 ,6.44
# alpha,beta: 8.53 ,7.00
# alpha,beta: 5.93 ,5.61
# alpha,beta: 37.99 ,12.29
# alpha,beta: 18.59 ,10.37
# alpha,beta: 21.07 ,20.91
# alpha,beta: 10.44 ,9.89
# alpha,beta: 25.38 ,11.35
# alpha,beta: 6.64 ,8.48
# alpha,beta: 27.52 ,10.82
# alpha,beta: 71.29 ,25.57
# alpha,beta: 27.88 ,14.76
# alpha,beta: 20.93 ,14.95
# alpha,beta: 16.20 ,6.34
# alpha,beta: 33.89 ,19.33
# alpha,beta: 19.47 ,13.45
# alpha,beta: 53.46 ,14.07
# alpha,beta: 16.65 ,5.13
# alpha,beta: 55.78 ,16.57
# alpha,beta: 10.37 ,11.12
# alpha,beta: 10.64 ,8.46
# alpha,beta: 60.74 ,25.03
# alpha,beta: 4.06 ,15.80
# alpha,beta: 48.88 ,16.97
# alpha,beta: 14.04 ,10.90
# alpha,beta: 12.01 ,5.84
# alpha,beta: 10.31 ,6.12
# alpha,beta: 14.60 ,9.38
# alpha,beta: 6.71 ,4.22
# alpha,beta: 7.95 ,10.31
# alpha,beta: 20.19 ,12.14
# alpha,beta: 67.01 ,15.15
# alpha,beta: 32.04 ,8.88
# alpha,beta: 19.81 ,16.84
# alpha,beta: 3.74 ,6.36
# alpha,beta: 34.61 ,15.44
# alpha,beta: 49.47 ,13.53
# alpha,beta: 9.91 ,8.20
# alpha,beta: 18.46 ,9.67
# alpha,beta: 18.37 ,7.79
# alpha,beta: 41.94 ,21.36
# alpha,beta: 1.89 ,5.24
# alpha,beta: 25.24 ,9.04
# alpha,beta: 8.33 ,5.51
# alpha,beta: 19.12 ,11.43
# alpha,beta: 64.43 ,19.51
# alpha,beta: 21.97 ,17.17
# alpha,beta: 97.22 ,29.12
# alpha,beta: 17.01 ,7.59
# alpha,beta: 59.98 ,22.29
# alpha,beta: 37.27 ,17.43
# alpha,beta: 53.17 ,12.01
# alpha,beta: 19.90 ,6.05
# alpha,beta: 46.68 ,10.08
# alpha,beta: 16.67 ,10.10
# alpha,beta: 22.55 ,16.27
# alpha,beta: 17.53 ,10.36
# alpha,beta: 11.37 ,9.39
# alpha,beta: 49.39 ,17.51
# alpha,beta: 14.31 ,12.42
# alpha,beta: 7.03 ,6.35
# alpha,beta: 16.88 ,4.66
# alpha,beta: 54.59 ,27.88
# alpha,beta: 66.59 ,25.02
# alpha,beta: 22.94 ,6.73
# alpha,beta: 3.17 ,6.73
# alpha,beta: 33.08 ,12.78
# alpha,beta: 19.03 ,8.68
# alpha,beta: 16.16 ,6.03
# alpha,beta: 10.59 ,10.61
# alpha,beta: 21.30 ,11.31
# alpha,beta: 32.03 ,27.52
# alpha,beta: 7.69 ,7.68
# alpha,beta: 8.54 ,7.04
# alpha,beta: 30.01 ,8.19
# alpha,beta: 29.93 ,22.37
# alpha,beta: 41.98 ,19.15
# alpha,beta: 10.56 ,8.81
# alpha,beta: 6.22 ,2.86
# alpha,beta: 29.67 ,28.10
# alpha,beta: 11.22 ,11.17
# alpha,beta: 23.86 ,19.38
# alpha,beta: 8.43 ,13.50
# alpha,beta: 15.93 ,10.43
# alpha,beta: 37.01 ,23.79
# alpha,beta: 33.37 ,17.01
# alpha,beta: 40.14 ,13.64
# alpha,beta: 13.02 ,7.69
# alpha,beta: 7.29 ,14.94
# alpha,beta: 72.55 ,21.42
# alpha,beta: 12.69 ,8.06
# alpha,beta: 44.27 ,27.26
# alpha,beta: 24.93 ,7.58
# alpha,beta: 25.98 ,27.89
# alpha,beta: 15.57 ,7.07
# alpha,beta: 11.57 ,8.82
# alpha,beta: 49.12 ,13.33
# alpha,beta: 18.01 ,7.72
# alpha,beta: 14.46 ,8.31
# alpha,beta: 14.67 ,22.35
# alpha,beta: 15.17 ,8.96
# alpha,beta: 18.11 ,9.73
# alpha,beta: 53.00 ,32.50
# alpha,beta: 18.78 ,9.82
# alpha,beta: 5.64 ,5.84
# alpha,beta: 41.01 ,8.17
# alpha,beta: 42.26 ,18.41
# alpha,beta: 46.75 ,14.42
# alpha,beta: 45.24 ,13.31
# alpha,beta: 127.90 ,26.02
# alpha,beta: 34.20 ,28.37
# alpha,beta: 44.06 ,41.61
# alpha,beta: 19.62 ,19.53
# alpha,beta: 2.02 ,4.10
# alpha,beta: 21.42 ,15.46
# alpha,beta: 25.76 ,18.31
# alpha,beta: 25.98 ,18.49
# alpha,beta: 24.91 ,11.64
# alpha,beta: 5.96 ,5.14
# alpha,beta: 30.62 ,24.80
# alpha,beta: 46.41 ,16.69
# alpha,beta: 6.06 ,6.43
# alpha,beta: 11.96 ,16.50
# alpha,beta: 14.46 ,11.02
# alpha,beta: 6.34 ,8.94
# alpha,beta: 29.18 ,14.21
# alpha,beta: 32.51 ,15.54
# alpha,beta: 13.12 ,9.69
# alpha,beta: 1.97 ,7.50
# alpha,beta: 9.33 ,11.08
# alpha,beta: 8.89 ,8.95
# alpha,beta: 6.20 ,8.14
# alpha,beta: 15.53 ,11.49
# alpha,beta: 26.64 ,11.20
# alpha,beta: 28.68 ,14.55
# alpha,beta: 12.67 ,6.28
# alpha,beta: 8.94 ,7.52
# alpha,beta: 19.30 ,9.54
# alpha,beta: 14.29 ,8.16
# alpha,beta: 59.09 ,27.40
# alpha,beta: 44.39 ,15.74
# alpha,beta: 23.66 ,12.40
# alpha,beta: 23.21 ,17.51
# alpha,beta: 52.73 ,23.57
# alpha,beta: 25.96 ,15.92
# alpha,beta: 56.02 ,21.58
# alpha,beta: 28.16 ,15.92
# alpha,beta: 18.69 ,6.83
# alpha,beta: 27.30 ,13.71
# alpha,beta: 48.11 ,12.92
# alpha,beta: 11.66 ,13.61
# alpha,beta: 41.37 ,26.86
# alpha,beta: 27.27 ,19.17
# alpha,beta: 7.14 ,9.18
# alpha,beta: 5.26 ,6.09
# alpha,beta: 8.64 ,6.94
# alpha,beta: 9.30 ,8.14
# alpha,beta: 6.62 ,5.13
# alpha,beta: 10.97 ,11.15
# alpha,beta: 60.51 ,15.70
# alpha,beta: 35.42 ,21.00
# alpha,beta: 21.91 ,12.83
# alpha,beta: 21.05 ,17.20
# alpha,beta: 33.56 ,15.41
# alpha,beta: 5.56 ,6.40
# alpha,beta: 28.85 ,22.17
# alpha,beta: 67.29 ,25.85
# alpha,beta: 25.74 ,16.15
# alpha,beta: 16.17 ,10.69
# alpha,beta: 20.27 ,18.42
# alpha,beta: 45.00 ,13.04
# alpha,beta: 16.39 ,10.26
# alpha,beta: 46.22 ,16.23
# alpha,beta: 11.44 ,9.10
# alpha,beta: 53.26 ,19.84
# alpha,beta: 24.15 ,11.18
# alpha,beta: 32.08 ,12.59
# alpha,beta: 9.82 ,7.10
# alpha,beta: 20.10 ,10.76
# alpha,beta: 29.80 ,14.20
# alpha,beta: 23.46 ,23.03
# alpha,beta: 40.51 ,18.09
# alpha,beta: 6.34 ,10.09
# alpha,beta: 37.98 ,20.30
# alpha,beta: 12.10 ,8.89
# alpha,beta: 22.61 ,11.87
# alpha,beta: 14.78 ,13.18
# alpha,beta: 20.24 ,20.98
# alpha,beta: 24.29 ,12.90
# alpha,beta: 35.06 ,15.61
# alpha,beta: 48.55 ,21.59
# alpha,beta: 11.50 ,10.45
# alpha,beta: 17.80 ,8.45
# alpha,beta: 132.45 ,19.83
# alpha,beta: 9.74 ,8.25
# alpha,beta: 55.50 ,19.84
# alpha,beta: 15.31 ,14.98
# alpha,beta: 4.26 ,8.91
# alpha,beta: 39.13 ,21.74
# alpha,beta: 5.67 ,6.95
# alpha,beta: 25.36 ,13.09
# alpha,beta: 23.06 ,7.48
# alpha,beta: 36.27 ,14.67
# alpha,beta: 5.00 ,10.59
# alpha,beta: 17.62 ,9.52
# alpha,beta: 8.07 ,8.91
# alpha,beta: 60.10 ,16.10
# alpha,beta: 14.05 ,8.19
# alpha,beta: 8.40 ,6.98
# alpha,beta: 30.56 ,17.89
# alpha,beta: 7.77 ,8.34
# alpha,beta: 1.89 ,14.90
# alpha,beta: 2.39 ,6.46
# alpha,beta: 50.36 ,32.52
# alpha,beta: 30.10 ,24.39
# alpha,beta: 73.39 ,20.45
# alpha,beta: 9.69 ,6.02
# alpha,beta: 6.07 ,8.02
# alpha,beta: 50.76 ,24.40
# alpha,beta: 17.77 ,16.36
# alpha,beta: 26.14 ,12.29
# alpha,beta: 28.45 ,28.73
# alpha,beta: 16.60 ,8.34
# alpha,beta: 10.23 ,8.09
# alpha,beta: 26.51 ,13.26
# alpha,beta: 22.49 ,18.08
# alpha,beta: 22.88 ,20.81
# alpha,beta: 17.75 ,7.34
# alpha,beta: 3.63 ,10.71
# alpha,beta: 75.33 ,22.97
# alpha,beta: 12.14 ,15.04
# alpha,beta: 28.52 ,16.87
# alpha,beta: 3.59 ,9.29
# alpha,beta: 19.58 ,9.44
# alpha,beta: 13.35 ,9.19
# alpha,beta: 17.20 ,12.74
# alpha,beta: 6.37 ,8.97
# alpha,beta: 14.25 ,13.00
# alpha,beta: 63.95 ,28.26
# alpha,beta: 46.79 ,28.20
# alpha,beta: 47.89 ,31.00

# %% [markdown]
# ### Comparing The Prior Choices:
#
# Here we compare the difference between the two choices of priors, flat and beta.

# %%
pflat = np.array([res[i]['prior']['flat'] for i in range(ncls)])
pbeta = np.array([res[i]['prior']['beta'] for i in range(ncls)])

plt.scatter(alpha,(pbeta-pflat),c=pflat,cmap='jet')
plt.xscale('log')
plt.ylabel('prior prob: beta - flat',fontsize=16)
plt.xlabel(r'$\alpha = \hat{N}_{c}$',fontsize=16)
plt.colorbar().set_label(r'$P_{flat}=N_c/(N_c+N_f)$',fontsize=16)

# %% [markdown]
# The prior prob. difference is below 2.5% for $\alpha>10$, for lower values the difference can be up to 15%, which is signficant.

# %%
pflat = np.array([res[i]['prior']['flat'] for i in range(ncls)])
pbeta = np.array([res[i]['prior']['beta'] for i in range(ncls)])

plt.scatter(Nt,(pbeta-pflat),c=pflat,cmap='jet')
plt.xscale('log')
plt.ylabel('prior prob: beta - flat',fontsize=16)
plt.xlabel(r'True richness: $N_{200}$',fontsize=16)
plt.colorbar().set_label(r'$P_{flat}=N_c/(N_c+N_f)$',fontsize=16)

# %% [markdown]
# The prior choice has its impact on recovering the true richness. The main difference is on the low signal-to-noise ratio cases, i.e. higher number of fields galaxies than cluster galaxies ($P_{flat}<0.5$).

# %% [markdown]
# ## Comparing the richness
#
# Here we compare the richness for the different estimators, old method, flat and beta priors.

# %%
## assign the new probabilities
gal = set_new_columns(gal,columns,val=-99.)
cat = set_new_columns(cat,['Ngals_%s'%c for c in columns],val=-99.)
cat = set_new_columns(cat,[c for c in ['flat','beta']],val=-99.)

for i in range(ncls):
    for col in columns:
        gal[col][keys[i]]  = res[i]['Pmem'][col][:]
        cat['Ngals_%s'%col][i]= res[i]['Ngals'][col]
    
    for col in ['flat','beta']:
        cat[col][i]= res[i]['prior'][col]

# %%
def compute_ptaken(g0,label='Pmem'):
	"""
	it computes p_taken
	"""
	print('compute ptaken')
	# g0.sort('Pmem')
	pmem = g0[label]
	ptaken = np.ones_like(pmem,dtype=float)

	## find common galaxies
	gid = np.array(g0['GID'])#.astype(np.int)
	commonGroups = commonValues(gid)

	for indices in commonGroups:
		pm_group = np.array(pmem[indices])
		pt_group = np.array(ptaken[indices])

		idx_sort = np.argsort(-1*pm_group) ## -1* to reverse order

		pm_group_s = pm_group[idx_sort]
		pt_group_s = pt_group[idx_sort]

		new_pm = 0
		toto = 1
		pm = []
		for i in range(indices.size):
			toto *= (1-new_pm)
			new_pm = toto*pm_group_s[i]
			pt_group_s[i] = toto
			pm.append(new_pm)

		pmem[indices[idx_sort]] = np.array(pm)
		ptaken[indices[idx_sort]] = pt_group_s

	g0[label] = pmem
	#g0['Ptaken'] = ptaken

	return g0

def commonValues(values):
	idx_sort = np.argsort(values)
	sorted_values = values[idx_sort]
	vals, idx_start, count = np.unique(sorted_values, return_counts=True,
                                return_index=True)

	# sets of indices
	res = np.split(idx_sort, idx_start[1:])
	#filter them with respect to their size, keeping only items occurring more than once

	vals = vals[count > 1]
	commonValuesIndicies = [ri for ri in res if ri.size>1]
	
	return commonValuesIndicies

# %%
for col in ['flat','beta','old']:
    gal = compute_ptaken(gal,col)
# Out:
# compute ptaken
# compute ptaken
# compute ptaken

# %%
for i in range(ncls):
    for col in ['flat','beta','old']:
        cat['Ngals_%s'] = np.nansum(gal[col][keys[i]])

# %% [markdown]
# ### $N_{200}$ depends on the prior choice?

# %%
def plot_residual(cat,labela,labelb):
    na, nb = cat['Ngals_%s'%labela],cat['Ngals_%s'%labelb]
    w, = np.where((na>0)&(nb>0))
    pflat  = cat['flat'][w]
    
    x = cat['Ngals_true'][w]
    frac_difference = (na[w]-nb[w])#/nb
    
    plt.scatter(x,frac_difference,c=pflat,cmap='jet')
    plt.axhline(0.,color='k',ls='--')
    plt.xlim(.5,300.)
    plt.xscale('log')
    plt.ylabel(r'$N_{200,%s} - N_{200,%s}$'%(labela,labelb),fontsize=16)
    plt.xlabel(r'True richness: $N_{200}$',fontsize=16)
    plt.colorbar().set_label(r'$P_{flat}=N_c/(N_c+N_f)$',fontsize=16)

# %%
plot_residual(cat,'beta','flat')

# %% [markdown]
# The net effect on $N_{200}$ is not significant.

# %%
plot_residual(cat,'flat','old')

# %% [markdown]
# Check if the code old prob. definition is consitenty with the new definition.

# %%
plt.scatter(cat['Ngals_true'],cat['Ngals'],alpha=0.3)
plt.plot([0.5,300.],[0.5,300.],'k--')
plt.xlim(0.5,300.)
plt.ylim(0.5,300.)
plt.xscale('log')
plt.yscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-89107eaf1bde> in <module>()
# ----> 1 plt.scatter(cat['Ngals_true'],cat['Ngals'],alpha=0.3)
#       2 plt.plot([0.5,300.],[0.5,300.],'k--')
#       3 plt.xlim(0.5,300.)
#       4 plt.ylim(0.5,300.)
#       5 plt.xscale('log')
#
# NameError: name 'plt' is not defined

# %%
plt.scatter(cat['Ngals_true'],cat['Ngals_beta'],alpha=0.3)
plt.plot([0.5,300.],[0.5,300.],'k--')
plt.xlim(0.5,300.)
plt.ylim(0.5,300.)
plt.xscale('log')
plt.yscale('log')

# %%
plt.scatter(cat['Ngals_true'],cat['Ngals_old'],alpha=0.3)
plt.plot([0.5,300.],[0.5,300.],'k--')
plt.xlim(0.5,300.)
plt.ylim(0.5,300.)
plt.xscale('log')
plt.yscale('log')

# %%
def get_variable(cat,label):
    nt0= np.array(cat['Ngals_true']).copy()
    ng0= np.array(cat[label]).copy()
    
    w, = np.where(ng0>0.)
    return nt0[w],ng0[w]

def remove_outliers(x,n=1.5):
    q25,q75 = np.nanpercentile(x,[25,75])
    iqr     = q75-q25
    lo, up  = q25-n*iqr, q75+n*iqr
    mask    = (x<up)&(x>lo)
    return mask

def get_scatter(x,xt):
    residual     = x/xt
    log_residual = np.log10(residual)
    
    check    = np.logical_not(np.isnan(log_residual) | np.isinf(log_residual))
    mask     = remove_outliers(log_residual,n=1.5)&(check)
    
    bias            = 10**np.nanmean(log_residual[mask])
    log_scatter     = np.nanstd(log_residual[mask])
    scatter         = 10**(log_scatter)-1
    
    out_fraction    = 1-1.*np.count_nonzero(mask)/len(x)
    out = {'residual':residual,'log_residual':log_residual,'bias': bias, 
           'scatter':scatter, 'log_scatter':log_scatter, 'outlier_fraction': out_fraction,'mask':mask}
    return out

def plot_scatter_distribution(cat,col,label="data",xmin=0.25,xmax=2.25,logx=False):
    ngalst, ngals = get_variable(cat,col)
    
    w = np.where(ngalst>1)[0]
    res  = get_scatter(ngals[w],ngalst[w])
    print(r'mean: %.3f'%(res['bias']))
    print(r'rms : %.3f'%(res['scatter']))
    print(r'out. frac. : %.3f'%(res['outlier_fraction']))
    
    if logx:
        xbins    = np.linspace(np.log10(xmin),np.log10(xmax),30)
        residual = res['log_residual']
        xm       = np.log10(res['bias'])
        xlo,xup  = xm-2*res['log_scatter'],xm+2*res['log_scatter']
        
    else:
        xbins = np.linspace(xmin,xmax,30)
        residual = res['residual']
        xm       = res['bias']
        xlo,xup  = 10**(np.log10(xm)-2*res['log_scatter']),10**(np.log10(xm)+2*res['log_scatter'])
    print(xbins)
    check     = np.logical_not(np.isnan(residual))&np.logical_not(np.isinf(residual))
    _ = plt.hist(residual[check],bins=xbins,label='out. perc = %.2f %%'%(100*res['outlier_fraction']))
    _ = plt.hist(residual[res['mask']],bins=xbins,label=r'precision = %.2f %%'%(100*res['scatter']))
    plt.axvline(xm,color='k',ls='--')
    plt.axvline(xlo,color='r',ls='--')
    plt.axvline(xup,color='r',ls='--')
    plt.title(label)
    # plt.yscale('log')
    plt.xlabel('ratio')
    plt.legend()

# %%
plot_scatter_distribution(cat,'Ngals')
# Out:
# mean: 1.004
# rms : 0.300
# out. frac. : 0.052
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
plot_scatter_distribution(cat,'Ngals_beta')
# Out:
# mean: 1.255
# rms : 0.342
# out. frac. : 0.024
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
plot_scatter_distribution(cat,'Ngals_flat')
# Out:
# mean: 1.229
# rms : 0.347
# out. frac. : 0.029
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
plot_scatter_distribution(cat,'Ngals_old')
# Out:
# mean: 1.229
# rms : 0.347
# out. frac. : 0.029
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
def plot_fraction_pmem(galaxies,lcol='Pmem',color='r',label='_noLabel_',save=False):
    pmem = galaxies[lcol]
    mask = galaxies['True']==True

    pmem_edges = np.arange(0.0,1.1,0.1)
    idx, x_bin = makeBin(pmem, pmem_edges)
    fraction_bin = [len(galaxies[ix][mask[ix]])/(len(galaxies[ix])+1e-9) for ix in idx ]

    # fig = plt.figure(figsize=(6,6))
    plt.scatter(x_bin,fraction_bin,color=color,s=50,label=label)
    plt.plot(np.linspace(0,1.,100),np.linspace(0,1.,100),linestyle='--',color='k')

def makeBin(variable, xedges):
    xbins = (xedges[1:]+xedges[:-1])/2
    indices = [ np.where((variable >= xedges[i]) & (variable <= xedges[i + 1]))[0] for i in range(len(xedges)-1)]
    return indices, xbins

# %%
plot_fraction_pmem(gal,'beta')

# %%
plot_fraction_pmem(gal,'flat')

# %%
plot_fraction_pmem(gal,'old')

# %%
# plt.plot(pvec,b.pr0.pdf(pvec))
# plt.plot(pvec,b.prior)

# plt.axvline(b.pr0.mean())
# plt.axvline(b.pm0,color='r')

# %%
ncls   = len(cat)
columns = ['flat','beta','old']

## compute the new probabilities
res = []
for i in range(ncls):
    print('alpha,beta: %.2f ,%.2f'%(alpha[i],beta[i]))
    b = bayes_prob(alpha[i],beta[i])
    b.load_likelihood(gal[keys[i]])
    b.get_probabilities()
    b.compute_ngals()
    res.append(b.probabilities)
    del b
    
## assign the new probabilities
gal = set_new_columns(gal,columns,val=-99.)
cat = set_new_columns(cat,['Ngals_%s'%c for c in columns],val=-99.)

for i in range(ncls):
    for col in columns:
        gal[col][keys[i]]  = res[i][col][:]
        cat['Ngals_%s'%col][i]= res[i]['Ngals_%s'%col]

# %% [markdown]
# ## Testing the Prior Distributions
#
# To understand the differences between the models first, we make a set of fake data. A very simply setup, a grid of 100 points for each variable $N_c$ and $N_f$.

# %%
import numpy as np
from scipy.stats import beta
