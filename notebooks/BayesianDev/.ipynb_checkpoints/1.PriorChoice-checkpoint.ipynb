# %% [markdown]
# # Bayesian Inference Model
#
# In Bayesian inference approach, we associate a membership probability for each galaxy in the following manner: <br>
#
# $$
# P(\textit{member}\;| \;R,z,c,N_c,N_f) = \frac{P(R,z,c,N_c,N_f|\; \textit{member})P(\textit{member})}{P(R,z,c)}
# $$
#
# where $ P(R,z,c,N_c,N_f|\; \textit{membership}) $ is our likelihood model and $P(\textit{membership})$ is our prior. The marginal, $P(R,z,c)$, is the probability of measuring any galaxy in the field or the cluster.

# %% [markdown]
# ## Prior
#
# In this notebook, we quantify our prior precision. Basically, we have two models for the prior, one that is simply the sum of the galaxies and one that is based on a beta distribution.
#
# **A) Counting model**: George et al. 2011 defined the prior as:
#
# $$
# P(\textit{member}) = N_c/(N_c+N_f) = 1-P(\textit{field})
# $$
#
# which is based on the relative numbers of galaxies inside a cylinder of length $3\sigma$.
#
# **B) Beta Distribution:** since the $P(\textit{member})$ is a number between 0 and 1 and it's a reflection of $P(\textit{member})=1-P(\textit{field})$ we can write both variables as beta distribution, $Beta(x;\alpha,\beta)$.
#
# $$
# f(x,\alpha,\beta) = \frac{\Gamma(\alpha+\beta) x^{a-1} (1-x)^{\beta-1}}{\Gamma(\alpha)\Gamma(\beta)} \qquad \qquad \text{where} \quad \alpha=N_c \; ,\; \beta=N_{f} \; \text{and} \; x = N_c/(N_c+N_f)
# $$
#
# Where $x \in [0,1]$ and $\alpha$ and $\beta$ positive numbers. Notice that $x$ is simply the prior for the model **A**. The number of cluster and field galaxies are taken into account by the beta distribution. The diffence in this models  can be significant in the low counts since $x$ is biased due to the poissonian random fluctuations.
#
# This is an informative prior, to compute $P(\textit{member})$ you need to integrate the probabilities over your model.
#
# $$
# P(\textit{member}| \alpha, \beta) = {\rm E}\left[P(Model_{Radial}|member)(x) Beta(x| \alpha, \beta)\right]
# $$
#
# where $x$ is the probability of galaxy being a member. Basically, we use our prior knowledge of $N_c, N_f$ and the radial distribution of the members to estimate the probability.

# %% [markdown]
# # Copacabana
#
# In this lines, I'll load the copacabana output and investigate the addition of the Beta Distribution.

# %%
import matplotlib.pyplot as plt
import matplotlib

import seaborn as sns; sns.set(color_codes=True)
plt.rcParams.update({'font.size': 16})
sns.set_style("whitegrid")

import numpy as np
from scipy.interpolate import interp1d
import scipy

from collections import defaultdict

# %%
import sys
sys.path.append("/home/s1/jesteves/git/ccopa/python/")
from main import copacabana
# Out:
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using Modified sklearn.mixture.GMM, modified to allow data weights

# %%
cfg='/home/s1/jesteves/git/ccopa/config_files/config_copa_dc2.yaml'
dataset='cosmoDC2'

copa = copacabana(cfg,dataset=dataset)

# %%
run_name = u'gauss003-v2-r200-ztest-bkg'
cat = copa.load_copa_out('cluster',run_name)
gal = copa.load_copa_out('members',run_name)

# %%
zmask = np.logical_not(gal['zmask'])
true  = gal['GID']>0.

print(100.*np.count_nonzero(zmask&true)/np.count_nonzero(true))
# Out:
# 47.0636184648

# %% [markdown]
# ## Loading $\alpha$ and $\beta$
#
# We're making a correction on the $n_c$ only for this purpose. In another notebook I'll investigate why $n_c$ is biased.

# %%
pz_factor=0.84

# %%
area = cat['Area']

Nc = cat['Norm']#/pz_factor
Nf = cat['Nbkg']*area

Nt = cat['Ngals_true']#/pz_factor
Nft= cat['Nbkg_true']*area

Ncf = Nc+Nf

# %%
## Correcting Nc 
## Only for test purposes

# Nc = 1.34*Nc

# %%
# alpha = np.array(Nc).copy()
# beta  = np.array(Nf).copy()

# %%
alpha = np.array(Nt).copy()
beta  = np.array(Nft).copy()

# %%
cat['Norm','Nbkg']
# Out:
# <Table length=2056>
#        Norm                Nbkg
#      float64             float64
# ------------------ -------------------
#  56.58415125765307   5.082646722998792
# 33.280522522937446 0.10369314366089194
#  17.53951837364622     1.3010866673934
#  30.57562106089012  0.7736270088610085
#  7.524306927304617  0.9844604813132677
#  77.01201328188218   5.668611579198652
#  56.23705427302039 0.19011758154448624
# 10.067379747793524  0.7605322338234359
#  36.39086183633419  1.1363131906396275
#   4.06624293958051  1.5396981805911556
#                ...                 ...
# 37.969354375611864    6.05997199762686
# 12.769086165783538  1.8194857423815733
# 22.807527690334055   8.122025517783642
#  7.400228331530417  12.058729221627623
# 12.868946591426512   11.19334968511072
#  12.00027931785268    3.83096554116689
# 21.031171689526385   5.234908874303014
#  96.18692799854095   5.109794587533712
#  54.70807292639713   5.237813447085712
#   72.8452629082156   6.745471189263373

# %% [markdown]
# ## Bayesian Approach: Membership probabilities
#
# Let's compute the new membership probabilities.

# %%
def chunks(ids1, ids2):
    """Yield successive n-sized chunks from data"""
    for id in ids2:
        w, = np.where( ids1==id )
        yield w

# %%
def set_new_columns(table,columns,val=0.):
    for col in columns:
        table[col] = val
    return table

# %% [markdown]
# ### Prior Example
#
# For a given cluster, we show the prior distribution.

# %%
cids = np.array(cat['CID'])
gids = np.array(gal['CID'])
r200 = np.array(cat['R200'])
zcls = np.array(cat['redshift'])
keys = list(chunks(gids,cids))

# %%
#gal.rename_column('redshift_1','redshift')

# %%
i=32
b = BayesianProbability(alpha[i],beta[i],r2=r200[i])
b.assign_probabilities(gal[keys[i]])
# Out:
# ratio: 1.00
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:73: RuntimeWarning: invalid value encountered in divide

# %% [markdown]
# In the figure above we illustrate the prior choice. The Beta Distribution has its mean at the prior probability $\alpha/(\alpha+\beta)=N_c/(N_c+N_f)$ (blue dashed line), which corresponds to the choice of a non informative prior. In our informative prior approach we marginilize the membership probability over the likelihood (black curve) and our new prior prior probability is the mean of this distribution (red dashed line). We can see that our new $P(member)$ has a slightly higher value. We note that for this purposes, our likelihood only depends on the radial distance, this choice is eplained on a later section.

# %%
b.plot_prior_distribution()
plt.yscale('log')
plt.ylim(1e-2,7e1)
# Out:
# (0.01, 70.0)

# %%
np.sum(b.pdf)
# Out:
# 1.0000000000000002

# %%
np.sum(b.prob['marginal']['pdf'])#/(alpha[i]+beta[i])
# Out:
# 1.0

# %%
ncls    = len(cat)
columns = ['flat','beta','old']

## compute the new probabilities
cla,res = [],[]
for i in range(ncls):
    print('alpha,beta: %.2f ,%.2f'%(alpha[i],beta[i]))
    b = BayesianProbability(alpha[i],beta[i],r2=r200[i])
    b.assign_probabilities(gal[keys[i]])
    b.compute_ngals()
    
    res.append(b.prob)
    cla.append(b)
    del b
# Out:
# alpha,beta: 58.00 ,51.09
# ratio: 1.00
# alpha,beta: 33.00 ,0.59
# ratio: 1.00
# alpha,beta: 17.00 ,10.44
# ratio: 1.00
# alpha,beta: 30.00 ,6.92
# ratio: 1.00
# alpha,beta: 7.00 ,2.67
# ratio: 1.00
# alpha,beta: 79.00 ,29.21
# ratio: 1.00
# alpha,beta: 55.00 ,1.68
# ratio: 1.00
# alpha,beta: 10.00 ,4.12
# ratio: 1.00
# alpha,beta: 36.00 ,11.57
# ratio: 1.00
# alpha,beta: 4.00 ,4.97
# ratio: 1.00
# alpha,beta: 6.00 ,1.15
# ratio: 1.00
# alpha,beta: 87.00 ,21.23
# ratio: 1.00
# alpha,beta: 9.00 ,1.64
# ratio: 1.00
# alpha,beta: 23.00 ,5.85
# ratio: 1.00
# alpha,beta: 5.00 ,5.02
# ratio: 1.00
# alpha,beta: 3.00 ,2.84
# ratio: 1.00
# alpha,beta: 10.00 ,0.68
# ratio: 1.00
# alpha,beta: 35.00 ,2.55
# ratio: 1.00
# alpha,beta: 17.00 ,4.90
# ratio: 1.00
# alpha,beta: 17.00 ,6.83
# ratio: 1.00
# alpha,beta: 13.00 ,4.11
# ratio: 1.00
# alpha,beta: 34.00 ,8.13
# ratio: 1.00
# alpha,beta: 4.00 ,4.42
# ratio: 1.00
# alpha,beta: 24.00 ,8.53
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:73: RuntimeWarning: invalid value encountered in divide
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:289: RuntimeWarning: invalid value encountered in divide
# ratio: 1.00
# alpha,beta: 45.00 ,42.02
# ratio: 1.00
# alpha,beta: 13.00 ,1.67
# ratio: 1.00
# alpha,beta: 22.00 ,44.10
# ratio: 1.00
# alpha,beta: 5.00 ,0.87
# ratio: 1.00
# alpha,beta: 50.00 ,1.61
# ratio: 1.00
# alpha,beta: 17.00 ,4.37
# ratio: 1.00
# alpha,beta: 20.00 ,5.58
# ratio: 1.00
# alpha,beta: 5.00 ,0.93
# ratio: 1.00
# alpha,beta: 6.00 ,2.34
# ratio: 1.00
# alpha,beta: 29.00 ,10.35
# ratio: 1.00
# alpha,beta: 19.00 ,6.02
# ratio: 1.00
# alpha,beta: 44.00 ,71.10
# ratio: 1.00
# alpha,beta: 9.00 ,3.06
# ratio: 1.00
# alpha,beta: 12.00 ,3.98
# ratio: 1.00
# alpha,beta: 10.00 ,2.41
# ratio: 1.00
# alpha,beta: 3.00 ,12.19
# ratio: 1.00
# alpha,beta: 8.00 ,1.69
# ratio: 1.00
# alpha,beta: 49.00 ,139.66
# ratio: 1.00
# alpha,beta: 11.00 ,3.60
# ratio: 1.00
# alpha,beta: 6.00 ,0.00
# ratio: 1.00
# alpha,beta: 4.00 ,0.95
# ratio: 1.00
# alpha,beta: 5.00 ,0.91
# ratio: 1.00
# alpha,beta: 20.00 ,24.18
# ratio: 1.00
# alpha,beta: 23.00 ,13.23
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:309: RuntimeWarning: invalid value encountered in greater
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:309: RuntimeWarning: invalid value encountered in less_equal
# ratio: 1.00
# alpha,beta: 8.00 ,5.41
# ratio: 1.00
# alpha,beta: 115.00 ,35.27
# ratio: 1.00
# alpha,beta: 20.00 ,1.50
# ratio: 1.00
# alpha,beta: 120.00 ,21.53
# ratio: 1.00
# alpha,beta: 74.00 ,9.55
# ratio: 1.00
# alpha,beta: 4.00 ,0.91
# ratio: 1.00
# alpha,beta: 55.00 ,6.84
# ratio: 1.00
# alpha,beta: 11.00 ,2.54
# ratio: 1.00
# alpha,beta: 46.00 ,46.80
# ratio: 1.00
# alpha,beta: 16.00 ,8.77
# ratio: 1.00
# alpha,beta: 4.00 ,7.94
# ratio: 1.00
# alpha,beta: 31.00 ,6.63
# ratio: 1.00
# alpha,beta: 8.00 ,1.55
# ratio: 1.00
# alpha,beta: 52.00 ,9.59
# ratio: 1.00
# alpha,beta: 31.00 ,12.79
# ratio: 1.00
# alpha,beta: 13.00 ,6.71
# ratio: 1.00
# alpha,beta: 6.00 ,15.88
# ratio: 1.00
# alpha,beta: 54.00 ,19.48
# ratio: 1.00
# alpha,beta: 4.00 ,2.70
# ratio: 1.00
# alpha,beta: 6.00 ,3.13
# ratio: 1.00
# alpha,beta: 64.00 ,55.89
# ratio: 1.00
# alpha,beta: 15.00 ,10.86
# ratio: 1.00
# alpha,beta: 34.00 ,11.14
# ratio: 1.00
# alpha,beta: 9.00 ,9.43
# ratio: 1.00
# alpha,beta: 15.00 ,4.48
# ratio: 1.00
# alpha,beta: 16.00 ,4.82
# ratio: 1.00
# alpha,beta: 13.00 ,7.60
# ratio: 1.00
# alpha,beta: 12.00 ,3.24
# ratio: 1.00
# alpha,beta: 10.00 ,1.88
# ratio: 1.00
# alpha,beta: 22.00 ,21.36
# ratio: 1.00
# alpha,beta: 3.00 ,0.00
# ratio: 1.00
# alpha,beta: 15.00 ,11.77
# ratio: 1.00
# alpha,beta: 4.00 ,2.35
# ratio: 1.00
# alpha,beta: 31.00 ,17.28
# ratio: 1.00
# alpha,beta: 5.00 ,6.10
# ratio: 1.00
# alpha,beta: 11.00 ,3.27
# ratio: 1.00
# alpha,beta: 1.00 ,7.66
# ratio: 1.00
# alpha,beta: 4.00 ,4.10
# ratio: 1.00
# alpha,beta: 10.00 ,2.60
# ratio: 1.00
# alpha,beta: 51.00 ,13.69
# ratio: 1.00
# alpha,beta: 5.00 ,1.35
# ratio: 1.00
# alpha,beta: 12.00 ,2.23
# ratio: 1.00
# alpha,beta: 19.00 ,16.95
# ratio: 1.00
# alpha,beta: 9.00 ,3.10
# ratio: 1.00
# alpha,beta: 19.00 ,10.05
# ratio: 1.00
# alpha,beta: 9.00 ,0.94
# ratio: 1.00
# alpha,beta: 17.00 ,17.79
# ratio: 1.00
# alpha,beta: 4.00 ,3.79
# ratio: 1.00
# alpha,beta: 14.00 ,3.69
# ratio: 1.00
# alpha,beta: 30.00 ,9.47
# ratio: 1.00
# alpha,beta: 40.00 ,7.39
# ratio: 1.00
# alpha,beta: 10.00 ,1.88
# ratio: 1.00
# alpha,beta: 37.00 ,15.72
# ratio: 1.00
# alpha,beta: 17.00 ,6.81
# ratio: 1.00
# alpha,beta: 6.00 ,0.65
# ratio: 1.00
# alpha,beta: 9.00 ,1.66
# ratio: 1.00
# alpha,beta: 17.00 ,8.63
# ratio: 1.00
# alpha,beta: 27.00 ,6.26
# ratio: 1.00
# alpha,beta: 7.00 ,6.56
# ratio: 1.00
# alpha,beta: 15.00 ,34.54
# ratio: 1.00
# alpha,beta: 20.00 ,10.07
# ratio: 1.00
# alpha,beta: 5.00 ,1.63
# ratio: 1.00
# alpha,beta: 8.00 ,6.31
# ratio: 1.00
# alpha,beta: 18.00 ,10.83
# ratio: 1.00
# alpha,beta: 2.00 ,4.55
# ratio: 1.00
# alpha,beta: 31.00 ,5.06
# ratio: 1.00
# alpha,beta: 8.00 ,0.86
# ratio: 1.00
# alpha,beta: 41.00 ,37.58
# ratio: 1.00
# alpha,beta: 49.00 ,7.14
# ratio: 1.00
# alpha,beta: 5.00 ,2.65
# ratio: 1.00
# alpha,beta: 15.00 ,2.64
# ratio: 1.00
# alpha,beta: 26.00 ,3.63
# ratio: 1.00
# alpha,beta: 2.00 ,0.80
# ratio: 1.00
# alpha,beta: 17.00 ,4.33
# ratio: 1.00
# alpha,beta: 9.00 ,3.24
# ratio: 1.00
# alpha,beta: 10.00 ,0.00
# ratio: 1.00
# alpha,beta: 9.00 ,0.63
# ratio: 1.00
# alpha,beta: 54.00 ,11.66
# ratio: 1.00
# alpha,beta: 9.00 ,1.45
# ratio: 1.00
# alpha,beta: 3.00 ,11.29
# ratio: 1.00
# alpha,beta: 10.00 ,2.83
# ratio: 1.00
# alpha,beta: 18.00 ,9.07
# ratio: 1.00
# alpha,beta: 8.00 ,6.94
# ratio: 1.00
# alpha,beta: 12.00 ,9.75
# ratio: 1.00
# alpha,beta: 4.00 ,2.90
# ratio: 1.00
# alpha,beta: 31.00 ,3.35
# ratio: 1.00
# alpha,beta: 31.00 ,5.59
# ratio: 1.00
# alpha,beta: 50.00 ,11.42
# ratio: 1.00
# alpha,beta: 55.00 ,26.87
# ratio: 1.00
# alpha,beta: 54.00 ,13.87
# ratio: 1.00
# alpha,beta: 11.00 ,9.27
# ratio: 1.00
# alpha,beta: 6.00 ,2.02
# ratio: 1.00
# alpha,beta: 5.00 ,1.89
# ratio: 1.00
# alpha,beta: 12.00 ,0.71
# ratio: 1.00
# alpha,beta: 16.00 ,6.33
# ratio: 1.00
# alpha,beta: 25.00 ,18.38
# ratio: 1.00
# alpha,beta: 4.00 ,2.28
# ratio: 1.00
# alpha,beta: 5.00 ,4.72
# ratio: 1.00
# alpha,beta: 13.00 ,12.92
# ratio: 1.00
# alpha,beta: 10.00 ,2.91
# ratio: 1.00
# alpha,beta: 77.00 ,6.82
# ratio: 1.00
# alpha,beta: 19.00 ,6.36
# ratio: 1.00
# alpha,beta: 119.00 ,80.84
# ratio: 1.00
# alpha,beta: 13.00 ,5.05
# ratio: 1.00
# alpha,beta: 20.00 ,4.15
# ratio: 1.00
# alpha,beta: 9.00 ,2.94
# ratio: 1.00
# alpha,beta: 7.00 ,12.23
# ratio: 1.00
# alpha,beta: 12.00 ,9.36
# ratio: 1.00
# alpha,beta: 14.00 ,0.86
# ratio: 1.00
# alpha,beta: 31.00 ,1.70
# ratio: 1.00
# alpha,beta: 20.00 ,16.81
# ratio: 1.00
# alpha,beta: 6.00 ,6.81
# ratio: 1.00
# alpha,beta: 12.00 ,28.18
# ratio: 1.00
# alpha,beta: 19.00 ,12.57
# ratio: 1.00
# alpha,beta: 23.00 ,6.78
# ratio: 1.00
# alpha,beta: 8.00 ,7.67
# ratio: 1.00
# alpha,beta: 23.00 ,0.00
# ratio: 1.00
# alpha,beta: 7.00 ,4.23
# ratio: 1.00
# alpha,beta: 3.00 ,2.08
# ratio: 1.00
# alpha,beta: 28.00 ,25.32
# ratio: 1.00
# alpha,beta: 27.00 ,1.89
# ratio: 1.00
# alpha,beta: 8.00 ,4.23
# ratio: 1.00
# alpha,beta: 4.00 ,1.68
# ratio: 1.00
# alpha,beta: 3.00 ,1.73
# ratio: 1.00
# alpha,beta: 16.00 ,3.47
# ratio: 1.00
# alpha,beta: 7.00 ,2.60
# ratio: 1.00
# alpha,beta: 7.00 ,3.70
# ratio: 1.00
# alpha,beta: 15.00 ,4.60
# ratio: 1.00
# alpha,beta: 8.00 ,6.13
# ratio: 1.00
# alpha,beta: 32.00 ,54.60
# ratio: 1.00
# alpha,beta: 23.00 ,3.21
# ratio: 1.00
# alpha,beta: 24.00 ,9.81
# ratio: 1.00
# alpha,beta: 6.00 ,4.73
# ratio: 1.00
# alpha,beta: 23.00 ,3.70
# ratio: 1.00
# alpha,beta: 8.00 ,0.81
# ratio: 1.00
# alpha,beta: 33.00 ,4.50
# ratio: 1.00
# alpha,beta: 5.00 ,8.05
# ratio: 1.00
# alpha,beta: 6.00 ,9.53
# ratio: 1.00
# alpha,beta: 6.00 ,0.94
# ratio: 1.00
# alpha,beta: 42.00 ,65.96
# ratio: 1.00
# alpha,beta: 33.00 ,3.99
# ratio: 1.00
# alpha,beta: 12.00 ,0.00
# ratio: 1.00
# alpha,beta: 10.00 ,3.54
# ratio: 1.00
# alpha,beta: 160.00 ,14.13
# ratio: 1.00
# alpha,beta: 17.00 ,5.80
# ratio: 1.00
# alpha,beta: 4.00 ,13.31
# ratio: 1.00
# alpha,beta: 8.00 ,2.32
# ratio: 1.00
# alpha,beta: 21.00 ,21.81
# ratio: 1.00
# alpha,beta: 33.00 ,9.87
# ratio: 1.00
# alpha,beta: 132.00 ,7.54
# ratio: 1.00
# alpha,beta: 7.00 ,0.88
# ratio: 1.00
# alpha,beta: 34.00 ,6.64
# ratio: 1.00
# alpha,beta: 6.00 ,2.40
# ratio: 1.00
# alpha,beta: 8.00 ,1.58
# ratio: 1.00
# alpha,beta: 14.00 ,5.67
# ratio: 1.00
# alpha,beta: 23.00 ,11.21
# ratio: 1.00
# alpha,beta: 8.00 ,2.76
# ratio: 1.00
# alpha,beta: 9.00 ,3.64
# ratio: 1.00
# alpha,beta: 33.00 ,34.89
# ratio: 1.00
# alpha,beta: 5.00 ,1.61
# ratio: 1.00
# alpha,beta: 9.00 ,14.50
# ratio: 1.00
# alpha,beta: 17.00 ,3.07
# ratio: 1.00
# alpha,beta: 5.00 ,3.42
# ratio: 1.00
# alpha,beta: 20.00 ,22.91
# ratio: 1.00
# alpha,beta: 51.00 ,19.84
# ratio: 1.00
# alpha,beta: 23.00 ,2.11
# ratio: 1.00
# alpha,beta: 8.00 ,1.68
# ratio: 1.00
# alpha,beta: 11.00 ,4.92
# ratio: 1.00
# alpha,beta: 23.00 ,10.50
# ratio: 1.00
# alpha,beta: 8.00 ,2.43
# ratio: 1.00
# alpha,beta: 23.00 ,6.77
# ratio: 1.00
# alpha,beta: 24.00 ,8.81
# ratio: 1.00
# alpha,beta: 7.00 ,1.69
# ratio: 1.00
# alpha,beta: 28.00 ,0.77
# ratio: 1.00
# alpha,beta: 37.00 ,23.20
# ratio: 1.00
# alpha,beta: 91.00 ,9.73
# ratio: 1.00
# alpha,beta: 15.00 ,1.86
# ratio: 1.00
# alpha,beta: 11.00 ,7.72
# ratio: 1.00
# alpha,beta: 67.00 ,3.71
# ratio: 1.00
# alpha,beta: 19.00 ,4.83
# ratio: 1.00
# alpha,beta: 12.00 ,1.44
# ratio: 1.00
# alpha,beta: 13.00 ,13.26
# ratio: 1.00
# alpha,beta: 19.00 ,19.23
# ratio: 1.00
# alpha,beta: 29.00 ,6.87
# ratio: 1.00
# alpha,beta: 16.00 ,3.00
# ratio: 1.00
# alpha,beta: 8.00 ,1.16
# ratio: 1.00
# alpha,beta: 49.00 ,13.51
# ratio: 1.00
# alpha,beta: 14.00 ,1.51
# ratio: 1.00
# alpha,beta: 3.00 ,2.51
# ratio: 1.00
# alpha,beta: 7.00 ,2.41
# ratio: 1.00
# alpha,beta: 14.00 ,8.89
# ratio: 1.00
# alpha,beta: 4.00 ,1.65
# ratio: 1.00
# alpha,beta: 5.00 ,3.94
# ratio: 1.00
# alpha,beta: 7.00 ,2.67
# ratio: 1.00
# alpha,beta: 11.00 ,7.39
# ratio: 1.00
# alpha,beta: 18.00 ,5.11
# ratio: 1.00
# alpha,beta: 3.00 ,1.54
# ratio: 1.00
# alpha,beta: 14.00 ,8.30
# ratio: 1.00
# alpha,beta: 62.00 ,12.04
# ratio: 1.00
# alpha,beta: 17.00 ,4.70
# ratio: 1.00
# alpha,beta: 35.00 ,4.67
# ratio: 1.00
# alpha,beta: 31.00 ,2.81
# ratio: 1.00
# alpha,beta: 29.00 ,22.66
# ratio: 1.00
# alpha,beta: 9.00 ,2.46
# ratio: 1.00
# alpha,beta: 4.00 ,1.82
# ratio: 1.00
# alpha,beta: 15.00 ,3.93
# ratio: 1.00
# alpha,beta: 14.00 ,1.71
# ratio: 1.00
# alpha,beta: 13.00 ,3.36
# ratio: 1.00
# alpha,beta: 3.00 ,1.40
# ratio: 1.00
# alpha,beta: 16.00 ,1.81
# ratio: 1.00
# alpha,beta: 11.00 ,4.39
# ratio: 1.00
# alpha,beta: 43.00 ,54.94
# ratio: 1.00
# alpha,beta: 38.00 ,21.85
# ratio: 1.00
# alpha,beta: 28.00 ,24.25
# ratio: 1.00
# alpha,beta: 27.00 ,29.37
# ratio: 1.00
# alpha,beta: 8.00 ,3.92
# ratio: 1.00
# alpha,beta: 4.00 ,1.74
# ratio: 1.00
# alpha,beta: 118.00 ,7.31
# ratio: 1.00
# alpha,beta: 23.00 ,8.86
# ratio: 1.00
# alpha,beta: 11.00 ,2.58
# ratio: 1.00
# alpha,beta: 52.00 ,21.04
# ratio: 1.00
# alpha,beta: 8.00 ,8.05
# ratio: 1.00
# alpha,beta: 11.00 ,4.89
# ratio: 1.00
# alpha,beta: 8.00 ,2.48
# ratio: 1.00
# alpha,beta: 11.00 ,14.48
# ratio: 1.00
# alpha,beta: 6.00 ,5.86
# ratio: 1.00
# alpha,beta: 47.00 ,1.67
# ratio: 1.00
# alpha,beta: 21.00 ,8.42
# ratio: 1.00
# alpha,beta: 4.00 ,4.29
# ratio: 1.00
# alpha,beta: 44.00 ,14.10
# ratio: 1.00
# alpha,beta: 11.00 ,3.38
# ratio: 1.00
# alpha,beta: 14.00 ,5.83
# ratio: 1.00
# alpha,beta: 7.00 ,5.93
# ratio: 1.00
# alpha,beta: 7.00 ,1.55
# ratio: 1.00
# alpha,beta: 12.00 ,5.50
# ratio: 1.00
# alpha,beta: 14.00 ,8.86
# ratio: 1.00
# alpha,beta: 13.00 ,7.07
# ratio: 1.00
# alpha,beta: 9.00 ,9.65
# ratio: 1.00
# alpha,beta: 76.00 ,16.36
# ratio: 1.00
# alpha,beta: 67.00 ,12.19
# ratio: 1.00
# alpha,beta: 6.00 ,1.67
# ratio: 1.00
# alpha,beta: 53.00 ,13.55
# ratio: 1.00
# alpha,beta: 9.00 ,2.05
# ratio: 1.00
# alpha,beta: 12.00 ,1.71
# ratio: 1.00
# alpha,beta: 7.00 ,4.39
# ratio: 1.00
# alpha,beta: 16.00 ,10.23
# ratio: 1.00
# alpha,beta: 87.00 ,37.65
# ratio: 1.00
# alpha,beta: 60.00 ,43.43
# ratio: 1.00
# alpha,beta: 2.00 ,1.50
# ratio: 1.00
# alpha,beta: 14.00 ,23.98
# ratio: 1.00
# alpha,beta: 18.00 ,4.79
# ratio: 1.00
# alpha,beta: 41.00 ,5.09
# ratio: 1.00
# alpha,beta: 13.00 ,14.74
# ratio: 1.00
# alpha,beta: 5.00 ,0.84
# ratio: 1.00
# alpha,beta: 6.00 ,2.44
# ratio: 1.00
# alpha,beta: 4.00 ,5.99
# ratio: 1.00
# alpha,beta: 12.00 ,9.23
# ratio: 1.00
# alpha,beta: 69.00 ,31.05
# ratio: 1.00
# alpha,beta: 13.00 ,6.24
# ratio: 1.00
# alpha,beta: 9.00 ,2.75
# ratio: 1.00
# alpha,beta: 4.00 ,0.57
# ratio: 1.00
# alpha,beta: 46.00 ,4.00
# ratio: 1.00
# alpha,beta: 97.00 ,18.41
# ratio: 1.00
# alpha,beta: 29.00 ,7.41
# ratio: 1.00
# alpha,beta: 11.00 ,4.54
# ratio: 1.00
# alpha,beta: 20.00 ,2.48
# ratio: 1.00
# alpha,beta: 12.00 ,1.55
# ratio: 1.00
# alpha,beta: 16.00 ,32.73
# ratio: 1.00
# alpha,beta: 18.00 ,4.26
# ratio: 1.00
# alpha,beta: 7.00 ,4.11
# ratio: 1.00
# alpha,beta: 20.00 ,14.50
# ratio: 1.00
# alpha,beta: 27.00 ,2.23
# ratio: 1.00
# alpha,beta: 34.00 ,11.12
# ratio: 1.00
# alpha,beta: 5.00 ,3.29
# ratio: 1.00
# alpha,beta: 6.00 ,9.49
# ratio: 1.00
# alpha,beta: 9.00 ,2.42
# ratio: 1.00
# alpha,beta: 14.00 ,0.95
# ratio: 1.00
# alpha,beta: 4.00 ,0.85
# ratio: 1.00
# alpha,beta: 80.00 ,132.50
# ratio: 1.00
# alpha,beta: 42.00 ,16.92
# ratio: 1.00
# alpha,beta: 21.00 ,10.92
# ratio: 1.00
# alpha,beta: 5.00 ,3.71
# ratio: 1.00
# alpha,beta: 48.00 ,26.84
# ratio: 1.00
# alpha,beta: 11.00 ,3.46
# ratio: 1.00
# alpha,beta: 20.00 ,10.38
# ratio: 1.00
# alpha,beta: 5.00 ,0.57
# ratio: 1.00
# alpha,beta: 5.00 ,5.39
# ratio: 1.00
# alpha,beta: 13.00 ,28.40
# ratio: 1.00
# alpha,beta: 5.00 ,2.72
# ratio: 1.00
# alpha,beta: 39.00 ,7.37
# ratio: 1.00
# alpha,beta: 26.00 ,5.91
# ratio: 1.00
# alpha,beta: 40.00 ,10.46
# ratio: 1.00
# alpha,beta: 90.00 ,17.89
# ratio: 1.00
# alpha,beta: 13.00 ,2.97
# ratio: 1.00
# alpha,beta: 70.00 ,22.12
# ratio: 1.00
# alpha,beta: 23.00 ,4.19
# ratio: 1.00
# alpha,beta: 27.00 ,9.30
# ratio: 1.00
# alpha,beta: 6.00 ,4.26
# ratio: 1.00
# alpha,beta: 53.00 ,16.82
# ratio: 1.00
# alpha,beta: 81.00 ,4.80
# ratio: 1.00
# alpha,beta: 8.00 ,2.88
# ratio: 1.00
# alpha,beta: 9.00 ,6.33
# ratio: 1.00
# alpha,beta: 10.00 ,2.42
# ratio: 1.00
# alpha,beta: 26.00 ,14.46
# ratio: 1.00
# alpha,beta: 14.00 ,0.00
# ratio: 1.00
# alpha,beta: 8.00 ,10.37
# ratio: 1.00
# alpha,beta: 8.00 ,2.13
# ratio: 1.00
# alpha,beta: 14.00 ,1.52
# ratio: 1.00
# alpha,beta: 48.00 ,0.62
# ratio: 1.00
# alpha,beta: 11.00 ,25.95
# ratio: 1.00
# alpha,beta: 7.00 ,1.79
# ratio: 1.00
# alpha,beta: 17.00 ,15.66
# ratio: 1.00
# alpha,beta: 15.00 ,7.11
# ratio: 1.00
# alpha,beta: 86.00 ,15.93
# ratio: 1.00
# alpha,beta: 51.00 ,11.89
# ratio: 1.00
# alpha,beta: 11.00 ,2.31
# ratio: 1.00
# alpha,beta: 7.00 ,1.76
# ratio: 1.00
# alpha,beta: 10.00 ,3.92
# ratio: 1.00
# alpha,beta: 1.00 ,3.25
# ratio: 1.00
# alpha,beta: 18.00 ,1.84
# ratio: 1.00
# alpha,beta: 28.00 ,9.37
# ratio: 1.00
# alpha,beta: 5.00 ,4.07
# ratio: 1.00
# alpha,beta: 34.00 ,23.13
# ratio: 1.00
# alpha,beta: 10.00 ,2.41
# ratio: 1.00
# alpha,beta: 16.00 ,8.08
# ratio: 1.00
# alpha,beta: 29.00 ,20.82
# ratio: 1.00
# alpha,beta: 69.00 ,17.76
# ratio: 1.00
# alpha,beta: 7.00 ,1.57
# ratio: 1.00
# alpha,beta: 17.00 ,7.81
# ratio: 1.00
# alpha,beta: 4.00 ,1.78
# ratio: 1.00
# alpha,beta: 27.00 ,7.21
# ratio: 1.00
# alpha,beta: 25.00 ,17.64
# ratio: 1.00
# alpha,beta: 7.00 ,4.67
# ratio: 1.00
# alpha,beta: 15.00 ,16.62
# ratio: 1.00
# alpha,beta: 6.00 ,25.91
# ratio: 1.00
# alpha,beta: 38.00 ,7.72
# ratio: 1.00
# alpha,beta: 6.00 ,0.59
# ratio: 1.00
# alpha,beta: 8.00 ,0.84
# ratio: 1.00
# alpha,beta: 61.00 ,4.39
# ratio: 1.00
# alpha,beta: 17.00 ,12.76
# ratio: 1.00
# alpha,beta: 8.00 ,6.43
# ratio: 1.00
# alpha,beta: 14.00 ,11.48
# ratio: 1.00
# alpha,beta: 143.00 ,42.81
# ratio: 1.00
# alpha,beta: 7.00 ,3.12
# ratio: 1.00
# alpha,beta: 35.00 ,18.80
# ratio: 1.00
# alpha,beta: 36.00 ,12.38
# ratio: 1.00
# alpha,beta: 34.00 ,16.54
# ratio: 1.00
# alpha,beta: 17.00 ,3.87
# ratio: 1.00
# alpha,beta: 23.00 ,4.76
# ratio: 1.00
# alpha,beta: 61.00 ,6.56
# ratio: 1.00
# alpha,beta: 3.00 ,3.80
# ratio: 1.00
# alpha,beta: 18.00 ,2.33
# ratio: 1.00
# alpha,beta: 5.00 ,2.39
# ratio: 1.00
# alpha,beta: 6.00 ,3.71
# ratio: 1.00
# alpha,beta: 16.00 ,7.67
# ratio: 1.00
# alpha,beta: 17.00 ,3.42
# ratio: 1.00
# alpha,beta: 8.00 ,14.10
# ratio: 1.00
# alpha,beta: 12.00 ,3.99
# ratio: 1.00
# alpha,beta: 14.00 ,13.62
# ratio: 1.00
# alpha,beta: 31.00 ,17.25
# ratio: 1.00
# alpha,beta: 30.00 ,9.58
# ratio: 1.00
# alpha,beta: 43.00 ,69.11
# ratio: 1.00
# alpha,beta: 4.00 ,1.36
# ratio: 1.00
# alpha,beta: 9.00 ,3.93
# ratio: 1.00
# alpha,beta: 3.00 ,12.89
# ratio: 1.00
# alpha,beta: 16.00 ,13.99
# ratio: 1.00
# alpha,beta: 7.00 ,4.44
# ratio: 1.00
# alpha,beta: 59.00 ,12.26
# ratio: 1.00
# alpha,beta: 67.00 ,13.47
# ratio: 1.00
# alpha,beta: 52.00 ,55.29
# ratio: 1.00
# alpha,beta: 13.00 ,2.37
# ratio: 1.00
# alpha,beta: 13.00 ,2.44
# ratio: 1.00
# alpha,beta: 23.00 ,8.85
# ratio: 1.00
# alpha,beta: 41.00 ,16.27
# ratio: 1.00
# alpha,beta: 15.00 ,7.05
# ratio: 1.00
# alpha,beta: 20.00 ,8.36
# ratio: 1.00
# alpha,beta: 10.00 ,1.56
# ratio: 1.00
# alpha,beta: 5.00 ,1.73
# ratio: 1.00
# alpha,beta: 17.00 ,4.22
# ratio: 1.00
# alpha,beta: 11.00 ,0.95
# ratio: 1.00
# alpha,beta: 25.00 ,11.06
# ratio: 1.00
# alpha,beta: 31.00 ,11.41
# ratio: 1.00
# alpha,beta: 30.00 ,28.89
# ratio: 1.00
# alpha,beta: 17.00 ,9.31
# ratio: 1.00
# alpha,beta: 17.00 ,15.51
# ratio: 1.00
# alpha,beta: 21.00 ,3.26
# ratio: 1.00
# alpha,beta: 3.00 ,1.57
# ratio: 1.00
# alpha,beta: 17.00 ,4.98
# ratio: 1.00
# alpha,beta: 48.00 ,18.37
# ratio: 1.00
# alpha,beta: 20.00 ,0.70
# ratio: 1.00
# alpha,beta: 8.00 ,3.54
# ratio: 1.00
# alpha,beta: 13.00 ,5.27
# ratio: 1.00
# alpha,beta: 11.00 ,7.06
# ratio: 1.00
# alpha,beta: 31.00 ,19.83
# ratio: 1.00
# alpha,beta: 57.00 ,16.58
# ratio: 1.00
# alpha,beta: 26.00 ,7.72
# ratio: 1.00
# alpha,beta: 14.00 ,5.01
# ratio: 1.00
# alpha,beta: 9.00 ,4.44
# ratio: 1.00
# alpha,beta: 24.00 ,0.95
# ratio: 1.00
# alpha,beta: 27.00 ,4.36
# ratio: 1.00
# alpha,beta: 25.00 ,15.03
# ratio: 1.00
# alpha,beta: 35.00 ,2.50
# ratio: 1.00
# alpha,beta: 5.00 ,0.00
# ratio: 1.00
# alpha,beta: 9.00 ,5.00
# ratio: 1.00
# alpha,beta: 25.00 ,24.45
# ratio: 1.00
# alpha,beta: 13.00 ,3.17
# ratio: 1.00
# alpha,beta: 31.00 ,11.56
# ratio: 1.00
# alpha,beta: 28.00 ,10.81
# ratio: 1.00
# alpha,beta: 7.00 ,3.50
# ratio: 1.00
# alpha,beta: 7.00 ,1.80
# ratio: 1.00
# alpha,beta: 10.00 ,1.73
# ratio: 1.00
# alpha,beta: 33.00 ,18.33
# ratio: 1.00
# alpha,beta: 12.00 ,3.88
# ratio: 1.00
# alpha,beta: 20.00 ,8.00
# ratio: 1.00
# alpha,beta: 32.00 ,9.71
# ratio: 1.00
# alpha,beta: 7.00 ,6.95
# ratio: 1.00
# alpha,beta: 33.00 ,8.90
# ratio: 1.00
# alpha,beta: 7.00 ,4.04
# ratio: 1.00
# alpha,beta: 7.00 ,1.88
# ratio: 1.00
# alpha,beta: 27.00 ,1.47
# ratio: 1.00
# alpha,beta: 5.00 ,0.90
# ratio: 1.00
# alpha,beta: 10.00 ,6.73
# ratio: 1.00
# alpha,beta: 38.00 ,4.81
# ratio: 1.00
# alpha,beta: 63.00 ,16.62
# ratio: 1.00
# alpha,beta: 7.00 ,6.62
# ratio: 1.00
# alpha,beta: 50.00 ,23.19
# ratio: 1.00
# alpha,beta: 15.00 ,3.60
# ratio: 1.00
# alpha,beta: 10.00 ,20.99
# ratio: 1.00
# alpha,beta: 13.00 ,10.80
# ratio: 1.00
# alpha,beta: 5.00 ,2.58
# ratio: 1.00
# alpha,beta: 9.00 ,2.49
# ratio: 1.00
# alpha,beta: 15.00 ,5.40
# ratio: 1.00
# alpha,beta: 18.00 ,3.13
# ratio: 1.00
# alpha,beta: 23.00 ,12.95
# ratio: 1.00
# alpha,beta: 20.00 ,2.52
# ratio: 1.00
# alpha,beta: 12.00 ,9.17
# ratio: 1.00
# alpha,beta: 50.00 ,50.70
# ratio: 1.00
# alpha,beta: 17.00 ,3.25
# ratio: 1.00
# alpha,beta: 9.00 ,7.99
# ratio: 1.00
# alpha,beta: 29.00 ,8.37
# ratio: 1.00
# alpha,beta: 13.00 ,3.46
# ratio: 1.00
# alpha,beta: 46.00 ,15.76
# ratio: 1.00
# alpha,beta: 12.00 ,3.77
# ratio: 1.00
# alpha,beta: 37.00 ,19.02
# ratio: 1.00
# alpha,beta: 19.00 ,8.24
# ratio: 1.00
# alpha,beta: 24.00 ,10.79
# ratio: 1.00
# alpha,beta: 16.00 ,9.10
# ratio: 1.00
# alpha,beta: 36.00 ,2.60
# ratio: 1.00
# alpha,beta: 25.00 ,9.53
# ratio: 1.00
# alpha,beta: 22.00 ,7.15
# ratio: 1.00
# alpha,beta: 12.00 ,0.78
# ratio: 1.00
# alpha,beta: 67.00 ,10.12
# ratio: 1.00
# alpha,beta: 19.00 ,2.50
# ratio: 1.00
# alpha,beta: 31.00 ,11.46
# ratio: 1.00
# alpha,beta: 13.00 ,7.07
# ratio: 1.00
# alpha,beta: 12.00 ,3.72
# ratio: 1.00
# alpha,beta: 22.00 ,15.64
# ratio: 1.00
# alpha,beta: 44.00 ,18.53
# ratio: 1.00
# alpha,beta: 38.00 ,15.41
# ratio: 1.00
# alpha,beta: 9.00 ,9.37
# ratio: 1.00
# alpha,beta: 26.00 ,19.93
# ratio: 1.00
# alpha,beta: 11.00 ,3.95
# ratio: 1.00
# alpha,beta: 13.00 ,8.21
# ratio: 1.00
# alpha,beta: 8.00 ,6.16
# ratio: 1.00
# alpha,beta: 29.00 ,10.41
# ratio: 1.00
# alpha,beta: 12.00 ,4.62
# ratio: 1.00
# alpha,beta: 18.00 ,32.52
# ratio: 1.00
# alpha,beta: 11.00 ,9.22
# ratio: 1.00
# alpha,beta: 7.00 ,0.00
# ratio: 1.00
# alpha,beta: 19.00 ,28.87
# ratio: 1.00
# alpha,beta: 9.00 ,6.57
# ratio: 1.00
# alpha,beta: 39.00 ,72.42
# ratio: 1.00
# alpha,beta: 10.00 ,3.36
# ratio: 1.00
# alpha,beta: 7.00 ,2.44
# ratio: 1.00
# alpha,beta: 27.00 ,36.37
# ratio: 1.00
# alpha,beta: 9.00 ,2.29
# ratio: 1.00
# alpha,beta: 29.00 ,14.21
# ratio: 1.00
# alpha,beta: 9.00 ,5.54
# ratio: 1.00
# alpha,beta: 6.00 ,1.27
# ratio: 1.00
# alpha,beta: 7.00 ,3.56
# ratio: 1.00
# alpha,beta: 9.00 ,2.04
# ratio: 1.00
# alpha,beta: 80.00 ,38.97
# ratio: 1.00
# alpha,beta: 15.00 ,11.24
# ratio: 1.00
# alpha,beta: 17.00 ,7.31
# ratio: 1.00
# alpha,beta: 15.00 ,9.40
# ratio: 1.00
# alpha,beta: 7.00 ,5.81
# ratio: 1.00
# alpha,beta: 72.00 ,10.59
# ratio: 1.00
# alpha,beta: 13.00 ,7.91
# ratio: 1.00
# alpha,beta: 6.00 ,6.84
# ratio: 1.00
# alpha,beta: 7.00 ,2.22
# ratio: 1.00
# alpha,beta: 14.00 ,11.79
# ratio: 1.00
# alpha,beta: 12.00 ,12.16
# ratio: 1.00
# alpha,beta: 20.00 ,8.78
# ratio: 1.00
# alpha,beta: 12.00 ,6.89
# ratio: 1.00
# alpha,beta: 71.00 ,3.14
# ratio: 1.00
# alpha,beta: 5.00 ,2.46
# ratio: 1.00
# alpha,beta: 14.00 ,3.39
# ratio: 1.00
# alpha,beta: 16.00 ,9.89
# ratio: 1.00
# alpha,beta: 6.00 ,0.50
# ratio: 1.00
# alpha,beta: 8.00 ,3.52
# ratio: 1.00
# alpha,beta: 17.00 ,25.34
# ratio: 1.00
# alpha,beta: 59.00 ,57.00
# ratio: 1.00
# alpha,beta: 72.00 ,27.47
# ratio: 1.00
# alpha,beta: 47.00 ,14.84
# ratio: 1.00
# alpha,beta: 13.00 ,4.37
# ratio: 1.00
# alpha,beta: 34.00 ,3.28
# ratio: 1.00
# alpha,beta: 8.00 ,15.70
# ratio: 1.00
# alpha,beta: 14.00 ,16.13
# ratio: 1.00
# alpha,beta: 8.00 ,0.94
# ratio: 1.00
# alpha,beta: 78.00 ,132.55
# ratio: 1.00
# alpha,beta: 17.00 ,13.94
# ratio: 1.00
# alpha,beta: 41.00 ,20.41
# ratio: 1.00
# alpha,beta: 23.00 ,26.48
# ratio: 1.00
# alpha,beta: 33.00 ,13.63
# ratio: 1.00
# alpha,beta: 7.00 ,6.41
# ratio: 1.00
# alpha,beta: 10.00 ,4.93
# ratio: 1.00
# alpha,beta: 24.00 ,12.34
# ratio: 1.00
# alpha,beta: 11.00 ,3.11
# ratio: 1.00
# alpha,beta: 9.00 ,1.20
# ratio: 1.00
# alpha,beta: 10.00 ,7.62
# ratio: 1.00
# alpha,beta: 7.00 ,4.11
# ratio: 1.00
# alpha,beta: 21.00 ,4.15
# ratio: 1.00
# alpha,beta: 24.00 ,22.22
# ratio: 1.00
# alpha,beta: 39.00 ,15.56
# ratio: 1.00
# alpha,beta: 12.00 ,3.37
# ratio: 1.00
# alpha,beta: 67.00 ,23.41
# ratio: 1.00
# alpha,beta: 8.00 ,3.71
# ratio: 1.00
# alpha,beta: 4.00 ,0.91
# ratio: 1.00
# alpha,beta: 4.00 ,1.78
# ratio: 1.00
# alpha,beta: 6.00 ,3.41
# ratio: 1.00
# alpha,beta: 102.00 ,18.54
# ratio: 1.00
# alpha,beta: 18.00 ,10.26
# ratio: 1.00
# alpha,beta: 5.00 ,5.84
# ratio: 1.00
# alpha,beta: 35.00 ,16.68
# ratio: 1.00
# alpha,beta: 31.00 ,3.23
# ratio: 1.00
# alpha,beta: 28.00 ,4.80
# ratio: 1.00
# alpha,beta: 82.00 ,116.86
# ratio: 1.00
# alpha,beta: 39.00 ,15.41
# ratio: 1.00
# alpha,beta: 5.00 ,7.46
# ratio: 1.00
# alpha,beta: 31.00 ,15.95
# ratio: 1.00
# alpha,beta: 11.00 ,3.36
# ratio: 1.00
# alpha,beta: 85.00 ,99.12
# ratio: 1.00
# alpha,beta: 14.00 ,3.19
# ratio: 1.00
# alpha,beta: 14.00 ,4.81
# ratio: 1.00
# alpha,beta: 15.00 ,5.21
# ratio: 1.00
# alpha,beta: 107.00 ,8.28
# ratio: 1.00
# alpha,beta: 35.00 ,26.00
# ratio: 1.00
# alpha,beta: 6.00 ,6.45
# ratio: 1.00
# alpha,beta: 15.00 ,5.88
# ratio: 1.00
# alpha,beta: 77.00 ,9.64
# ratio: 1.00
# alpha,beta: 16.00 ,24.29
# ratio: 1.00
# alpha,beta: 50.00 ,16.18
# ratio: 1.00
# alpha,beta: 3.00 ,4.91
# ratio: 1.00
# alpha,beta: 38.00 ,19.84
# ratio: 1.00
# alpha,beta: 13.00 ,5.11
# ratio: 1.00
# alpha,beta: 22.00 ,22.20
# ratio: 1.00
# alpha,beta: 24.00 ,13.20
# ratio: 1.00
# alpha,beta: 41.00 ,18.80
# ratio: 1.00
# alpha,beta: 8.00 ,2.48
# ratio: 1.00
# alpha,beta: 14.00 ,10.29
# ratio: 1.00
# alpha,beta: 6.00 ,4.80
# ratio: 1.00
# alpha,beta: 14.00 ,7.62
# ratio: 1.00
# alpha,beta: 11.00 ,8.01
# ratio: 1.00
# alpha,beta: 10.00 ,2.65
# ratio: 1.00
# alpha,beta: 28.00 ,4.99
# ratio: 1.00
# alpha,beta: 5.00 ,9.46
# ratio: 1.00
# alpha,beta: 9.00 ,3.54
# ratio: 1.00
# alpha,beta: 6.00 ,2.35
# ratio: 1.00
# alpha,beta: 23.00 ,9.32
# ratio: 1.00
# alpha,beta: 10.00 ,4.35
# ratio: 1.00
# alpha,beta: 6.00 ,3.21
# ratio: 1.00
# alpha,beta: 3.00 ,1.87
# ratio: 1.00
# alpha,beta: 5.00 ,7.41
# ratio: 1.00
# alpha,beta: 16.00 ,3.08
# ratio: 1.00
# alpha,beta: 41.00 ,14.38
# ratio: 1.00
# alpha,beta: 8.00 ,4.64
# ratio: 1.00
# alpha,beta: 6.00 ,4.91
# ratio: 1.00
# alpha,beta: 12.00 ,7.78
# ratio: 1.00
# alpha,beta: 20.00 ,20.05
# ratio: 1.00
# alpha,beta: 2.00 ,2.46
# ratio: 1.00
# alpha,beta: 7.00 ,6.49
# ratio: 1.00
# alpha,beta: 102.00 ,35.29
# ratio: 1.00
# alpha,beta: 9.00 ,4.36
# ratio: 1.00
# alpha,beta: 30.00 ,15.47
# ratio: 1.00
# alpha,beta: 24.00 ,12.32
# ratio: 1.00
# alpha,beta: 14.00 ,13.34
# ratio: 1.00
# alpha,beta: 60.00 ,12.33
# ratio: 1.00
# alpha,beta: 23.00 ,7.70
# ratio: 1.00
# alpha,beta: 16.00 ,5.23
# ratio: 1.00
# alpha,beta: 11.00 ,5.25
# ratio: 1.00
# alpha,beta: 23.00 ,2.85
# ratio: 1.00
# alpha,beta: 30.00 ,16.48
# ratio: 1.00
# alpha,beta: 13.00 ,1.53
# ratio: 1.00
# alpha,beta: 47.00 ,40.12
# ratio: 1.00
# alpha,beta: 8.00 ,8.91
# ratio: 1.00
# alpha,beta: 23.00 ,2.40
# ratio: 1.00
# alpha,beta: 14.00 ,13.89
# ratio: 1.00
# alpha,beta: 26.00 ,23.42
# ratio: 1.00
# alpha,beta: 38.00 ,21.70
# ratio: 1.00
# alpha,beta: 41.00 ,17.44
# ratio: 1.00
# alpha,beta: 24.00 ,8.62
# ratio: 1.00
# alpha,beta: 31.00 ,18.84
# ratio: 1.00
# alpha,beta: 29.00 ,3.04
# ratio: 1.00
# alpha,beta: 147.00 ,9.31
# ratio: 1.00
# alpha,beta: 23.00 ,1.74
# ratio: 1.00
# alpha,beta: 10.00 ,6.37
# ratio: 1.00
# alpha,beta: 6.00 ,3.28
# ratio: 1.00
# alpha,beta: 19.00 ,3.52
# ratio: 1.00
# alpha,beta: 13.00 ,20.62
# ratio: 1.00
# alpha,beta: 23.00 ,2.25
# ratio: 1.00
# alpha,beta: 35.00 ,25.54
# ratio: 1.00
# alpha,beta: 14.00 ,1.20
# ratio: 1.00
# alpha,beta: 4.00 ,1.54
# ratio: 1.00
# alpha,beta: 62.00 ,16.23
# ratio: 1.00
# alpha,beta: 10.00 ,5.05
# ratio: 1.00
# alpha,beta: 13.00 ,7.00
# ratio: 1.00
# alpha,beta: 5.00 ,5.46
# ratio: 1.00
# alpha,beta: 17.00 ,8.99
# ratio: 1.00
# alpha,beta: 13.00 ,22.80
# ratio: 1.00
# alpha,beta: 13.00 ,2.36
# ratio: 1.00
# alpha,beta: 25.00 ,4.57
# ratio: 1.00
# alpha,beta: 11.00 ,10.90
# ratio: 1.00
# alpha,beta: 28.00 ,9.97
# ratio: 1.00
# alpha,beta: 7.00 ,3.42
# ratio: 1.00
# alpha,beta: 44.00 ,15.66
# ratio: 1.00
# alpha,beta: 30.00 ,14.84
# ratio: 1.00
# alpha,beta: 14.00 ,10.33
# ratio: 1.00
# alpha,beta: 90.00 ,16.50
# ratio: 1.00
# alpha,beta: 30.00 ,13.69
# ratio: 1.00
# alpha,beta: 6.00 ,22.36
# ratio: 1.00
# alpha,beta: 78.00 ,44.01
# ratio: 1.00
# alpha,beta: 22.00 ,6.80
# ratio: 1.00
# alpha,beta: 10.00 ,2.41
# ratio: 1.00
# alpha,beta: 9.00 ,0.86
# ratio: 1.00
# alpha,beta: 14.00 ,5.61
# ratio: 1.00
# alpha,beta: 15.00 ,4.52
# ratio: 1.00
# alpha,beta: 8.00 ,9.05
# ratio: 1.00
# alpha,beta: 6.00 ,2.40
# ratio: 1.00
# alpha,beta: 36.00 ,0.95
# ratio: 1.00
# alpha,beta: 30.00 ,15.29
# ratio: 1.00
# alpha,beta: 21.00 ,7.62
# ratio: 1.00
# alpha,beta: 39.00 ,6.03
# ratio: 1.00
# alpha,beta: 63.00 ,8.37
# ratio: 1.00
# alpha,beta: 18.00 ,28.31
# ratio: 1.00
# alpha,beta: 8.00 ,4.19
# ratio: 1.00
# alpha,beta: 5.00 ,4.95
# ratio: 1.00
# alpha,beta: 33.00 ,6.06
# ratio: 1.00
# alpha,beta: 163.00 ,16.63
# ratio: 1.00
# alpha,beta: 18.00 ,12.24
# ratio: 1.00
# alpha,beta: 43.00 ,8.37
# ratio: 1.00
# alpha,beta: 6.00 ,7.97
# ratio: 1.00
# alpha,beta: 5.00 ,1.76
# ratio: 1.00
# alpha,beta: 18.00 ,9.32
# ratio: 1.00
# alpha,beta: 16.00 ,6.40
# ratio: 1.00
# alpha,beta: 13.00 ,5.51
# ratio: 1.00
# alpha,beta: 71.00 ,12.65
# ratio: 1.00
# alpha,beta: 14.00 ,8.77
# ratio: 1.00
# alpha,beta: 18.00 ,4.76
# ratio: 1.00
# alpha,beta: 8.00 ,2.55
# ratio: 1.00
# alpha,beta: 6.00 ,0.85
# ratio: 1.00
# alpha,beta: 8.00 ,4.30
# ratio: 1.00
# alpha,beta: 3.00 ,4.22
# ratio: 1.00
# alpha,beta: 15.00 ,0.86
# ratio: 1.00
# alpha,beta: 60.00 ,14.53
# ratio: 1.00
# alpha,beta: 71.00 ,48.22
# ratio: 1.00
# alpha,beta: 6.00 ,3.23
# ratio: 1.00
# alpha,beta: 25.00 ,17.53
# ratio: 1.00
# alpha,beta: 5.00 ,0.85
# ratio: 1.00
# alpha,beta: 5.00 ,1.44
# ratio: 1.00
# alpha,beta: 23.00 ,7.44
# ratio: 1.00
# alpha,beta: 41.00 ,13.48
# ratio: 1.00
# alpha,beta: 7.00 ,3.86
# ratio: 1.00
# alpha,beta: 35.00 ,1.67
# ratio: 1.00
# alpha,beta: 6.00 ,2.82
# ratio: 1.00
# alpha,beta: 27.00 ,0.95
# ratio: 1.00
# alpha,beta: 28.00 ,10.83
# ratio: 1.00
# alpha,beta: 5.00 ,1.69
# ratio: 1.00
# alpha,beta: 8.00 ,6.97
# ratio: 1.00
# alpha,beta: 3.00 ,2.39
# ratio: 1.00
# alpha,beta: 10.00 ,6.97
# ratio: 1.00
# alpha,beta: 51.00 ,5.81
# ratio: 1.00
# alpha,beta: 34.00 ,20.99
# ratio: 1.00
# alpha,beta: 8.00 ,1.48
# ratio: 1.00
# alpha,beta: 16.00 ,3.35
# ratio: 1.00
# alpha,beta: 7.00 ,22.68
# ratio: 1.00
# alpha,beta: 41.00 ,11.23
# ratio: 1.00
# alpha,beta: 61.00 ,48.13
# ratio: 1.00
# alpha,beta: 2.00 ,4.31
# ratio: 1.00
# alpha,beta: 18.00 ,15.72
# ratio: 1.00
# alpha,beta: 5.00 ,26.98
# ratio: 1.00
# alpha,beta: 14.00 ,4.12
# ratio: 1.00
# alpha,beta: 10.00 ,2.28
# ratio: 1.00
# alpha,beta: 77.00 ,125.48
# ratio: 1.00
# alpha,beta: 4.00 ,1.02
# ratio: 1.00
# alpha,beta: 14.00 ,8.08
# ratio: 1.00
# alpha,beta: 27.00 ,10.78
# ratio: 1.00
# alpha,beta: 31.00 ,17.11
# ratio: 1.00
# alpha,beta: 10.00 ,0.95
# ratio: 1.00
# alpha,beta: 30.00 ,0.65
# ratio: 1.00
# alpha,beta: 15.00 ,0.78
# ratio: 1.00
# alpha,beta: 8.00 ,12.48
# ratio: 1.00
# alpha,beta: 34.00 ,29.06
# ratio: 1.00
# alpha,beta: 20.00 ,25.70
# ratio: 1.00
# alpha,beta: 106.00 ,13.07
# ratio: 1.00
# alpha,beta: 5.00 ,0.56
# ratio: 1.00
# alpha,beta: 25.00 ,19.85
# ratio: 1.00
# alpha,beta: 70.00 ,5.59
# ratio: 1.00
# alpha,beta: 8.00 ,7.51
# ratio: 1.00
# alpha,beta: 12.00 ,1.83
# ratio: 1.00
# alpha,beta: 36.00 ,27.17
# ratio: 1.00
# alpha,beta: 2.00 ,2.07
# ratio: 1.00
# alpha,beta: 16.00 ,4.56
# ratio: 1.00
# alpha,beta: 9.00 ,4.92
# ratio: 1.00
# alpha,beta: 13.00 ,8.80
# ratio: 1.00
# alpha,beta: 13.00 ,5.69
# ratio: 1.00
# alpha,beta: 10.00 ,9.79
# ratio: 1.00
# alpha,beta: 11.00 ,0.92
# ratio: 1.00
# alpha,beta: 31.00 ,12.44
# ratio: 1.00
# alpha,beta: 64.00 ,6.05
# ratio: 1.00
# alpha,beta: 18.00 ,1.58
# ratio: 1.00
# alpha,beta: 21.00 ,6.41
# ratio: 1.00
# alpha,beta: 69.00 ,22.09
# ratio: 1.00
# alpha,beta: 18.00 ,5.23
# ratio: 1.00
# alpha,beta: 15.00 ,8.34
# ratio: 1.00
# alpha,beta: 42.00 ,10.40
# ratio: 1.00
# alpha,beta: 10.00 ,2.63
# ratio: 1.00
# alpha,beta: 5.00 ,3.68
# ratio: 1.00
# alpha,beta: 8.00 ,4.96
# ratio: 1.00
# alpha,beta: 16.00 ,8.60
# ratio: 1.00
# alpha,beta: 11.00 ,18.13
# ratio: 1.00
# alpha,beta: 14.00 ,6.12
# ratio: 1.00
# alpha,beta: 48.00 ,15.24
# ratio: 1.00
# alpha,beta: 34.00 ,8.82
# ratio: 1.00
# alpha,beta: 3.00 ,0.85
# ratio: 1.00
# alpha,beta: 29.00 ,10.31
# ratio: 1.00
# alpha,beta: 41.00 ,12.32
# ratio: 1.00
# alpha,beta: 8.00 ,0.52
# ratio: 1.00
# alpha,beta: 35.00 ,12.49
# ratio: 1.00
# alpha,beta: 12.00 ,2.32
# ratio: 1.00
# alpha,beta: 19.00 ,7.48
# ratio: 1.00
# alpha,beta: 48.00 ,48.68
# ratio: 1.00
# alpha,beta: 3.00 ,1.62
# ratio: 1.00
# alpha,beta: 5.00 ,4.93
# ratio: 1.00
# alpha,beta: 10.00 ,16.35
# ratio: 1.00
# alpha,beta: 9.00 ,0.81
# ratio: 1.00
# alpha,beta: 10.00 ,2.82
# ratio: 1.00
# alpha,beta: 40.00 ,11.04
# ratio: 1.00
# alpha,beta: 70.00 ,15.80
# ratio: 1.00
# alpha,beta: 20.00 ,9.04
# ratio: 1.00
# alpha,beta: 22.00 ,12.40
# ratio: 1.00
# alpha,beta: 31.00 ,11.91
# ratio: 1.00
# alpha,beta: 17.00 ,18.70
# ratio: 1.00
# alpha,beta: 22.00 ,3.08
# ratio: 1.00
# alpha,beta: 16.00 ,10.44
# ratio: 1.00
# alpha,beta: 7.00 ,5.92
# ratio: 1.00
# alpha,beta: 30.00 ,2.59
# ratio: 1.00
# alpha,beta: 12.00 ,7.93
# ratio: 1.00
# alpha,beta: 7.00 ,6.70
# ratio: 1.00
# alpha,beta: 37.00 ,18.70
# ratio: 1.00
# alpha,beta: 7.00 ,0.93
# ratio: 1.00
# alpha,beta: 24.00 ,18.08
# ratio: 1.00
# alpha,beta: 8.00 ,0.00
# ratio: 1.00
# alpha,beta: 7.00 ,3.39
# ratio: 1.00
# alpha,beta: 20.00 ,8.33
# ratio: 1.00
# alpha,beta: 20.00 ,19.65
# ratio: 1.00
# alpha,beta: 6.00 ,3.11
# ratio: 1.00
# alpha,beta: 37.00 ,4.59
# ratio: 1.00
# alpha,beta: 12.00 ,5.42
# ratio: 1.00
# alpha,beta: 7.00 ,4.70
# ratio: 1.00
# alpha,beta: 16.00 ,8.78
# ratio: 1.00
# alpha,beta: 21.00 ,23.77
# ratio: 1.00
# alpha,beta: 5.00 ,2.66
# ratio: 1.00
# alpha,beta: 8.00 ,6.79
# ratio: 1.00
# alpha,beta: 94.00 ,13.40
# ratio: 1.00
# alpha,beta: 6.00 ,0.95
# ratio: 1.00
# alpha,beta: 30.00 ,14.87
# ratio: 1.00
# alpha,beta: 5.00 ,3.04
# ratio: 1.00
# alpha,beta: 18.00 ,11.74
# ratio: 1.00
# alpha,beta: 42.00 ,15.61
# ratio: 1.00
# alpha,beta: 5.00 ,2.27
# ratio: 1.00
# alpha,beta: 12.00 ,14.84
# ratio: 1.00
# alpha,beta: 11.00 ,3.73
# ratio: 1.00
# alpha,beta: 42.00 ,15.16
# ratio: 1.00
# alpha,beta: 9.00 ,3.74
# ratio: 1.00
# alpha,beta: 23.00 ,11.01
# ratio: 1.00
# alpha,beta: 24.00 ,13.79
# ratio: 1.00
# alpha,beta: 10.00 ,7.31
# ratio: 1.00
# alpha,beta: 8.00 ,9.35
# ratio: 1.00
# alpha,beta: 11.00 ,3.23
# ratio: 1.00
# alpha,beta: 21.00 ,3.84
# ratio: 1.00
# alpha,beta: 42.00 ,7.38
# ratio: 1.00
# alpha,beta: 9.00 ,4.93
# ratio: 1.00
# alpha,beta: 26.00 ,12.95
# ratio: 1.00
# alpha,beta: 4.00 ,3.93
# ratio: 1.00
# alpha,beta: 21.00 ,21.95
# ratio: 1.00
# alpha,beta: 43.00 ,10.38
# ratio: 1.00
# alpha,beta: 19.00 ,17.74
# ratio: 1.00
# alpha,beta: 6.00 ,14.52
# ratio: 1.00
# alpha,beta: 5.00 ,5.68
# ratio: 1.00
# alpha,beta: 22.00 ,43.69
# ratio: 1.00
# alpha,beta: 38.00 ,9.52
# ratio: 1.00
# alpha,beta: 7.00 ,3.05
# ratio: 1.00
# alpha,beta: 26.00 ,40.14
# ratio: 1.00
# alpha,beta: 16.00 ,2.34
# ratio: 1.00
# alpha,beta: 4.00 ,3.17
# ratio: 1.00
# alpha,beta: 17.00 ,20.13
# ratio: 1.00
# alpha,beta: 134.00 ,22.80
# ratio: 1.00
# alpha,beta: 54.00 ,7.66
# ratio: 1.00
# alpha,beta: 12.00 ,24.04
# ratio: 1.00
# alpha,beta: 37.00 ,14.23
# ratio: 1.00
# alpha,beta: 13.00 ,4.11
# ratio: 1.00
# alpha,beta: 24.00 ,4.67
# ratio: 1.00
# alpha,beta: 16.00 ,14.89
# ratio: 1.00
# alpha,beta: 4.00 ,4.34
# ratio: 1.00
# alpha,beta: 19.00 ,4.59
# ratio: 1.00
# alpha,beta: 66.00 ,61.38
# ratio: 1.00
# alpha,beta: 28.00 ,6.72
# ratio: 1.00
# alpha,beta: 22.00 ,0.89
# ratio: 1.00
# alpha,beta: 22.00 ,13.11
# ratio: 1.00
# alpha,beta: 12.00 ,6.01
# ratio: 1.00
# alpha,beta: 18.00 ,25.89
# ratio: 1.00
# alpha,beta: 11.00 ,2.06
# ratio: 1.00
# alpha,beta: 19.00 ,4.81
# ratio: 1.00
# alpha,beta: 17.00 ,4.31
# ratio: 1.00
# alpha,beta: 27.00 ,8.80
# ratio: 1.00
# alpha,beta: 13.00 ,5.04
# ratio: 1.00
# alpha,beta: 76.00 ,35.89
# ratio: 1.00
# alpha,beta: 57.00 ,19.64
# ratio: 1.00
# alpha,beta: 26.00 ,9.37
# ratio: 1.00
# alpha,beta: 10.00 ,14.64
# ratio: 1.00
# alpha,beta: 41.00 ,52.52
# ratio: 1.00
# alpha,beta: 7.00 ,2.56
# ratio: 1.00
# alpha,beta: 4.00 ,11.38
# ratio: 1.00
# alpha,beta: 6.00 ,4.09
# ratio: 1.00
# alpha,beta: 7.00 ,2.90
# ratio: 1.00
# alpha,beta: 73.00 ,14.26
# ratio: 1.00
# alpha,beta: 59.00 ,5.53
# ratio: 1.00
# alpha,beta: 6.00 ,0.62
# ratio: 1.00
# alpha,beta: 73.00 ,25.99
# ratio: 1.00
# alpha,beta: 56.00 ,15.67
# ratio: 1.00
# alpha,beta: 22.00 ,32.03
# ratio: 1.00
# alpha,beta: 18.00 ,3.67
# ratio: 1.00
# alpha,beta: 16.00 ,21.47
# ratio: 1.00
# alpha,beta: 68.00 ,14.79
# ratio: 1.00
# alpha,beta: 25.00 ,9.28
# ratio: 1.00
# alpha,beta: 7.00 ,7.13
# ratio: 1.00
# alpha,beta: 29.00 ,10.10
# ratio: 1.00
# alpha,beta: 16.00 ,8.11
# ratio: 1.00
# alpha,beta: 4.00 ,0.80
# ratio: 1.00
# alpha,beta: 59.00 ,8.55
# ratio: 1.00
# alpha,beta: 42.00 ,16.47
# ratio: 1.00
# alpha,beta: 7.00 ,2.83
# ratio: 1.00
# alpha,beta: 34.00 ,43.17
# ratio: 1.00
# alpha,beta: 15.00 ,4.97
# ratio: 1.00
# alpha,beta: 5.00 ,5.29
# ratio: 1.00
# alpha,beta: 10.00 ,17.02
# ratio: 1.00
# alpha,beta: 19.00 ,4.21
# ratio: 1.00
# alpha,beta: 25.00 ,19.78
# ratio: 1.00
# alpha,beta: 30.00 ,17.87
# ratio: 1.00
# alpha,beta: 39.00 ,6.24
# ratio: 1.00
# alpha,beta: 24.00 ,14.23
# ratio: 1.00
# alpha,beta: 61.00 ,20.14
# ratio: 1.00
# alpha,beta: 16.00 ,11.62
# ratio: 1.00
# alpha,beta: 13.00 ,3.50
# ratio: 1.00
# alpha,beta: 13.00 ,3.98
# ratio: 1.00
# alpha,beta: 7.00 ,4.40
# ratio: 1.00
# alpha,beta: 6.00 ,7.29
# ratio: 1.00
# alpha,beta: 23.00 ,11.20
# ratio: 1.00
# alpha,beta: 10.00 ,4.00
# ratio: 1.00
# alpha,beta: 14.00 ,8.23
# ratio: 1.00
# alpha,beta: 18.00 ,6.77
# ratio: 1.00
# alpha,beta: 24.00 ,12.12
# ratio: 1.00
# alpha,beta: 15.00 ,12.00
# ratio: 1.00
# alpha,beta: 14.00 ,12.67
# ratio: 1.00
# alpha,beta: 16.00 ,8.80
# ratio: 1.00
# alpha,beta: 20.00 ,8.15
# ratio: 1.00
# alpha,beta: 23.00 ,10.88
# ratio: 1.00
# alpha,beta: 28.00 ,32.63
# ratio: 1.00
# alpha,beta: 21.00 ,4.08
# ratio: 1.00
# alpha,beta: 48.00 ,22.94
# ratio: 1.00
# alpha,beta: 6.00 ,5.01
# ratio: 1.00
# alpha,beta: 10.00 ,7.49
# ratio: 1.00
# alpha,beta: 6.00 ,0.95
# ratio: 1.00
# alpha,beta: 37.00 ,37.49
# ratio: 1.00
# alpha,beta: 33.00 ,48.21
# ratio: 1.00
# alpha,beta: 57.00 ,12.76
# ratio: 1.00
# alpha,beta: 12.00 ,7.85
# ratio: 1.00
# alpha,beta: 35.00 ,16.34
# ratio: 1.00
# alpha,beta: 8.00 ,2.63
# ratio: 1.00
# alpha,beta: 38.00 ,19.14
# ratio: 1.00
# alpha,beta: 28.00 ,10.12
# ratio: 1.00
# alpha,beta: 36.00 ,18.84
# ratio: 1.00
# alpha,beta: 28.00 ,6.33
# ratio: 1.00
# alpha,beta: 24.00 ,15.60
# ratio: 1.00
# alpha,beta: 7.00 ,2.41
# ratio: 1.00
# alpha,beta: 37.00 ,27.80
# ratio: 1.00
# alpha,beta: 21.00 ,4.28
# ratio: 1.00
# alpha,beta: 48.00 ,24.54
# ratio: 1.00
# alpha,beta: 23.00 ,6.29
# ratio: 1.00
# alpha,beta: 34.00 ,35.27
# ratio: 1.00
# alpha,beta: 69.00 ,8.99
# ratio: 1.00
# alpha,beta: 7.00 ,4.55
# ratio: 1.00
# alpha,beta: 8.00 ,11.15
# ratio: 1.00
# alpha,beta: 8.00 ,6.19
# ratio: 1.00
# alpha,beta: 6.00 ,2.46
# ratio: 1.00
# alpha,beta: 16.00 ,1.50
# ratio: 1.00
# alpha,beta: 8.00 ,8.25
# ratio: 1.00
# alpha,beta: 36.00 ,5.18
# ratio: 1.00
# alpha,beta: 30.00 ,9.45
# ratio: 1.00
# alpha,beta: 47.00 ,16.04
# ratio: 1.00
# alpha,beta: 8.00 ,0.58
# ratio: 1.00
# alpha,beta: 4.00 ,9.49
# ratio: 1.00
# alpha,beta: 30.00 ,7.79
# ratio: 1.00
# alpha,beta: 14.00 ,6.76
# ratio: 1.00
# alpha,beta: 6.00 ,10.54
# ratio: 1.00
# alpha,beta: 62.00 ,40.94
# ratio: 1.00
# alpha,beta: 51.00 ,12.05
# ratio: 1.00
# alpha,beta: 20.00 ,15.09
# ratio: 1.00
# alpha,beta: 15.00 ,13.64
# ratio: 1.00
# alpha,beta: 24.00 ,5.00
# ratio: 1.00
# alpha,beta: 10.00 ,13.98
# ratio: 1.00
# alpha,beta: 44.00 ,8.49
# ratio: 1.00
# alpha,beta: 13.00 ,0.94
# ratio: 1.00
# alpha,beta: 16.00 ,11.09
# ratio: 1.00
# alpha,beta: 5.00 ,5.26
# ratio: 1.00
# alpha,beta: 29.00 ,7.02
# ratio: 1.00
# alpha,beta: 12.00 ,10.51
# ratio: 1.00
# alpha,beta: 21.00 ,32.87
# ratio: 1.00
# alpha,beta: 4.00 ,2.83
# ratio: 1.00
# alpha,beta: 39.00 ,35.02
# ratio: 1.00
# alpha,beta: 9.00 ,4.33
# ratio: 1.00
# alpha,beta: 7.00 ,4.78
# ratio: 1.00
# alpha,beta: 35.00 ,15.87
# ratio: 1.00
# alpha,beta: 33.00 ,14.21
# ratio: 1.00
# alpha,beta: 30.00 ,10.95
# ratio: 1.00
# alpha,beta: 19.00 ,3.99
# ratio: 1.00
# alpha,beta: 4.00 ,0.61
# ratio: 1.00
# alpha,beta: 16.00 ,6.36
# ratio: 1.00
# alpha,beta: 10.00 ,10.19
# ratio: 1.00
# alpha,beta: 31.00 ,4.71
# ratio: 1.00
# alpha,beta: 13.00 ,8.90
# ratio: 1.00
# alpha,beta: 42.00 ,4.96
# ratio: 1.00
# alpha,beta: 9.00 ,4.83
# ratio: 1.00
# alpha,beta: 50.00 ,16.71
# ratio: 1.00
# alpha,beta: 6.00 ,4.31
# ratio: 1.00
# alpha,beta: 15.00 ,8.93
# ratio: 1.00
# alpha,beta: 25.00 ,9.73
# ratio: 1.00
# alpha,beta: 13.00 ,5.16
# ratio: 1.00
# alpha,beta: 10.00 ,9.84
# ratio: 1.00
# alpha,beta: 6.00 ,3.36
# ratio: 1.00
# alpha,beta: 35.00 ,16.62
# ratio: 1.00
# alpha,beta: 70.00 ,17.01
# ratio: 1.00
# alpha,beta: 15.00 ,7.60
# ratio: 1.00
# alpha,beta: 86.00 ,24.86
# ratio: 1.00
# alpha,beta: 20.00 ,20.78
# ratio: 1.00
# alpha,beta: 18.00 ,18.21
# ratio: 1.00
# alpha,beta: 74.00 ,24.24
# ratio: 1.00
# alpha,beta: 70.00 ,13.59
# ratio: 1.00
# alpha,beta: 47.00 ,13.23
# ratio: 1.00
# alpha,beta: 34.00 ,4.18
# ratio: 1.00
# alpha,beta: 10.00 ,8.77
# ratio: 1.00
# alpha,beta: 27.00 ,6.64
# ratio: 1.00
# alpha,beta: 10.00 ,3.92
# ratio: 1.00
# alpha,beta: 7.00 ,2.49
# ratio: 1.00
# alpha,beta: 31.00 ,29.07
# ratio: 1.00
# alpha,beta: 9.00 ,2.40
# ratio: 1.00
# alpha,beta: 17.00 ,8.96
# ratio: 1.00
# alpha,beta: 11.00 ,12.61
# ratio: 1.00
# alpha,beta: 39.00 ,13.71
# ratio: 1.00
# alpha,beta: 6.00 ,4.20
# ratio: 1.00
# alpha,beta: 44.00 ,38.04
# ratio: 1.00
# alpha,beta: 16.00 ,5.90
# ratio: 1.00
# alpha,beta: 11.00 ,3.66
# ratio: 1.00
# alpha,beta: 17.00 ,13.48
# ratio: 1.00
# alpha,beta: 26.00 ,29.86
# ratio: 1.00
# alpha,beta: 7.00 ,0.80
# ratio: 1.00
# alpha,beta: 9.00 ,7.87
# ratio: 1.00
# alpha,beta: 24.00 ,7.36
# ratio: 1.00
# alpha,beta: 23.00 ,4.74
# ratio: 1.00
# alpha,beta: 13.00 ,5.69
# ratio: 1.00
# alpha,beta: 30.00 ,16.34
# ratio: 1.00
# alpha,beta: 11.00 ,6.96
# ratio: 1.00
# alpha,beta: 44.00 ,23.98
# ratio: 1.00
# alpha,beta: 30.00 ,3.36
# ratio: 1.00
# alpha,beta: 31.00 ,19.76
# ratio: 1.00
# alpha,beta: 14.00 ,7.08
# ratio: 1.00
# alpha,beta: 10.00 ,3.33
# ratio: 1.00
# alpha,beta: 10.00 ,0.80
# ratio: 1.00
# alpha,beta: 9.00 ,4.67
# ratio: 1.00
# alpha,beta: 17.00 ,26.06
# ratio: 1.00
# alpha,beta: 19.00 ,1.83
# ratio: 1.00
# alpha,beta: 10.00 ,5.05
# ratio: 1.00
# alpha,beta: 77.00 ,24.79
# ratio: 1.00
# alpha,beta: 10.00 ,7.98
# ratio: 1.00
# alpha,beta: 57.00 ,18.64
# ratio: 1.00
# alpha,beta: 5.00 ,8.02
# ratio: 1.00
# alpha,beta: 23.00 ,9.77
# ratio: 1.00
# alpha,beta: 13.00 ,5.84
# ratio: 1.00
# alpha,beta: 9.00 ,13.75
# ratio: 1.00
# alpha,beta: 26.00 ,9.60
# ratio: 1.00
# alpha,beta: 19.00 ,4.14
# ratio: 1.00
# alpha,beta: 48.00 ,7.23
# ratio: 1.00
# alpha,beta: 58.00 ,67.01
# ratio: 1.00
# alpha,beta: 62.00 ,9.83
# ratio: 1.00
# alpha,beta: 48.00 ,10.70
# ratio: 1.00
# alpha,beta: 17.00 ,11.42
# ratio: 1.00
# alpha,beta: 25.00 ,11.84
# ratio: 1.00
# alpha,beta: 10.00 ,18.47
# ratio: 1.00
# alpha,beta: 23.00 ,15.08
# ratio: 1.00
# alpha,beta: 38.00 ,37.46
# ratio: 1.00
# alpha,beta: 7.00 ,2.05
# ratio: 1.00
# alpha,beta: 9.00 ,4.16
# ratio: 1.00
# alpha,beta: 48.00 ,44.41
# ratio: 1.00
# alpha,beta: 19.00 ,2.42
# ratio: 1.00
# alpha,beta: 64.00 ,13.74
# ratio: 1.00
# alpha,beta: 6.00 ,9.17
# ratio: 1.00
# alpha,beta: 33.00 ,10.34
# ratio: 1.00
# alpha,beta: 5.00 ,0.94
# ratio: 1.00
# alpha,beta: 16.00 ,6.79
# ratio: 1.00
# alpha,beta: 10.00 ,10.47
# ratio: 1.00
# alpha,beta: 33.00 ,14.28
# ratio: 1.00
# alpha,beta: 12.00 ,8.75
# ratio: 1.00
# alpha,beta: 49.00 ,13.04
# ratio: 1.00
# alpha,beta: 15.00 ,2.85
# ratio: 1.00
# alpha,beta: 15.00 ,22.73
# ratio: 1.00
# alpha,beta: 101.00 ,101.12
# ratio: 1.00
# alpha,beta: 39.00 ,14.60
# ratio: 1.00
# alpha,beta: 19.00 ,12.15
# ratio: 1.00
# alpha,beta: 13.00 ,5.09
# ratio: 1.00
# alpha,beta: 21.00 ,11.52
# ratio: 1.00
# alpha,beta: 9.00 ,5.92
# ratio: 1.00
# alpha,beta: 16.00 ,6.45
# ratio: 1.00
# alpha,beta: 19.00 ,3.45
# ratio: 1.00
# alpha,beta: 44.00 ,12.26
# ratio: 1.00
# alpha,beta: 24.00 ,26.15
# ratio: 1.00
# alpha,beta: 35.00 ,10.84
# ratio: 1.00
# alpha,beta: 56.00 ,33.19
# ratio: 1.00
# alpha,beta: 10.00 ,13.07
# ratio: 1.00
# alpha,beta: 34.00 ,14.77
# ratio: 1.00
# alpha,beta: 34.00 ,4.95
# ratio: 1.00
# alpha,beta: 18.00 ,15.93
# ratio: 1.00
# alpha,beta: 9.00 ,5.63
# ratio: 1.00
# alpha,beta: 16.00 ,4.17
# ratio: 1.00
# alpha,beta: 18.00 ,9.18
# ratio: 1.00
# alpha,beta: 14.00 ,13.56
# ratio: 1.00
# alpha,beta: 7.00 ,8.69
# ratio: 1.00
# alpha,beta: 11.00 ,9.72
# ratio: 1.00
# alpha,beta: 65.00 ,19.73
# ratio: 1.00
# alpha,beta: 14.00 ,4.41
# ratio: 1.00
# alpha,beta: 8.00 ,6.92
# ratio: 1.00
# alpha,beta: 32.00 ,36.50
# ratio: 1.00
# alpha,beta: 14.00 ,20.04
# ratio: 1.00
# alpha,beta: 58.00 ,13.05
# ratio: 1.00
# alpha,beta: 109.00 ,25.02
# ratio: 1.00
# alpha,beta: 92.00 ,22.46
# ratio: 1.00
# alpha,beta: 24.00 ,9.34
# ratio: 1.00
# alpha,beta: 98.00 ,16.24
# ratio: 1.00
# alpha,beta: 32.00 ,53.09
# ratio: 1.00
# alpha,beta: 29.00 ,26.40
# ratio: 1.00
# alpha,beta: 10.00 ,15.92
# ratio: 1.00
# alpha,beta: 16.00 ,0.66
# ratio: 1.00
# alpha,beta: 60.00 ,49.41
# ratio: 1.00
# alpha,beta: 9.00 ,8.97
# ratio: 1.00
# alpha,beta: 15.00 ,4.36
# ratio: 1.00
# alpha,beta: 11.00 ,3.96
# ratio: 1.00
# alpha,beta: 8.00 ,8.35
# ratio: 1.00
# alpha,beta: 12.00 ,7.12
# ratio: 1.00
# alpha,beta: 8.00 ,5.57
# ratio: 1.00
# alpha,beta: 5.00 ,2.39
# ratio: 1.00
# alpha,beta: 15.00 ,8.09
# ratio: 1.00
# alpha,beta: 23.00 ,26.58
# ratio: 1.00
# alpha,beta: 12.00 ,4.01
# ratio: 1.00
# alpha,beta: 53.00 ,15.72
# ratio: 1.00
# alpha,beta: 27.00 ,17.95
# ratio: 1.00
# alpha,beta: 85.00 ,28.41
# ratio: 1.00
# alpha,beta: 15.00 ,20.03
# ratio: 1.00
# alpha,beta: 24.00 ,15.28
# ratio: 1.00
# alpha,beta: 31.00 ,26.95
# ratio: 1.00
# alpha,beta: 10.00 ,4.02
# ratio: 1.00
# alpha,beta: 9.00 ,6.02
# ratio: 1.00
# alpha,beta: 67.00 ,34.40
# ratio: 1.00
# alpha,beta: 10.00 ,0.96
# ratio: 1.00
# alpha,beta: 142.00 ,30.14
# ratio: 1.00
# alpha,beta: 15.00 ,7.35
# ratio: 1.00
# alpha,beta: 7.00 ,15.81
# ratio: 1.00
# alpha,beta: 21.00 ,19.56
# ratio: 1.00
# alpha,beta: 58.00 ,14.52
# ratio: 1.00
# alpha,beta: 18.00 ,2.50
# ratio: 1.00
# alpha,beta: 63.00 ,16.85
# ratio: 1.00
# alpha,beta: 10.00 ,6.52
# ratio: 1.00
# alpha,beta: 10.00 ,9.69
# ratio: 1.00
# alpha,beta: 35.00 ,32.50
# ratio: 1.00
# alpha,beta: 12.00 ,4.44
# ratio: 1.00
# alpha,beta: 75.00 ,23.33
# ratio: 1.00
# alpha,beta: 17.00 ,4.37
# ratio: 1.00
# alpha,beta: 24.00 ,20.77
# ratio: 1.00
# alpha,beta: 14.00 ,4.79
# ratio: 1.00
# alpha,beta: 35.00 ,48.17
# ratio: 1.00
# alpha,beta: 35.00 ,16.61
# ratio: 1.00
# alpha,beta: 30.00 ,11.67
# ratio: 1.00
# alpha,beta: 71.00 ,16.14
# ratio: 1.00
# alpha,beta: 17.00 ,11.96
# ratio: 1.00
# alpha,beta: 16.00 ,8.41
# ratio: 1.00
# alpha,beta: 31.00 ,15.89
# ratio: 1.00
# alpha,beta: 2.00 ,2.50
# ratio: 1.00
# alpha,beta: 38.00 ,16.33
# ratio: 1.00
# alpha,beta: 16.00 ,4.26
# ratio: 1.00
# alpha,beta: 8.00 ,2.40
# ratio: 1.00
# alpha,beta: 17.00 ,28.51
# ratio: 1.00
# alpha,beta: 90.00 ,20.32
# ratio: 1.00
# alpha,beta: 32.00 ,9.20
# ratio: 1.00
# alpha,beta: 10.00 ,4.31
# ratio: 1.00
# alpha,beta: 8.00 ,3.04
# ratio: 1.00
# alpha,beta: 125.00 ,57.19
# ratio: 1.00
# alpha,beta: 5.00 ,2.02
# ratio: 1.00
# alpha,beta: 28.00 ,19.49
# ratio: 1.00
# alpha,beta: 43.00 ,16.97
# ratio: 1.00
# alpha,beta: 37.00 ,19.47
# ratio: 1.00
# alpha,beta: 7.00 ,2.20
# ratio: 1.00
# alpha,beta: 72.00 ,22.54
# ratio: 1.00
# alpha,beta: 127.00 ,71.03
# ratio: 1.00
# alpha,beta: 12.00 ,14.69
# ratio: 1.00
# alpha,beta: 36.00 ,27.40
# ratio: 1.00
# alpha,beta: 116.00 ,35.04
# ratio: 1.00
# alpha,beta: 31.00 ,11.88
# ratio: 1.00
# alpha,beta: 48.00 ,6.94
# ratio: 1.00
# alpha,beta: 9.00 ,3.21
# ratio: 1.00
# alpha,beta: 25.00 ,17.47
# ratio: 1.00
# alpha,beta: 40.00 ,49.89
# ratio: 1.00
# alpha,beta: 16.00 ,3.64
# ratio: 1.00
# alpha,beta: 14.00 ,3.70
# ratio: 1.00
# alpha,beta: 71.00 ,16.86
# ratio: 1.00
# alpha,beta: 15.00 ,9.08
# ratio: 1.00
# alpha,beta: 5.00 ,1.13
# ratio: 1.00
# alpha,beta: 25.00 ,11.52
# ratio: 1.00
# alpha,beta: 10.00 ,5.52
# ratio: 1.00
# alpha,beta: 42.00 ,15.83
# ratio: 1.00
# alpha,beta: 34.00 ,9.04
# ratio: 1.00
# alpha,beta: 31.00 ,7.98
# ratio: 1.00
# alpha,beta: 9.00 ,3.49
# ratio: 1.00
# alpha,beta: 19.00 ,20.76
# ratio: 1.00
# alpha,beta: 21.00 ,14.20
# ratio: 1.00
# alpha,beta: 14.00 ,6.08
# ratio: 1.00
# alpha,beta: 60.00 ,9.80
# ratio: 1.00
# alpha,beta: 22.00 ,22.78
# ratio: 1.00
# alpha,beta: 8.00 ,5.27
# ratio: 1.00
# alpha,beta: 19.00 ,2.37
# ratio: 1.00
# alpha,beta: 5.00 ,3.45
# ratio: 1.00
# alpha,beta: 32.00 ,33.10
# ratio: 1.00
# alpha,beta: 61.00 ,23.54
# ratio: 1.00
# alpha,beta: 37.00 ,11.19
# ratio: 1.00
# alpha,beta: 26.00 ,17.60
# ratio: 1.00
# alpha,beta: 14.00 ,8.74
# ratio: 1.00
# alpha,beta: 12.00 ,2.42
# ratio: 1.00
# alpha,beta: 19.00 ,21.68
# ratio: 1.00
# alpha,beta: 7.00 ,8.68
# ratio: 1.00
# alpha,beta: 52.00 ,81.17
# ratio: 1.00
# alpha,beta: 63.00 ,10.60
# ratio: 1.00
# alpha,beta: 18.00 ,7.69
# ratio: 1.00
# alpha,beta: 25.00 ,20.01
# ratio: 1.00
# alpha,beta: 16.00 ,8.95
# ratio: 1.00
# alpha,beta: 19.00 ,17.38
# ratio: 1.00
# alpha,beta: 29.00 ,13.40
# ratio: 1.00
# alpha,beta: 11.00 ,4.44
# ratio: 1.00
# alpha,beta: 23.00 ,35.85
# ratio: 1.00
# alpha,beta: 13.00 ,6.10
# ratio: 1.00
# alpha,beta: 37.00 ,8.19
# ratio: 1.00
# alpha,beta: 19.00 ,9.35
# ratio: 1.00
# alpha,beta: 106.00 ,17.63
# ratio: 1.00
# alpha,beta: 20.00 ,21.36
# ratio: 1.00
# alpha,beta: 22.00 ,9.00
# ratio: 1.00
# alpha,beta: 60.00 ,21.04
# ratio: 1.00
# alpha,beta: 23.00 ,13.47
# ratio: 1.00
# alpha,beta: 6.00 ,5.99
# ratio: 1.00
# alpha,beta: 11.00 ,4.36
# ratio: 1.00
# alpha,beta: 50.00 ,19.06
# ratio: 1.00
# alpha,beta: 55.00 ,15.88
# ratio: 1.00
# alpha,beta: 73.00 ,13.35
# ratio: 1.00
# alpha,beta: 29.00 ,7.46
# ratio: 1.00
# alpha,beta: 7.00 ,8.03
# ratio: 1.00
# alpha,beta: 11.00 ,10.09
# ratio: 1.00
# alpha,beta: 137.00 ,45.96
# ratio: 1.00
# alpha,beta: 5.00 ,0.00
# ratio: 1.00
# alpha,beta: 7.00 ,4.04
# ratio: 1.00
# alpha,beta: 37.00 ,3.53
# ratio: 1.00
# alpha,beta: 9.00 ,19.68
# ratio: 1.00
# alpha,beta: 19.00 ,2.65
# ratio: 1.00
# alpha,beta: 48.00 ,44.33
# ratio: 1.00
# alpha,beta: 45.00 ,18.96
# ratio: 1.00
# alpha,beta: 26.00 ,9.13
# ratio: 1.00
# alpha,beta: 48.00 ,41.17
# ratio: 1.00
# alpha,beta: 11.00 ,5.76
# ratio: 1.00
# alpha,beta: 5.00 ,2.84
# ratio: 1.00
# alpha,beta: 35.00 ,11.48
# ratio: 1.00
# alpha,beta: 7.00 ,2.13
# ratio: 1.00
# alpha,beta: 6.00 ,0.65
# ratio: 1.00
# alpha,beta: 17.00 ,7.18
# ratio: 1.00
# alpha,beta: 10.00 ,7.51
# ratio: 1.00
# alpha,beta: 72.00 ,27.85
# ratio: 1.00
# alpha,beta: 99.00 ,11.77
# ratio: 1.00
# alpha,beta: 16.00 ,9.06
# ratio: 1.00
# alpha,beta: 14.00 ,13.24
# ratio: 1.00
# alpha,beta: 5.00 ,4.18
# ratio: 1.00
# alpha,beta: 16.00 ,4.97
# ratio: 1.00
# alpha,beta: 15.00 ,6.74
# ratio: 1.00
# alpha,beta: 24.00 ,1.74
# ratio: 1.00
# alpha,beta: 13.00 ,2.84
# ratio: 1.00
# alpha,beta: 9.00 ,9.04
# ratio: 1.00
# alpha,beta: 24.00 ,18.26
# ratio: 1.00
# alpha,beta: 7.00 ,11.73
# ratio: 1.00
# alpha,beta: 15.00 ,12.12
# ratio: 1.00
# alpha,beta: 22.00 ,14.45
# ratio: 1.00
# alpha,beta: 39.00 ,13.74
# ratio: 1.00
# alpha,beta: 28.00 ,19.26
# ratio: 1.00
# alpha,beta: 15.00 ,6.41
# ratio: 1.00
# alpha,beta: 13.00 ,10.13
# ratio: 1.00
# alpha,beta: 34.00 ,9.30
# ratio: 1.00
# alpha,beta: 11.00 ,10.09
# ratio: 1.00
# alpha,beta: 16.00 ,19.00
# ratio: 1.00
# alpha,beta: 40.00 ,30.79
# ratio: 1.00
# alpha,beta: 65.00 ,21.33
# ratio: 1.00
# alpha,beta: 14.00 ,5.67
# ratio: 1.00
# alpha,beta: 31.00 ,42.02
# ratio: 1.00
# alpha,beta: 26.00 ,2.44
# ratio: 1.00
# alpha,beta: 7.00 ,4.58
# ratio: 1.00
# alpha,beta: 17.00 ,17.07
# ratio: 1.00
# alpha,beta: 22.00 ,6.32
# ratio: 1.00
# alpha,beta: 23.00 ,15.60
# ratio: 1.00
# alpha,beta: 14.00 ,14.56
# ratio: 1.00
# alpha,beta: 6.00 ,9.00
# ratio: 1.00
# alpha,beta: 1.00 ,5.19
# ratio: 1.00
# alpha,beta: 6.00 ,7.15
# ratio: 1.00
# alpha,beta: 16.00 ,13.12
# ratio: 1.00
# alpha,beta: 10.00 ,3.00
# ratio: 1.00
# alpha,beta: 24.00 ,48.44
# ratio: 1.00
# alpha,beta: 12.00 ,6.07
# ratio: 1.00
# alpha,beta: 28.00 ,9.28
# ratio: 1.00
# alpha,beta: 14.00 ,8.36
# ratio: 1.00
# alpha,beta: 22.00 ,11.28
# ratio: 1.00
# alpha,beta: 6.00 ,2.78
# ratio: 1.00
# alpha,beta: 58.00 ,14.28
# ratio: 1.00
# alpha,beta: 5.00 ,16.05
# ratio: 1.00
# alpha,beta: 107.00 ,22.69
# ratio: 1.00
# alpha,beta: 17.00 ,9.25
# ratio: 1.00
# alpha,beta: 29.00 ,7.23
# ratio: 1.00
# alpha,beta: 24.00 ,6.91
# ratio: 1.00
# alpha,beta: 20.00 ,27.93
# ratio: 1.00
# alpha,beta: 13.00 ,3.75
# ratio: 1.00
# alpha,beta: 11.00 ,3.16
# ratio: 1.00
# alpha,beta: 41.00 ,30.07
# ratio: 1.00
# alpha,beta: 7.00 ,0.94
# ratio: 1.00
# alpha,beta: 38.00 ,25.80
# ratio: 1.00
# alpha,beta: 15.00 ,11.39
# ratio: 1.00
# alpha,beta: 10.00 ,2.07
# ratio: 1.00
# alpha,beta: 18.00 ,6.24
# ratio: 1.00
# alpha,beta: 25.00 ,39.04
# ratio: 1.00
# alpha,beta: 4.00 ,2.48
# ratio: 1.00
# alpha,beta: 27.00 ,14.28
# ratio: 1.00
# alpha,beta: 46.00 ,8.28
# ratio: 1.00
# alpha,beta: 86.00 ,8.63
# ratio: 1.00
# alpha,beta: 26.00 ,32.34
# ratio: 1.00
# alpha,beta: 16.00 ,6.56
# ...
# ratio: 1.00
# alpha,beta: 26.00 ,15.57
# ratio: 1.00
# alpha,beta: 59.00 ,38.31
# ratio: 1.00
# alpha,beta: 15.00 ,9.88
# ratio: 1.00
# alpha,beta: 15.00 ,4.04
# ratio: 1.00
# alpha,beta: 15.00 ,12.00
# ratio: 1.00
# alpha,beta: 7.00 ,4.31
# ratio: 1.00
# alpha,beta: 133.00 ,21.79
# ratio: 1.00
# alpha,beta: 26.00 ,28.07
# ratio: 1.00
# alpha,beta: 1.00 ,1.36
# ratio: 1.00
# alpha,beta: 11.00 ,11.65
# ratio: 1.00
# alpha,beta: 10.00 ,10.18
# ratio: 1.00
# alpha,beta: 30.00 ,17.88
# ratio: 1.00
# alpha,beta: 16.00 ,12.58
# ratio: 1.00
# alpha,beta: 18.00 ,10.46
# ratio: 1.00
# alpha,beta: 7.00 ,1.87
# ratio: 1.00
# alpha,beta: 7.00 ,3.47
# ratio: 1.00
# alpha,beta: 10.00 ,8.32
# ratio: 1.00
# alpha,beta: 23.00 ,12.68
# ratio: 1.00
# alpha,beta: 5.00 ,8.62
# ratio: 1.00
# alpha,beta: 29.00 ,12.70
# ratio: 1.00
# alpha,beta: 12.00 ,8.42
# ratio: 1.00
# alpha,beta: 14.00 ,7.40
# ratio: 1.00
# alpha,beta: 18.00 ,5.63
# ratio: 1.00
# alpha,beta: 30.00 ,43.49
# ratio: 1.00
# alpha,beta: 22.00 ,6.24
# ratio: 1.00
# alpha,beta: 3.00 ,15.86
# ratio: 1.00
# alpha,beta: 6.00 ,4.68
# ratio: 1.00
# alpha,beta: 48.00 ,15.63
# ratio: 1.00
# alpha,beta: 36.00 ,17.91
# ratio: 1.00
# alpha,beta: 48.00 ,19.34
# ratio: 1.00
# alpha,beta: 27.00 ,13.68
# ratio: 1.00
# alpha,beta: 9.00 ,21.85
# ratio: 1.00
# alpha,beta: 9.00 ,0.95
# ratio: 1.00
# alpha,beta: 41.00 ,45.16
# ratio: 1.00
# alpha,beta: 14.00 ,16.59
# ratio: 1.00
# alpha,beta: 18.00 ,11.59
# ratio: 1.00
# alpha,beta: 21.00 ,7.98
# ratio: 1.00
# alpha,beta: 16.00 ,7.60
# ratio: 1.00
# alpha,beta: 11.00 ,4.71
# ratio: 1.00
# alpha,beta: 30.00 ,12.60
# ratio: 1.00
# alpha,beta: 41.00 ,37.59
# ratio: 1.00
# alpha,beta: 44.00 ,8.64
# ratio: 1.00
# alpha,beta: 37.00 ,29.33
# ratio: 1.00
# alpha,beta: 16.00 ,5.17
# ratio: 1.00
# alpha,beta: 34.00 ,8.08
# ratio: 1.00
# alpha,beta: 20.00 ,18.61
# ratio: 1.00
# alpha,beta: 53.00 ,31.24
# ratio: 1.00
# alpha,beta: 77.00 ,19.14
# ratio: 1.00
# alpha,beta: 100.00 ,23.15
# ratio: 1.00
# alpha,beta: 20.00 ,9.50
# ratio: 1.00
# alpha,beta: 10.00 ,4.90
# ratio: 1.00
# alpha,beta: 6.00 ,4.59
# ratio: 1.00
# alpha,beta: 14.00 ,21.29
# ratio: 1.00
# alpha,beta: 57.00 ,21.53
# ratio: 1.00
# alpha,beta: 30.00 ,16.77
# ratio: 1.00
# alpha,beta: 15.00 ,9.17
# ratio: 1.00
# alpha,beta: 12.00 ,7.03
# ratio: 1.00
# alpha,beta: 59.00 ,31.61
# ratio: 1.00
# alpha,beta: 17.00 ,11.55
# ratio: 1.00
# alpha,beta: 33.00 ,23.54
# ratio: 1.00
# alpha,beta: 59.00 ,66.31
# ratio: 1.00
# alpha,beta: 24.00 ,16.98
# ratio: 1.00
# alpha,beta: 21.00 ,16.58
# ratio: 1.00
# alpha,beta: 40.00 ,6.22
# ratio: 1.00
# alpha,beta: 11.00 ,8.91
# ratio: 1.00
# alpha,beta: 28.00 ,11.18
# ratio: 1.00
# alpha,beta: 21.00 ,17.77
# ratio: 1.00
# alpha,beta: 4.00 ,8.46
# ratio: 1.00
# alpha,beta: 23.00 ,17.52
# ratio: 1.00
# alpha,beta: 7.00 ,7.74
# ratio: 1.00
# alpha,beta: 64.00 ,19.33
# ratio: 1.00
# alpha,beta: 13.00 ,6.79
# ratio: 1.00
# alpha,beta: 68.00 ,40.28
# ratio: 1.00
# alpha,beta: 48.00 ,15.54
# ratio: 1.00
# alpha,beta: 20.00 ,10.77
# ratio: 1.00
# alpha,beta: 8.00 ,4.83
# ratio: 1.00
# alpha,beta: 24.00 ,19.41
# ratio: 1.00
# alpha,beta: 35.00 ,19.50
# ratio: 1.00
# alpha,beta: 41.00 ,25.39
# ratio: 1.00
# alpha,beta: 22.00 ,11.35
# ratio: 1.00
# alpha,beta: 43.00 ,15.99
# ratio: 1.00
# alpha,beta: 9.00 ,6.01
# ratio: 1.00
# alpha,beta: 8.00 ,1.41
# ratio: 1.00
# alpha,beta: 78.00 ,12.13
# ratio: 1.00
# alpha,beta: 30.00 ,11.44
# ratio: 1.00
# alpha,beta: 14.00 ,8.54
# ratio: 1.00
# alpha,beta: 13.00 ,7.17
# ratio: 1.00
# alpha,beta: 67.00 ,22.49
# ratio: 1.00
# alpha,beta: 19.00 ,24.75
# ratio: 1.00
# alpha,beta: 31.00 ,26.86
# ratio: 1.00
# alpha,beta: 11.00 ,5.78
# ratio: 1.00
# alpha,beta: 18.00 ,14.18
# ratio: 1.00
# alpha,beta: 29.00 ,15.38
# ratio: 1.00
# alpha,beta: 19.00 ,15.58
# ratio: 1.00
# alpha,beta: 13.00 ,11.40
# ratio: 1.00
# alpha,beta: 62.00 ,19.59
# ratio: 1.00
# alpha,beta: 23.00 ,13.39
# ratio: 1.00
# alpha,beta: 14.00 ,8.04
# ratio: 1.00
# alpha,beta: 12.00 ,6.16
# ratio: 1.00
# alpha,beta: 43.00 ,27.75
# ratio: 1.00
# alpha,beta: 6.00 ,4.16
# ratio: 1.00
# alpha,beta: 23.00 ,28.01
# ratio: 1.00
# alpha,beta: 11.00 ,15.52
# ratio: 1.00
# alpha,beta: 30.00 ,17.87
# ratio: 1.00
# alpha,beta: 17.00 ,15.39
# ratio: 1.00
# alpha,beta: 31.00 ,15.70
# ratio: 1.00
# alpha,beta: 7.00 ,14.04
# ratio: 1.00
# alpha,beta: 19.00 ,35.32
# ratio: 1.00
# alpha,beta: 14.00 ,1.74
# ratio: 1.00
# alpha,beta: 42.00 ,28.46
# ratio: 1.00
# alpha,beta: 67.00 ,42.06
# ratio: 1.00
# alpha,beta: 46.00 ,32.56
# ratio: 1.00
# alpha,beta: 36.00 ,10.75
# ratio: 1.00
# alpha,beta: 38.00 ,31.30
# ratio: 1.00
# alpha,beta: 35.00 ,49.98
# ratio: 1.00
# alpha,beta: 18.00 ,30.63
# ratio: 1.00
# alpha,beta: 26.00 ,23.22
# ratio: 1.00
# alpha,beta: 8.00 ,13.95
# ratio: 1.00
# alpha,beta: 48.00 ,20.59
# ratio: 1.00
# alpha,beta: 29.00 ,7.48
# ratio: 1.00
# alpha,beta: 24.00 ,11.80
# ratio: 1.00
# alpha,beta: 33.00 ,26.83
# ratio: 1.00
# alpha,beta: 63.00 ,17.06
# ratio: 1.00
# alpha,beta: 156.00 ,54.58
# ratio: 1.00
# alpha,beta: 57.00 ,18.74
# ratio: 1.00
# alpha,beta: 12.00 ,3.82
# ratio: 1.00
# alpha,beta: 39.00 ,19.52
# ratio: 1.00
# alpha,beta: 50.00 ,17.88
# ratio: 1.00
# alpha,beta: 13.00 ,17.40
# ratio: 1.00
# alpha,beta: 10.00 ,15.70
# ratio: 1.00
# alpha,beta: 14.00 ,15.88
# ratio: 1.00
# alpha,beta: 12.00 ,6.12
# ratio: 1.00
# alpha,beta: 27.00 ,19.16
# ratio: 1.00
# alpha,beta: 7.00 ,12.97
# ratio: 1.00
# alpha,beta: 10.00 ,12.79
# ratio: 1.00
# alpha,beta: 36.00 ,8.60
# ratio: 1.00
# alpha,beta: 93.00 ,57.54
# ratio: 1.00
# alpha,beta: 53.00 ,14.59
# ratio: 1.00
# alpha,beta: 6.00 ,0.86
# ratio: 1.00
# alpha,beta: 13.00 ,11.51
# ratio: 1.00
# alpha,beta: 11.00 ,7.35
# ratio: 1.00
# alpha,beta: 21.00 ,7.57
# ratio: 1.00
# alpha,beta: 33.00 ,30.46
# ratio: 1.00
# alpha,beta: 25.00 ,8.53
# ratio: 1.00
# alpha,beta: 15.00 ,13.03
# ratio: 1.00
# alpha,beta: 59.00 ,28.40
# ratio: 1.00
# alpha,beta: 9.00 ,15.99
# ratio: 1.00
# alpha,beta: 37.00 ,9.06
# ratio: 1.00
# alpha,beta: 52.00 ,47.05
# ratio: 1.00
# alpha,beta: 78.00 ,56.37
# ratio: 1.00
# alpha,beta: 37.00 ,7.93
# ratio: 1.00
# alpha,beta: 39.00 ,24.84
# ratio: 1.00
# alpha,beta: 20.00 ,7.80
# ratio: 1.00
# alpha,beta: 32.00 ,19.50
# ratio: 1.00
# alpha,beta: 5.00 ,8.03
# ratio: 1.00
# alpha,beta: 17.00 ,10.42
# ratio: 1.00
# alpha,beta: 8.00 ,5.30
# ratio: 1.00
# alpha,beta: 65.00 ,18.73
# ratio: 1.00
# alpha,beta: 7.00 ,6.35
# ratio: 1.00
# alpha,beta: 18.00 ,27.91
# ratio: 1.00
# alpha,beta: 22.00 ,7.73
# ratio: 1.00
# alpha,beta: 72.00 ,39.95
# ratio: 1.00
# alpha,beta: 9.00 ,4.84
# ratio: 1.00
# alpha,beta: 56.00 ,19.01
# ratio: 1.00
# alpha,beta: 7.00 ,6.06
# ratio: 1.00
# alpha,beta: 129.00 ,24.29
# ratio: 1.00
# alpha,beta: 32.00 ,26.49
# ratio: 1.00
# alpha,beta: 17.00 ,11.99
# ratio: 1.00
# alpha,beta: 18.00 ,13.05
# ratio: 1.00
# alpha,beta: 13.00 ,16.92
# ratio: 1.00
# alpha,beta: 33.00 ,31.50
# ratio: 1.00
# alpha,beta: 31.00 ,40.91
# ratio: 1.00
# alpha,beta: 112.00 ,11.91
# ratio: 1.00
# alpha,beta: 26.00 ,12.52
# ratio: 1.00
# alpha,beta: 16.00 ,9.13
# ratio: 1.00
# alpha,beta: 11.00 ,6.20
# ratio: 1.00
# alpha,beta: 11.00 ,3.98
# ratio: 1.00
# alpha,beta: 65.00 ,13.86
# ratio: 1.00
# alpha,beta: 66.00 ,17.64
# ratio: 1.00
# alpha,beta: 13.00 ,7.26
# ratio: 1.00
# alpha,beta: 53.00 ,20.36
# ratio: 1.00
# alpha,beta: 18.00 ,14.09
# ratio: 1.00
# alpha,beta: 8.00 ,6.87
# ratio: 1.00
# alpha,beta: 12.00 ,12.54
# ratio: 1.00
# alpha,beta: 9.00 ,17.68
# ratio: 1.00
# alpha,beta: 6.00 ,8.22
# ratio: 1.00
# alpha,beta: 7.00 ,9.71
# ratio: 1.00
# alpha,beta: 19.00 ,10.17
# ratio: 1.00
# alpha,beta: 12.00 ,15.04
# ratio: 1.00
# alpha,beta: 9.00 ,5.45
# ratio: 1.00
# alpha,beta: 11.00 ,4.00
# ratio: 1.00
# alpha,beta: 23.00 ,45.09
# ratio: 1.00
# alpha,beta: 14.00 ,18.33
# ratio: 1.00
# alpha,beta: 24.00 ,22.60
# ratio: 1.00
# alpha,beta: 85.00 ,24.42
# ratio: 1.00
# alpha,beta: 12.00 ,3.10
# ratio: 1.00
# alpha,beta: 10.00 ,9.71
# ratio: 1.00
# alpha,beta: 9.00 ,5.94
# ratio: 1.00
# alpha,beta: 49.00 ,18.95
# ratio: 1.00
# alpha,beta: 22.00 ,14.45
# ratio: 1.00
# alpha,beta: 24.00 ,28.26
# ratio: 1.00
# alpha,beta: 12.00 ,13.30
# ratio: 1.00
# alpha,beta: 18.00 ,26.77
# ratio: 1.00
# alpha,beta: 14.00 ,5.75
# ratio: 1.00
# alpha,beta: 29.00 ,19.45
# ratio: 1.00
# alpha,beta: 97.00 ,35.57
# ratio: 1.00
# alpha,beta: 29.00 ,25.02
# ratio: 1.00
# alpha,beta: 39.00 ,8.74
# ratio: 1.00
# alpha,beta: 18.00 ,10.76
# ratio: 1.00
# alpha,beta: 47.00 ,22.00
# ratio: 1.00
# alpha,beta: 20.00 ,22.38
# ratio: 1.00
# alpha,beta: 41.00 ,43.03
# ratio: 1.00
# alpha,beta: 22.00 ,7.61
# ratio: 1.00
# alpha,beta: 80.00 ,16.85
# ratio: 1.00
# alpha,beta: 12.00 ,15.22
# ratio: 1.00
# alpha,beta: 14.00 ,9.83
# ratio: 1.00
# alpha,beta: 85.00 ,28.77
# ratio: 1.00
# alpha,beta: 16.00 ,8.50
# ratio: 1.00
# alpha,beta: 70.00 ,16.24
# ratio: 1.00
# alpha,beta: 20.00 ,12.45
# ratio: 1.00
# alpha,beta: 13.00 ,9.74
# ratio: 1.00
# alpha,beta: 16.00 ,4.31
# ratio: 1.00
# alpha,beta: 14.00 ,14.66
# ratio: 1.00
# alpha,beta: 9.00 ,3.47
# ratio: 1.00
# alpha,beta: 8.00 ,13.97
# ratio: 1.00
# alpha,beta: 31.00 ,9.31
# ratio: 1.00
# alpha,beta: 103.00 ,9.85
# ratio: 1.00
# alpha,beta: 36.00 ,15.46
# ratio: 1.00
# alpha,beta: 28.00 ,18.13
# ratio: 1.00
# alpha,beta: 10.00 ,3.20
# ratio: 1.00
# alpha,beta: 57.00 ,8.85
# ratio: 1.00
# alpha,beta: 69.00 ,14.58
# ratio: 1.00
# alpha,beta: 14.00 ,11.69
# ratio: 1.00
# alpha,beta: 23.00 ,13.23
# ratio: 1.00
# alpha,beta: 28.00 ,10.00
# ratio: 1.00
# alpha,beta: 40.00 ,39.62
# ratio: 1.00
# alpha,beta: 5.00 ,3.44
# ratio: 1.00
# alpha,beta: 27.00 ,17.09
# ratio: 1.00
# alpha,beta: 15.00 ,4.17
# ratio: 1.00
# alpha,beta: 22.00 ,18.05
# ratio: 1.00
# alpha,beta: 89.00 ,22.04
# ratio: 1.00
# alpha,beta: 33.00 ,15.00
# ratio: 1.00
# alpha,beta: 86.00 ,73.68
# ratio: 1.00
# alpha,beta: 11.00 ,18.79
# ratio: 1.00
# alpha,beta: 76.00 ,30.79
# ratio: 1.00
# alpha,beta: 41.00 ,30.33
# ratio: 1.00
# alpha,beta: 71.00 ,19.51
# ratio: 1.00
# alpha,beta: 15.00 ,16.84
# ratio: 1.00
# alpha,beta: 64.00 ,13.24
# ratio: 1.00
# alpha,beta: 27.00 ,10.73
# ratio: 1.00
# alpha,beta: 32.00 ,17.92
# ratio: 1.00
# alpha,beta: 27.00 ,11.06
# ratio: 1.00
# alpha,beta: 14.00 ,13.79
# ratio: 1.00
# alpha,beta: 73.00 ,15.84
# ratio: 1.00
# alpha,beta: 21.00 ,13.55
# ratio: 1.00
# alpha,beta: 11.00 ,6.53
# ratio: 1.00
# alpha,beta: 15.00 ,13.12
# ratio: 1.00
# alpha,beta: 66.00 ,39.63
# ratio: 1.00
# alpha,beta: 88.00 ,33.61
# ratio: 1.00
# alpha,beta: 30.00 ,10.07
# ratio: 1.00
# alpha,beta: 10.00 ,2.35
# ratio: 1.00
# alpha,beta: 38.00 ,19.19
# ratio: 1.00
# alpha,beta: 9.00 ,23.90
# ratio: 1.00
# alpha,beta: 18.00 ,9.95
# ratio: 1.00
# alpha,beta: 18.00 ,8.29
# ratio: 1.00
# alpha,beta: 17.00 ,20.56
# ratio: 1.00
# alpha,beta: 36.00 ,40.51
# ratio: 1.00
# alpha,beta: 13.00 ,5.76
# ratio: 1.00
# alpha,beta: 14.00 ,5.62
# ratio: 1.00
# alpha,beta: 38.00 ,10.97
# ratio: 1.00
# alpha,beta: 36.00 ,30.81
# ratio: 1.00
# alpha,beta: 38.00 ,36.80
# ratio: 1.00
# alpha,beta: 17.00 ,6.82
# ratio: 1.00
# alpha,beta: 6.00 ,4.73
# ratio: 1.00
# alpha,beta: 58.00 ,17.80
# ratio: 1.00
# alpha,beta: 21.00 ,11.25
# ratio: 1.00
# alpha,beta: 32.00 ,21.09
# ratio: 1.00
# alpha,beta: 15.00 ,13.02
# ratio: 1.00
# alpha,beta: 19.00 ,14.86
# ratio: 1.00
# alpha,beta: 35.00 ,38.65
# ratio: 1.00
# alpha,beta: 37.00 ,25.95
# ratio: 1.00
# alpha,beta: 50.00 ,19.97
# ratio: 1.00
# alpha,beta: 14.00 ,11.62
# ratio: 1.00
# alpha,beta: 22.00 ,8.23
# ratio: 1.00
# alpha,beta: 67.00 ,49.78
# ratio: 1.00
# alpha,beta: 14.00 ,11.67
# ratio: 1.00
# alpha,beta: 61.00 ,32.26
# ratio: 1.00
# alpha,beta: 21.00 ,19.31
# ratio: 1.00
# alpha,beta: 53.00 ,16.19
# ratio: 1.00
# alpha,beta: 14.00 ,13.66
# ratio: 1.00
# alpha,beta: 21.00 ,4.52
# ratio: 1.00
# alpha,beta: 53.00 ,26.40
# ratio: 1.00
# alpha,beta: 20.00 ,13.54
# ratio: 1.00
# alpha,beta: 21.00 ,9.86
# ratio: 1.00
# alpha,beta: 29.00 ,18.72
# ratio: 1.00
# alpha,beta: 15.00 ,16.39
# ratio: 1.00
# alpha,beta: 17.00 ,17.36
# ratio: 1.00
# alpha,beta: 56.00 ,51.64
# ratio: 1.00
# alpha,beta: 28.00 ,9.14
# ratio: 1.00
# alpha,beta: 11.00 ,4.03
# ratio: 1.00
# alpha,beta: 54.00 ,8.81
# ratio: 1.00
# alpha,beta: 35.00 ,45.57
# ratio: 1.00
# alpha,beta: 62.00 ,18.86
# ratio: 1.00
# alpha,beta: 50.00 ,23.16
# ratio: 1.00
# alpha,beta: 163.00 ,41.64
# ratio: 1.00
# alpha,beta: 65.00 ,14.78
# ratio: 1.00
# alpha,beta: 85.00 ,31.57
# ratio: 1.00
# alpha,beta: 41.00 ,10.91
# ratio: 1.00
# alpha,beta: 7.00 ,1.53
# ratio: 1.00
# alpha,beta: 44.00 ,8.30
# ratio: 1.00
# alpha,beta: 23.00 ,31.51
# ratio: 1.00
# alpha,beta: 32.00 ,25.57
# ratio: 1.00
# alpha,beta: 33.00 ,14.97
# ratio: 1.00
# alpha,beta: 13.00 ,2.75
# ratio: 1.00
# alpha,beta: 45.00 ,25.66
# ratio: 1.00
# alpha,beta: 55.00 ,25.83
# ratio: 1.00
# alpha,beta: 15.00 ,3.85
# ratio: 1.00
# alpha,beta: 16.00 ,19.76
# ratio: 1.00
# alpha,beta: 21.00 ,10.34
# ratio: 1.00
# alpha,beta: 8.00 ,10.48
# ratio: 1.00
# alpha,beta: 31.00 ,25.58
# ratio: 1.00
# alpha,beta: 41.00 ,25.67
# ratio: 1.00
# alpha,beta: 14.00 ,13.97
# ratio: 1.00
# alpha,beta: 8.00 ,2.99
# ratio: 1.00
# alpha,beta: 17.00 ,7.90
# ratio: 1.00
# alpha,beta: 16.00 ,5.35
# ratio: 1.00
# alpha,beta: 10.00 ,7.75
# ratio: 1.00
# alpha,beta: 17.00 ,15.86
# ratio: 1.00
# alpha,beta: 23.00 ,24.13
# ratio: 1.00
# alpha,beta: 47.00 ,11.07
# ratio: 1.00
# alpha,beta: 18.00 ,7.01
# ratio: 1.00
# alpha,beta: 5.00 ,14.32
# ratio: 1.00
# alpha,beta: 18.00 ,17.89
# ratio: 1.00
# alpha,beta: 20.00 ,9.13
# ratio: 1.00
# alpha,beta: 85.00 ,26.26
# ratio: 1.00
# alpha,beta: 67.00 ,12.58
# ratio: 1.00
# alpha,beta: 16.00 ,27.85
# ratio: 1.00
# alpha,beta: 25.00 ,24.43
# ratio: 1.00
# alpha,beta: 52.00 ,43.40
# ratio: 1.00
# alpha,beta: 26.00 ,22.25
# ratio: 1.00
# alpha,beta: 63.00 ,37.10
# ratio: 1.00
# alpha,beta: 33.00 ,23.65
# ratio: 1.00
# alpha,beta: 22.00 ,11.89
# ratio: 1.00
# alpha,beta: 28.00 ,23.89
# ratio: 1.00
# alpha,beta: 61.00 ,21.68
# ratio: 1.00
# alpha,beta: 17.00 ,15.17
# ratio: 1.00
# alpha,beta: 43.00 ,43.00
# ratio: 1.00
# alpha,beta: 33.00 ,24.81
# ratio: 1.00
# alpha,beta: 8.00 ,12.21
# ratio: 1.00
# alpha,beta: 6.00 ,6.73
# ratio: 1.00
# alpha,beta: 12.00 ,9.33
# ratio: 1.00
# alpha,beta: 16.00 ,7.59
# ratio: 1.00
# alpha,beta: 9.00 ,5.42
# ratio: 1.00
# alpha,beta: 16.00 ,13.51
# ratio: 1.00
# alpha,beta: 63.00 ,37.01
# ratio: 1.00
# alpha,beta: 22.00 ,46.78
# ratio: 1.00
# alpha,beta: 35.00 ,11.99
# ratio: 1.00
# alpha,beta: 22.00 ,25.42
# ratio: 1.00
# alpha,beta: 20.00 ,39.24
# ratio: 1.00
# alpha,beta: 9.00 ,6.00
# ratio: 1.00
# alpha,beta: 45.00 ,19.17
# ratio: 1.00
# alpha,beta: 80.00 ,40.78
# ratio: 1.00
# alpha,beta: 42.00 ,10.57
# ratio: 1.00
# alpha,beta: 23.00 ,10.29
# ratio: 1.00
# alpha,beta: 25.00 ,24.26
# ratio: 1.00
# alpha,beta: 67.00 ,12.86
# ratio: 1.00
# alpha,beta: 13.00 ,19.51
# ratio: 1.00
# alpha,beta: 33.00 ,42.03
# ratio: 1.00
# alpha,beta: 12.00 ,15.12
# ratio: 1.00
# alpha,beta: 82.00 ,14.20
# ratio: 1.00
# alpha,beta: 28.00 ,17.66
# ratio: 1.00
# alpha,beta: 48.00 ,13.39
# ratio: 1.00
# alpha,beta: 12.00 ,8.67
# ratio: 1.00
# alpha,beta: 22.00 ,17.45
# ratio: 1.00
# alpha,beta: 32.00 ,23.37
# ratio: 1.00
# alpha,beta: 28.00 ,27.51
# ratio: 1.00
# alpha,beta: 35.00 ,38.10
# ratio: 1.00
# alpha,beta: 10.00 ,11.35
# ratio: 1.00
# alpha,beta: 54.00 ,18.79
# ratio: 1.00
# alpha,beta: 12.00 ,13.70
# ratio: 1.00
# alpha,beta: 22.00 ,20.94
# ratio: 1.00
# alpha,beta: 16.00 ,19.12
# ratio: 1.00
# alpha,beta: 36.00 ,17.86
# ratio: 1.00
# alpha,beta: 32.00 ,15.29
# ratio: 1.00
# alpha,beta: 48.00 ,16.01
# ratio: 1.00
# alpha,beta: 56.00 ,31.83
# ratio: 1.00
# alpha,beta: 20.00 ,9.57
# ratio: 1.00
# alpha,beta: 13.00 ,20.39
# ratio: 1.00
# alpha,beta: 183.00 ,25.73
# ratio: 1.00
# alpha,beta: 12.00 ,10.15
# ratio: 1.00
# alpha,beta: 67.00 ,29.16
# ratio: 1.00
# alpha,beta: 15.00 ,22.40
# ratio: 1.00
# alpha,beta: 11.00 ,6.03
# ratio: 1.00
# alpha,beta: 53.00 ,23.35
# ratio: 1.00
# alpha,beta: 11.00 ,4.10
# ratio: 1.00
# alpha,beta: 26.00 ,19.37
# ratio: 1.00
# alpha,beta: 32.00 ,10.14
# ratio: 1.00
# alpha,beta: 35.00 ,25.98
# ratio: 1.00
# alpha,beta: 7.00 ,12.36
# ratio: 1.00
# alpha,beta: 22.00 ,13.96
# ratio: 1.00
# alpha,beta: 16.00 ,4.09
# ratio: 1.00
# alpha,beta: 83.00 ,19.32
# ratio: 1.00
# alpha,beta: 16.00 ,10.48
# ratio: 1.00
# alpha,beta: 9.00 ,10.81
# ratio: 1.00
# alpha,beta: 41.00 ,20.05
# ratio: 1.00
# alpha,beta: 14.00 ,9.16
# ratio: 1.00
# alpha,beta: 11.00 ,11.58
# ratio: 1.00
# alpha,beta: 7.00 ,3.59
# ratio: 1.00
# alpha,beta: 43.00 ,62.49
# ratio: 1.00
# alpha,beta: 30.00 ,36.52
# ratio: 1.00
# alpha,beta: 106.00 ,20.04
# ratio: 1.00
# alpha,beta: 8.00 ,12.13
# ratio: 1.00
# alpha,beta: 10.00 ,7.39
# ratio: 1.00
# alpha,beta: 43.00 ,51.95
# ratio: 1.00
# alpha,beta: 21.00 ,18.60
# ratio: 1.00
# alpha,beta: 26.00 ,21.38
# ratio: 1.00
# alpha,beta: 33.00 ,37.21
# ratio: 1.00
# alpha,beta: 14.00 ,16.54
# ratio: 1.00
# alpha,beta: 14.00 ,9.65
# ratio: 1.00
# alpha,beta: 39.00 ,13.25
# ratio: 1.00
# alpha,beta: 27.00 ,22.80
# ratio: 1.00
# alpha,beta: 36.00 ,17.29
# ratio: 1.00
# alpha,beta: 12.00 ,19.04
# ratio: 1.00
# alpha,beta: 13.00 ,6.37
# ratio: 1.00
# alpha,beta: 102.00 ,33.07
# ratio: 1.00
# alpha,beta: 25.00 ,11.09
# ratio: 1.00
# alpha,beta: 42.00 ,20.98
# ratio: 1.00
# alpha,beta: 13.00 ,4.26
# ratio: 1.00
# alpha,beta: 22.00 ,14.23
# ratio: 1.00
# alpha,beta: 7.00 ,19.00
# ratio: 1.00
# alpha,beta: 12.00 ,23.79
# ratio: 1.00
# alpha,beta: 13.00 ,6.56
# ratio: 1.00
# alpha,beta: 21.00 ,12.59
# ratio: 1.00
# alpha,beta: 99.00 ,26.08
# ratio: 1.00
# alpha,beta: 58.00 ,38.81
# ratio: 1.00
# alpha,beta: 73.00 ,28.96
# ratio: 1.00

# %% [markdown]
# ### Comparing The Prior Choices:
#
# Here we compare the difference between the two choices of priors, flat and beta.

# %%
pflat = np.array([res[i]['prior']['flat'] for i in range(ncls)])
pbeta = np.array([res[i]['prior']['beta'] for i in range(ncls)])

plt.scatter(alpha,(pbeta-pflat),c=pflat,cmap='jet')
plt.xscale('log')
plt.ylabel('prior prob: beta - flat',fontsize=16)
plt.xlabel(r'$\alpha = \hat{N}_{c}$',fontsize=16)
plt.colorbar().set_label(r'$P_{flat}=N_c/(N_c+N_f)$',fontsize=16)

# %% [markdown]
# The prior prob. difference is below 2.5% for $\alpha>10$, for lower values the difference can be up to 15%, which is signficant.

# %%
pflat = np.array([res[i]['prior']['flat'] for i in range(ncls)])
pbeta = np.array([res[i]['prior']['beta'] for i in range(ncls)])

plt.scatter(Nt,(pbeta-pflat),c=pflat,cmap='jet')
plt.xscale('log')
plt.ylabel('prior prob: beta - flat',fontsize=16)
plt.xlabel(r'True richness: $N_{200}$',fontsize=16)
plt.colorbar().set_label(r'$P_{flat}=N_c/(N_c+N_f)$',fontsize=16)

# %% [markdown]
# The prior choice has its impact on recovering the true richness. The main difference is on the low signal-to-noise ratio cases, i.e. higher number of fields galaxies than cluster galaxies ($P_{flat}<0.5$).

# %% [markdown]
# ## Comparing the richness
#
# Here we compare the richness for the different estimators, old method, flat and beta priors.

# %%
## assign the new probabilities
gal = set_new_columns(gal,columns,val=-99.)
cat = set_new_columns(cat,['Ngals_%s'%c for c in columns],val=-99.)
cat = set_new_columns(cat,[c for c in ['flat','beta']],val=-99.)

for i in range(ncls):
    for col in columns:
        gal[col][keys[i]]  = res[i]['Pmem'][col][:]
        cat['Ngals_%s'%col][i]= res[i]['Ngals'][col]
    
    for col in ['flat','beta']:
        cat[col][i]= res[i]['prior'][col]

# %%
def compute_ptaken(g0,label='Pmem'):
	"""
	it computes p_taken
	"""
	print('compute ptaken')
	# g0.sort('Pmem')
	pmem = g0[label]
	ptaken = np.ones_like(pmem,dtype=float)

	## find common galaxies
	gid = np.array(g0['GID'])#.astype(np.int)
	commonGroups = commonValues(gid)

	for indices in commonGroups:
		pm_group = np.array(pmem[indices])
		pt_group = np.array(ptaken[indices])

		idx_sort = np.argsort(-1*pm_group) ## -1* to reverse order

		pm_group_s = pm_group[idx_sort]
		pt_group_s = pt_group[idx_sort]

		new_pm = 0
		toto = 1
		pm = []
		for i in range(indices.size):
			toto *= (1-new_pm)
			new_pm = toto*pm_group_s[i]
			pt_group_s[i] = toto
			pm.append(new_pm)

		pmem[indices[idx_sort]] = np.array(pm)
		ptaken[indices[idx_sort]] = pt_group_s

	g0[label] = pmem
	#g0['Ptaken'] = ptaken

	return g0

def commonValues(values):
	idx_sort = np.argsort(values)
	sorted_values = values[idx_sort]
	vals, idx_start, count = np.unique(sorted_values, return_counts=True,
                                return_index=True)

	# sets of indices
	res = np.split(idx_sort, idx_start[1:])
	#filter them with respect to their size, keeping only items occurring more than once

	vals = vals[count > 1]
	commonValuesIndicies = [ri for ri in res if ri.size>1]
	
	return commonValuesIndicies

# %%
for col in ['flat','beta','old']:
    gal = compute_ptaken(gal,col)
# Out:
# compute ptaken
# compute ptaken
# compute ptaken

# %%
for i in range(ncls):
    for col in ['flat','beta','old']:
        cat['Ngals_%s'] = np.nansum(gal[col][keys[i]])

# %% [markdown]
# ### $N_{200}$ depends on the prior choice?

# %%
def plot_residual(cat,labela,labelb):
    na, nb = cat['Ngals_%s'%labela],cat['Ngals_%s'%labelb]
    w, = np.where((na>0)&(nb>0))
    pflat  = cat['flat'][w]
    
    x = cat['Ngals_true'][w]
    frac_difference = (na[w]-nb[w])#/nb
    
    plt.scatter(x,frac_difference,c=pflat,cmap='jet')
    plt.axhline(0.,color='k',ls='--')
    plt.xlim(.5,300.)
    plt.xscale('log')
    plt.ylabel(r'$N_{200,%s} - N_{200,%s}$'%(labela,labelb),fontsize=16)
    plt.xlabel(r'True richness: $N_{200}$',fontsize=16)
    plt.colorbar().set_label(r'$P_{flat}=N_c/(N_c+N_f)$',fontsize=16)

# %%
plot_residual(cat,'beta','flat')

# %% [markdown]
# The net effect on $N_{200}$ is not significant.

# %%
plot_residual(cat,'flat','old')

# %% [markdown]
# Check if the code old prob. definition is consitenty with the new definition.

# %%
plt.scatter(cat['Ngals_true'],cat['Ngals'],alpha=0.3)
plt.plot([0.5,300.],[0.5,300.],'k--')
plt.xlim(0.5,300.)
plt.ylim(0.5,300.)
plt.xscale('log')
plt.yscale('log')

# %%
plt.scatter(cat['Ngals_true'],cat['Ngals_beta'],alpha=0.3)
plt.plot([0.5,300.],[0.5,300.],'k--')
plt.xlim(0.5,300.)
plt.ylim(0.5,300.)
plt.xscale('log')
plt.yscale('log')

# %%
plt.scatter(cat['Ngals_true'],cat['Ngals_old'],alpha=0.3)
plt.plot([0.5,300.],[0.5,300.],'k--')
plt.xlim(0.5,300.)
plt.ylim(0.5,300.)
plt.xscale('log')
plt.yscale('log')

# %%
plot_scatter_distribution(cat,'Ngals')
# Out:
# mean: 0.779
# rms : 0.124
# out. frac. : 0.028
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
plot_scatter_distribution(cat,'Ngals_beta')
# Out:
# mean: 0.810
# rms : 0.074
# out. frac. : 0.023
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
plot_scatter_distribution(cat,'Ngals_flat')
# Out:
# mean: 0.790
# rms : 0.080
# out. frac. : 0.017
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
plot_scatter_distribution(cat,'Ngals_old')
# Out:
# mean: 0.791
# rms : 0.080
# out. frac. : 0.021
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
plt.scatter(Nt,(cat['Ngals_beta']+Nf)/Ncf,alpha=0.3)
# plt.plot([0.5,300.],[0.5,300.],'k--')
# plt.xlim(0.5,300.)
# plt.ylim(0.5,300.)
plt.xscale('log')
# plt.yscale('log')

# %%
def get_variable(cat,label):
    nt0= np.array(cat['Ngals_true']).copy()
    ng0= np.array(cat[label]).copy()
    
    w, = np.where(ng0>0.)
    return nt0[w],ng0[w]

def remove_outliers(x,n=1.5):
    q25,q75 = np.nanpercentile(x,[25,75])
    iqr     = q75-q25
    lo, up  = q25-n*iqr, q75+n*iqr
    mask    = (x<up)&(x>lo)
    return mask

def get_scatter(x,xt):
    residual     = x/xt
    log_residual = np.log10(residual)
    
    check    = np.logical_not(np.isnan(log_residual) | np.isinf(log_residual))
    mask     = remove_outliers(log_residual,n=1.5)&(check)
    
    bias            = 10**np.nanmean(log_residual[mask])
    log_scatter     = np.nanstd(log_residual[mask])
    scatter         = 10**(log_scatter)-1
    
    out_fraction    = 1-1.*np.count_nonzero(mask)/len(x)
    out = {'residual':residual,'log_residual':log_residual,'bias': bias, 
           'scatter':scatter, 'log_scatter':log_scatter, 'outlier_fraction': out_fraction,'mask':mask}
    return out

def plot_scatter_distribution(cat,col,label="data",xmin=0.25,xmax=2.25,logx=False):
    ngalst, ngals = get_variable(cat,col)
    
    w = np.where(ngalst>1)[0]
    res  = get_scatter(ngals[w],ngalst[w])
    print(r'mean: %.3f'%(res['bias']))
    print(r'rms : %.3f'%(res['scatter']))
    print(r'out. frac. : %.3f'%(res['outlier_fraction']))
    
    if logx:
        xbins    = np.linspace(np.log10(xmin),np.log10(xmax),30)
        residual = res['log_residual']
        xm       = np.log10(res['bias'])
        xlo,xup  = xm-2*res['log_scatter'],xm+2*res['log_scatter']
        
    else:
        xbins = np.linspace(xmin,xmax,30)
        residual = res['residual']
        xm       = res['bias']
        xlo,xup  = 10**(np.log10(xm)-2*res['log_scatter']),10**(np.log10(xm)+2*res['log_scatter'])
    print(xbins)
    check     = np.logical_not(np.isnan(residual))&np.logical_not(np.isinf(residual))
    _ = plt.hist(residual[check],bins=xbins,label='out. perc = %.2f %%'%(100*res['outlier_fraction']))
    _ = plt.hist(residual[res['mask']],bins=xbins,label=r'precision = %.2f %%'%(100*res['scatter']))
    plt.axvline(xm,color='k',ls='--')
    plt.axvline(xlo,color='r',ls='--')
    plt.axvline(xup,color='r',ls='--')
    plt.title(label)
    # plt.yscale('log')
    plt.xlabel('ratio')
    plt.legend()

# %%
def plot_fraction_pmem(galaxies,lcol='Pmem',color='r',label='_noLabel_',save=False):
    pmem = galaxies[lcol]
    mask = galaxies['True']==True

    pmem_edges = np.arange(0.0,1.1,0.1)
    idx, x_bin = makeBin(pmem, pmem_edges)
    fraction_bin = [len(galaxies[ix][mask[ix]])/(len(galaxies[ix])+1e-9) for ix in idx ]

    # fig = plt.figure(figsize=(6,6))
    plt.scatter(x_bin,fraction_bin,color=color,s=50,label=label)
    plt.plot(np.linspace(0,1.,100),np.linspace(0,1.,100),linestyle='--',color='k')

def makeBin(variable, xedges):
    xbins = (xedges[1:]+xedges[:-1])/2
    indices = [ np.where((variable >= xedges[i]) & (variable <= xedges[i + 1]))[0] for i in range(len(xedges)-1)]
    return indices, xbins

# %%
class BayesianProbability:
    ''' Assign Membership Probabilities For Copacabana Galaxies

    input: alpha, beta, gal
    output: collection('prior','marginal','pdfs','pdfs_field','Pmem','Pr','Pz','Pc')

    alpha: Estimated number of galaxies inside the cluster area
    beta: Estimated number of field galaxies inside the cluster area
    gal: table of galaxies, columns: redshift,pdf,pdfr,pdfz,pdfc and also the field pdfs

    r2: r200, if None use the value from gal
    '''
    def __init__(self, a, b, r2=None):
        self.alpha = np.where(a<=0.,.1,a)
        self.beta  = b
        self.betaDist = scipy.stats.beta(self.alpha, self.beta)
        self.ntotal= a+b
        self.ratio = 1.
        
        self.r2    = r2
        

        self.prob  = defaultdict(dict)
        # ['prior','marginal','pdfs','pdfs_field','Pmem','Pr','Pz','Pc']

        ## init the prior
        self.compute_flat_prior()

    def updatate_ratio(self):
        self.ratio = 1.#*self.ntotal/self.size
        print('ratio: %.2f'%self.ratio)
        
    def load_pdfs(self,gal):
        self.nsize = np.count_nonzero(gal['zmask'])
        self.updatate_ratio()
        
        if self.r2 is None: self.r2 = float(gal['R200'][0])
        #zcls = np.array(gal['redshift'][:]).copy()
        
        self.pdfz = np.array(gal['pdfz'][:]).copy()
        self.pdfr = np.array(gal['pdfr'][:]).copy()
        #self.pdfc = get_color_pdf(zcls,gal['pdfc'][:]).copy()
        
        self.pdfzf= np.array(gal['pdfz_bkg'][:]).copy()
        self.pdfrf= np.array(gal['pdfr_bkg'][:]).copy()
        #self.pdfcf= get_color_pdf(zcls,gal['pdfc_bkg'][:]).copy()        
        
        models       = [self.pdfr,self.pdfz]
        models_field = [self.pdfrf,self.pdfzf]

        self.pdf     = get_full_pdf(models)
        self.pdff    = get_full_pdf(models_field)

#         self.pdf = np.array(gal['pdf'][:]).copy()
#         self.pdff= np.array(gal['pdf_bkg'][:]).copy()
        
    def compute_flat_prior(self):
        pm0 = self.betaDist.mean()
        
        priors = {'flat':pm0,'beta':None}
        self.prob['prior'] = priors

    def compute_marginal(self,name,prior_type):
        pm0 = self.prob['prior'][prior_type]
        pf,pff = self.pick_pdf(name)
        res    = pf*pm0 + pff*(1-pm0)
        self.prob['marginal'][name] = res.copy()
    
    def compute_prob(self,label,name,prior_type,eps=1e-12):
        pm0 = self.prob['prior'][prior_type]
        pdf,pdff = self.pick_pdf(name)
        mar = pdf*pm0 + pdff*(1-pm0)
        res = pdf*pm0/(mar*self.ratio)
        pmem= filter_prob(res.copy())
        self.prob[label][prior_type] = pmem.copy()
    
    def compute_likelihood(self,nbins=40):
        self.pvec = np.linspace(0.,1.,1000)
        pm0   = self.prob['prior']['flat']
        radii = np.linspace(0,self.r2,100)
        pdf   = radial_pdf(radii,self.r2)
        mar   = pdf*pm0+(1-pm0)*(np.pi*self.r2**2)
        p0 = pdf*pm0/(mar+1e-9)
        self.likelihood = get_likelihood(self.pvec,p0,pdf,nbins=nbins)
    
    def compute_beta_prior(self):
        ## assumes a likelihood that only depends on R
        self.compute_likelihood()

        prior = join_pdfs(self.pvec,self.likelihood,self.betaDist.pdf(self.pvec))
        pm0   = mean_pdf(self.pvec,prior)

        self.prob['prior']['beta'] = pm0
        self.prior = prior

    def pick_pdf(self,name):
        if name=='pdfr':
            return [self.pdfr,self.pdfrf]
        
        elif name=='pdfc':
            return [self.pdfc,self.pdfcf]

        elif name=='pdfz':
            return [self.pdfz,self.pdfzf]
        
        elif name=='pdf':
            return [self.pdf,self.pdff]
        else:
            print('error')

    def assign_prob(self,name,label,prior_type):
        self.compute_marginal(name,prior_type)
        self.compute_prob(label,name,prior_type)
    
    def assign_prob_old(self,name,label):
        pdf, pdff = self.pick_pdf(name)
        if name!='Pmem':
            res = doProb(pdf, pdff, self.alpha, self.beta, normed=False)
        else:
            res = doProb(pdf, pdff, self.alpha, self.beta, normed=False)

        self.prob[label]['old'] = res.copy()
    
    def assign_probabilities(self,gal):
        self.names = ['pdf','pdfr','pdfz']
        self.labels= ['Pmem','Pr','Pz']

        ## loading pdfs
        self.load_pdfs(gal)

        ## memb. prob. flat prior
        for label,name in zip(self.labels,self.names):
            self.assign_prob(name,label,'flat')

        ## estimating beta prior
        self.compute_beta_prior()
        
        ## memb. prob. beta prior
        for label,name in zip(self.labels,self.names):
            self.assign_prob(name,label,'beta')

        ## for check purposes
        ## old probabilities definition
        for label,name in zip(self.labels,self.names):
            self.assign_prob_old(name,label)
    
    def compute_ngals(self):
        for col in ['flat','beta','old']:
            self.prob['Ngals'][col] = np.nansum(self.prob['Pmem'][col][:]).copy()

    def plot_prior_distribution(self):
        plt.plot(self.pvec,self.betaDist.pdf(self.pvec),'b',label='Beta')
        plt.plot(self.pvec,self.likelihood,'k',label='P(model|member)')
        plt.plot(self.pvec,self.prior,'r',label='Beta*P(model|member)')
        plt.axvline(self.prob['prior']['flat'],color='b',ls='--')
        plt.axvline(self.prob['prior']['beta'],color='r',ls='--')
        plt.legend()
        plt.xlabel("Prior")
        plt.ylabel('Density')
        pass

def getPDFs(gal,galIndices,vec_list,pdf_list,nbkg,sigma,mag_pdf=False):
    rvec, zvec, cvec, mvec = vec_list
    pdfr, pdfz, pdfc, pdfm = pdf_list

    gal = set_new_columns(gal,['pdf','pdfr','pdfz','pdfm','norm'],val=0.)
    gal = set_new_columns(gal,['pdf_bkg','pdfr_bkg','pdfz_bkg','pdfm_bkg'],val=0.)

    gal['pdfc'] = np.zeros_like(gal['color'])
    gal['pdfc_bkg'] = gal['pdfc']
    
    for i, idx in enumerate(galIndices):
        nb      = nbkg[i]
        zwindow = sigma[i]

        ggal = gal[idx] ## group gal

        ## getting pdfs for a given cluster i
        pdfri, pdfr_cfi  = pdfr[0][i], pdfr[1][i]
        pdfzi, pdfzi_bkg = pdfz[0][i], pdfz[2][i]
        pdfci, pdfci_bkg = pdfc[0][i], pdfc[2][i]
        pdfmi, pdfmi_bkg = pdfm[0][i], pdfm[2][i]

        ## setting galaxies variable columns
        r2    = ggal['R200'] 
        radii = ggal['R']
        zgal  = ggal['z']
        zcls  = ggal['redshift']
        zoff  = ggal['zoffset']*(1+zcls)
        zsig  = ggal['zerr']
        color5= ggal['color']
        mag   = ggal['dmag']
        zmask = ggal['zmask']
        areag = np.pi*r2**2

        radi2 = 0.25*(np.trunc(radii/0.25)+1) ## bins with 0.125 x R200 width
        # areag = np.pi*radi2**2#((radi2+0.25)**2-radi2**2)

        out1 = get_radial_pdf(radii,rvec,pdfri)
        gal['pdfr'][idx]     = out1[0]
        gal['pdfr_bkg'][idx] = out1[1]
        
        out2 = get_photoz_pdf(zgal, zoff, zsig, zvec, pdfzi, pdfzi_bkg, zmask, sigma=zwindow)
        gal['pdfz'][idx]     = out2[0]
        gal['pdfz_bkg'][idx] = out2[1]
        
        for j in range(5):
            gal['pdfc'][idx,j] = get_frequency(interpData(cvec,pdfci[:,j],color5[:,j]))
            gal['pdfc_bkg'][idx,j] = get_frequency(interpData(cvec,pdfci_bkg[:,j],color5[:,j]))

        gal['pdfm'][idx]     = get_frequency(interpData(mvec,pdfmi,mag))
        gal['pdfm_bkg'][idx] = get_frequency(interpData(mvec,pdfmi_bkg,mag))

        ## choose the color filters: g-r for zcls<0.35 and r-i otherwise
        pdfcii     = get_color_pdf(zcls,gal['pdfc'][idx,:])
        pdfcii_bkg = get_color_pdf(zcls,gal['pdfc'][idx,:])

        models       = [gal['pdfr'][idx],gal['pdfz'][idx],pdfcii]
        models_field = [gal['pdfr_bkg'][idx],gal['pdfz_bkg'][idx],pdfcii_bkg]
        
        if mag_pdf:
            models.append(gal['pdfm'][idx])
            models_field.append(gal['pdfm_bkg'][idx])

        gal['pdf'][idx]     = get_full_pdf(models)
        gal['pdf_bkg'][idx] = get_full_pdf(models_field)
                
        ng_profile       = interpData(rvec,pdfr_cfi,radi2)
        gal['norm'][idx] = (ng_profile - nb*areag)#/nb
    return gal

def gaussian(x,mu,sigma):
    return np.exp(-(x-mu)**2/(2*sigma**2))/(sigma*np.sqrt(2*np.pi))

def get_frequency(pdf,eps=1e-12):
    pdfn = np.where(pdf<0.,0.,pdf)
    norm = np.sum(pdfn)
    if norm>0.: pdfn = 1.*pdfn/norm
    return pdfn

def get_radial_pdf(radii,rvec,pdfr):
    pdfr_gal = interpData(rvec,pdfr,radii)
    pdfr_bkg = np.ones_like(radii)
    
    pdfr_gal = np.where(pdfr_gal<0.,0.,pdfr_gal)
    return get_frequency(pdfr_gal), get_frequency(pdfr_bkg)

def get_photoz_pdf(zgal,zoff,zsig,zvec,pdfz,pdfz_field,cut,sigma=0.03):
    ## for a convoluted gaussian: sigma_new^2 = sigma_gal^2+sigma_cls^2
    sigma_eff= sigma#np.sqrt(zsig**2+sigma**2)
    pdfz_gal = gaussian(zoff,0.,sigma_eff)#interpData(rvec,pdfz,zgal)

    ## background distribution
    pdfz_bkg   = interpData(zvec,pdfz_field,zgal)
    pdfz_bkg   = np.where(pdfz_bkg<0.,0.,pdfz_bkg)

    ## only galaxies inside 3*sigma
    #cut = np.abs(zoff)<=2*sigma
    pdfz_gal[np.logical_not(cut)] = 0.
    pdfz_bkg[np.logical_not(cut)] = 0.

    return get_frequency(pdfz_gal), get_frequency(pdfz_bkg)

# pn = np.sum(pdfri),np.sum(pdfzi),np.sum(pdfci)
# pn_bkg = np.sum(pdfr_bkg_i),np.sum(pdfz_bkg_i),np.sum(pdfc_bkg_i)

# Lgals     =  pdfri*pdfzi*pdfci*(np.sum(pn))/np.sum(pdfri*pdfzi*pdfci + eps)#np.product(pn)#
# Lgals_bkg = pdfr_bkg_i*pdfz_bkg_i*pdfc_bkg_i*(np.sum(pn_bkg))/np.sum(pdfr_bkg_i*pdfz_bkg_i*pdfc_bkg_i +eps)#(np.product(pn_bkg))##(np.product(pn_bkg))

def get_full_pdf(params):
    norms= [np.sum(params[0])]
    res  = params[0]*norms[0]
    
    for j in params[1:]:
        res*=j*np.sum(j)
        norms.append(np.sum(j))

    res = get_frequency(res)*np.sum(norms)
    
    return get_frequency(res)

def interpData(x,y,x_new):
    out = interp1d(x, y, kind='linear', fill_value='extrapolate')
    return out(x_new)

def join_pdfs(x,pdf1,pdf2,eps=1e-9):
    prod = pdf1*pdf2
    norm = scipy.integrate.simps(prod,x=x)
    return prod/(norm+eps)

def mean_pdf(x,pdf):
    xmean = scipy.integrate.simps(x*pdf,x=x)
    return xmean

def get_likelihood(xnew,x,pdf,eps=1e-9,nbins=20):
    _,xb,pdfb = bin_data(x,pdf,nbins=nbins)
    like = interpData(xb,pdfb,xnew)
    like = np.where(np.isnan(like),0,like)
    norm = scipy.integrate.simps(like,x=xnew)
    return like/(norm+eps)

def bin_data(x,y,nbins=20):
    xbins = np.linspace(0,1.,nbins+1)#np.percentile(x,np.linspace(0,100,nbins+1))
    xmean = np.zeros_like(xbins[1:])
    ymean = np.zeros_like(xbins[1:])
    
    i=0
    for xl,xh in zip(xbins[:-1],xbins[1:]):
        w, = np.where((x>xl)&(x<=xh))
        if w.size>0:
            xmean[i] = np.nanmean(x[w])
            ymean[i] = np.nanmean(y[w])
        i+=1
    return xbins,xmean,ymean

def filter_prob(x):
    x[np.isnan(x)]=0.
    x = np.where(x<0,0.,x)
    x = np.where(x>1,1.,x)
    return x

def filter_pdf(pdf):
    pdf = np.where(pdf>1e6,1e6,pdf)
    return pdf

def filter_3pdf(x,y,z,norm=True):
    norm = (np.sum(x)+np.sum(y)+np.sum(z))
    norm/= (np.sum(x)*np.sum(y)*np.sum(z))
    
    pdf = x*y*z
    if norm:
        pdf*= norm
        
    pdf = filter_pdf(pdf)
    return pdf

## to do: smooth the color pdfs 
## https://stackoverflow.com/questions/20618804/how-to-smooth-a-curve-in-the-right-way
def get_color_pdf(zcls,pdfc):
    out = np.array(np.where(zcls<0.35,pdfc[:,0],pdfc[:,2]))
    out = np.where(out<0.,0.,out)
    return get_frequency(out)
    
#     return np.ones_like(pdfc[:,0])

def profileNFW(R,R200,c=3):
    #Radial NFW profile implementation. Takes array of radii, value of R200,
    #and NFW concentration parameter (set to 3 by default)
    if R200>0:
        Rs=float(R200)/c
        r=R/Rs
        r=np.where(np.logical_or(r<=1e-5,r==1.),r+0.001,r)
        pre=1./((r**2)-1)
        arctan_coeff=2./(np.sqrt(np.abs(r**2-1)))
        arctan_arg=np.sqrt(np.abs((r-1)/(r+1)))
        sigma=np.where(r>1,pre*(1-arctan_coeff*np.arctan(arctan_arg)),pre*(1-arctan_coeff*np.arctanh(arctan_arg)))
        
        return sigma*2*Rs
    
    else:
        bogusval=-99.*np.ones_like(R)
        return bogusval

def radial_pdf(radii,R200,c=3.5,rc=0.2):
    radii   = np.where(radii<rc/2.,rc/2.,radii)
    density = profileNFW(radii,R200,c=c) ## without norm
    density = np.where(radii<rc,np.mean(density[radii<rc]), density)
    return density

### To Remove
def doProb(Pgals,Pbkg,Ngals,Nbkg, normed=True, eps=1e-12):
    ratio = (Ngals+Nbkg)/( np.sum(Ngals*Pgals) + np.sum(Nbkg*Pbkg) )
    Pgals *= ratio
    Pbkg  *= ratio
    
    if normed:
        Pgals /= (Pgals.sum()+eps)
        Pbkg  /= (Pbkg.sum()+eps)
    
    prob = (Ngals*Pgals)/(Ngals*Pgals+Nbkg*Pbkg+eps)
    # prob[np.isnan(prob)] = 0.

    prob = np.where(prob>1,1.,prob)
    prob = np.where(prob<0.,0.,prob)
    return prob

def chunks(ids1, ids2):
    """Yield successive n-sized chunks from data"""
    for id in ids2:
        w, = np.where( ids1==id )
        yield w

def set_new_columns(table,columns,val=0.):
    for col in columns:
        table[col] = val
    return table

### Assign Probs
def main(cat,gal,norm=0.618):
    ncls    = len(cat)

    r200 = np.array(cat['R200']).copy()
    area = np.array(np.pi*r200**2).copy()

    Nc = cat['Norm']*norm
    Nf = cat['Nbkg']*area

    alpha = np.array(Nc).copy()
    beta  = np.array(Nf).copy()

    cids = np.array(cat['CID'])
    gids = np.array(gal['CID'])
    keys = list(chunks(gids,cids))

    ## compute the new probabilities
    res = []
    for i in range(ncls):
        print('alpha,beta: %.2f ,%.2f'%(alpha[i],beta[i]))
        b = BayesianProbability(alpha[i],beta[i],r2=r200[i])
        b.assign_probabilities(gal[keys[i]])

        res.append(b.prob)
        del b
    
    ## assign into the table
    ## assign the new probabilities
    gal = set_new_columns(gal,['Pmem','Pr','Pz','Pc'],val=0.)

    for i in range(ncls):
        for col in ['Pmem','Pr','Pz','Pc']:
            gal[col][keys[i]]  = res[i][col]['beta'][:]
            gal[col+'_flat'][keys[i]]  = res[i][col]['flat'][:]
            gal[col+'_old'][keys[i]]  = res[i][col]['old'][:]
    
    return gal

# %%
plot_fraction_pmem(gal,'beta')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-6121d6fdab75> in <module>()
# ----> 1 plot_fraction_pmem(gal,'beta')
#
# <ipython-input-20-2dd824b67ba0> in plot_fraction_pmem(galaxies, lcol, color, label, save)
#       1 def plot_fraction_pmem(galaxies,lcol='Pmem',color='r',label='_noLabel_',save=False):
# ----> 2     pmem = galaxies[lcol]
#       3     mask = galaxies['True']==True
#       4
#       5     pmem_edges = np.arange(0.0,1.1,0.1)
#
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/astropy/table/table.pyc in __getitem__(self, item)
#    1220     def __getitem__(self, item):
#    1221         if isinstance(item, six.string_types):
# -> 1222             return self.columns[item]
#    1223         elif isinstance(item, (int, np.integer)):
#    1224             return self.Row(self, item)
#
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/astropy/table/table.pyc in __getitem__(self, item)
#     107         """
#     108         if isinstance(item, six.string_types):
# --> 109             return OrderedDict.__getitem__(self, item)
#     110         elif isinstance(item, (int, np.integer)):
#     111             return self.values()[item]
#
# KeyError: 'beta'

# %%
plot_fraction_pmem(gal,'flat')

# %%
plot_fraction_pmem(gal,'old')

# %%
# plt.plot(pvec,b.pr0.pdf(pvec))
# plt.plot(pvec,b.prior)

# plt.axvline(b.pr0.mean())
# plt.axvline(b.pm0,color='r')

# %%
ncls   = len(cat)
columns = ['flat','beta','old']

## compute the new probabilities
res = []
for i in range(ncls):
    print('alpha,beta: %.2f ,%.2f'%(alpha[i],beta[i]))
    b = bayes_prob(alpha[i],beta[i])
    b.load_likelihood(gal[keys[i]])
    b.get_probabilities()
    b.compute_ngals()
    res.append(b.probabilities)
    del b
    
## assign the new probabilities
gal = set_new_columns(gal,columns,val=-99.)
cat = set_new_columns(cat,['Ngals_%s'%c for c in columns],val=-99.)

for i in range(ncls):
    for col in columns:
        gal[col][keys[i]]  = res[i][col][:]
        cat['Ngals_%s'%col][i]= res[i]['Ngals_%s'%col]

# %% [markdown]
# ## Testing the Prior Distributions
#
# To understand the differences between the models first, we make a set of fake data. A very simply setup, a grid of 100 points for each variable $N_c$ and $N_f$.

# %%
import numpy as np
from scipy.stats import beta
